# %%
import trimesh
from trimesh import viewer
from trimesh.viewer import windowed
from trimesh import creation, transformations
import numpy as np
import math
import sys
from scipy.spatial.transform import Rotation as R
import random

# %%
#Set up all parameters to be used in the planner here
pi = math.pi
yaw_rate_bounds = [-pi/6, pi/6]
pitch_rate_bounds = [-pi/6, pi/6]
lin_acc_rate_bounds = [-0.5, 0.5]

pitch_bounds = [-pi/3,pi/3]
velocity_bounds = [-1,1]
delta_s = 1.2
delta_bn = 3
T_prop = 2
probability_goal = 0.05
dynamic_bounds = {"PITCH":pitch_bounds,"VEL":velocity_bounds}
goal_state = [15, -300, 5, 0,0,0]
goal_radius = 2

N = 10000 #number of iterations
STATE_SPACE = {"X":None,"Y":None,"Z":None,"PITCH":None,"YAW":None,"VEL":None}
U = {"PITCH_RATE":yaw_rate_bounds,"YAW_RATE":pitch_rate_bounds,"LIN_ACC":lin_acc_rate_bounds}

# %%
#### LOAD IN STL MODELS ####
#########print("Loading environment stl...")
envMesh = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/FlatSlopes_WithTrees.stl",process=False)
envMesh = trimesh.Trimesh(envMesh.vertices,envMesh.faces,envMesh.face_normals,envMesh.vertex_normals)
#####print("Done.")

# %%
print("Loading drone stl...")
droneSTL = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/DroneGeneral_Smaller.stl")
droneSTL = trimesh.Trimesh(droneSTL.vertices,droneSTL.faces,droneSTL.face_normals,droneSTL.vertex_normals)
print("Done.")
#Get max dimension of the drone
bounds = droneSTL.bounds
x_dim = bounds[1][0]-bounds[0][0]
y_dim = bounds[1][1]-bounds[0][1]
z_dim = bounds[1][2]-bounds[0][2]
droneMaxDim = math.sqrt(x_dim**2+y_dim**2+z_dim**2)
print("Drone Max Dimension: " + str(droneMaxDim))
# Out:
# Loading drone stl...
# Done.
# Drone Max Dimension: 0.4856526011604424

# %%
print("Loading bounding mesh stl...")
boundingMesh = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/FlatSlopes_BoundingVolume.stl")
boundingMesh = trimesh.Trimesh(boundingMesh.vertices,boundingMesh.faces,boundingMesh.face_normals,boundingMesh.vertex_normals)
print("Done.")
# Out:
# Loading bounding mesh stl...
# Done.

# %%
print("Loading drone obj...")
droneMesh = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/DroneGeneral_Smaller.obj")
#droneMesh = trimesh.Trimesh(droneMesh.vertices,droneMesh.faces,droneMesh.face_normals,droneMesh.vertex_normals)
print("Done.")
# Out:
# Loading drone obj...
# Done.

# %%
print("Loading drone stl...")
droneSTL = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/DroneGeneral_Smaller.stl")
droneSTL = trimesh.Trimesh(droneSTL.vertices,droneSTL.faces,droneSTL.face_normals,droneSTL.vertex_normals)
print("Done.")
#Get max dimension of the drone
bounds = droneSTL.bounds
x_dim = bounds[1][0]-bounds[0][0]
y_dim = bounds[1][1]-bounds[0][1]
z_dim = bounds[1][2]-bounds[0][2]
droneMaxDim = math.sqrt(x_dim**2+y_dim**2+z_dim**2)
print("Drone Max Dimension: " + str(droneMaxDim))
# Out:
# Loading drone stl...
# Done.
# Drone Max Dimension: 0.4856526011604424

# %%
def Runge_Kutta_Integration_fourth_order(T_sampled,input_array,dynamic_bounds):
    None

def Get3Ddist(xyz1,xyz2):
    dist = math.sqrt((xyz1[0]-xyz2[0])**2 + (xyz1[1]-xyz2[1])**2 + (xyz1[1]-xyz2[1])**2)
    # print("DIST: " + str(dist))
    return dist


def CreateRotationMatrix(alpha = 0, beta = 0, gamma = 0):
    #NO INPUTS CREATES IDENTITY MATRIX
    r_x = transformations.rotation_matrix(alpha,[1,0,0])
    r_y = transformations.rotation_matrix(beta,[0,1,0])
    r_z = transformations.rotation_matrix(gamma,[0,0,1])
    R = np.matmul(np.matmul(r_z,r_y),r_x)
    return R


def CombineRotTransMatrices(rotationMatrix,translationMatrix):
    rotMatShape = np.shape(rotationMatrix)
    tranMatShape = np.shape(translationMatrix)
    if(rotMatShape != (4,4) and rotMatShape != (3,3)):
        raise Exception("Expecting rotation matrix with shape (4, 4) or (3, 3), given matrix of shape "+str(rotMatShape))
        sys.exit()
    elif(tranMatShape != (4,4) and tranMatShape != (4,1)):
        raise Exception("Expecting translation Matrix matrix with shape (4, 4) or (4, 1), given matrix of shape "+str(tranMatShape))
        sys.exit()

        
    tranMat = translationMatrix[0:3,3]
    combinedMatrix = np.zeros([4,4])

    if(rotMatShape != (3,3)):
        rotMat = rotationMatrix[0:3,0:3]
        rotMatTrans = rotationMatrix[0:3,3]
        combinedMatrix[0:3,3] = tranMat + rotMatTrans
    else:
        rotMat = rotationMatrix
        combinedMatrix[0:3,3] = tranMat

    combinedMatrix[0:3,0:3] = rotMat
    combinedMatrix[3,:] = np.array([0,0,0,1])
    return combinedMatrix

def CheckForDroneCollision(collision_manager_with_env = trimesh.collision.CollisionManager().__init__,drone_mesh=None,transform=None):
    collision_manager_with_env.add_object("Drone",drone_mesh,transform=transform)
    isCollision = collision_manager_with_env.in_collision_internal()
    collision_manager_with_env.remove_object("Drone")
    return isCollision

def CalculateFinalTransform(TransformationList):
    #Transformation list is a list of transformations from 1st to last
    #THIS WONT WORK -  NEED TO FIGURE OUT

    prevTransform = np.zeros([4,4])
    for i in range(len(TransformationList),0,-1):
        if(i == 0):
            break
        else:
            if(i == len(TransformationList)):
                prevTransform = np.matmul(TransformationList[i],TransformationList[i-1])
            else:
                prevTransform = np.matmul(prevTransform,TransformationList[i-1])

    return prevTransform ####XXXXXX

# %%
class MeshObject:
    def __init__(self,mesh,name):
        self.name = name
        self.mesh = mesh

        self.scene = trimesh.Scene()
        self.scene.add_geometry(mesh)
        self.centroid = self.scene.centroid
        self.X = self.centroid[0]
        self.Y = self.centroid[1]
        self.Z = self.centroid[2]
        self.alpha = 0 #rotation about X, roll
        self.beta = 0  #rotation about Y, pitch
        self.gamma = 0 #rotation about Z, yaw
        self.velocity = 0
        self.ROTATION_MATRIX = np.array([[1,0,0],[0,1,0],[0,0,1]])
        self.TRANSLATION_MATRIX = np.array([self.X,self.Y,self.Z])
    
    def GetEulerAnglesFromMatrix(self):
        r = R.from_matrix(self.ROTATION_MATRIX)
        xyz = r.as_euler('xyz',degrees=False)
        self.alpha = xyz[0]
        self.beta = xyz[1]
        self.gamma = xyz[2]

    def RotateMesh(self,rot_mat):
        self.ROTATION_MATRIX = np.matmul(self.ROTATION_MATRIX,rot_mat)
        self.GetEulerAnglesFromMatrix()

    def TranslateMesh(self,transl_mat):
        self.TRANSLATION_MATRIX = np.add(self.TRANSLATION_MATRIX,transl_mat)
        self.X = self.TRANSLATION_MATRIX[0]
        self.Y = self.TRANSLATION_MATRIX[1]
        self.Z = self.TRANSLATION_MATRIX[2]
        
    def GetMeshCentroid(self,mesh):
        scene = trimesh.Scene()
        scene.add_geometry(self.mesh)
        centroid = scene.centroid
        return centroid

    def CalculateTrajectory():
        None

# %%
class Vertice:
    def __init__(self,state,cost):
        self.state=state
        self.cost = cost
        self.Parent = None
        self.Children = []

    def AddParent(self,parent):
        self.Parent = parent
    def AddChild(self,child):
        self.Children.append(child)

# %%
class PlanningAlgorithms:
    def __init__(self):
        None

    class SST: #We will be using the drone model from the exam
        def __init__(self,start_state=None,goal_state=None,u_bounds_list=None,StateSpace=None):
            self.start_state = start_state
            self.goal_state = goal_state
            self.Witness_Regions = self.WitnessRegions()
            self.Active_Set = self.ActiveSet()
            self.Inactive_Set = self.InactiveSet()
            #self.Active_Set.Has_Witness = False
            self.StateSpace = StateSpace
            None
        def SST(X,U,x_0,T_prop,N,delta_BestNeighbor,delta_s):
            None

        def Is_Node_Locally_Best_SST(X_new,S,delta_s):
            None
        def Prune_Dominated_Nodes_SST(X_new,V_active,V_inactive,E):
            None
        def Best_First_Selection_SST(X,V,delta_BestNeighbor):
            x_rand = StateValidation.StateSample(boundingMesh,pitch_bounds=pitch_bounds,velocity_bounds=velocity_bounds)
            x_nearList = [(Get3Ddist(V[i][0:3],x_rand[0:3]),i) for i in range(0,len(V)) if Get3Ddist(V[i][0:3],x_rand[0:3]) < delta_BestNeighbor]
            x_near = [V[i] for i in range(0,len(V)) if Get3Ddist(V[i][0:3],x_rand[0:3]) < delta_BestNeighbor]
            if(len(x_near) == 0): #no neighbors within delta_BestNeighbor
                None

        def MonteCarlo_Prop(x_selected,U,T_prop):
            #x_selected is chosen neighbor, U is input bounds dict, T is max propagation time
            numInputs = len(U)
            random_inputs = np.empty([1,numInputs])
            for input in range(0,numInputs):
                inputBounds = input.value #get bounds of input from dictionary
                inputSample = random.uniform(inputBounds[0],inputBounds[1])
                random_inputs[0][input] = random.uniform(U[input][0],U[input][1])
            t = random.uniform(0,T_prop)

        def Randomized_Inputs(u_bounds_list):
            random_inputs = np.empty([1,len(u_bounds_list)])
            numInputs = len(u_bounds_list)
            
            for i in range(0,numInputs):
                random_inputs[0][i] = random.uniform(u_bounds_list[i][0],u_bounds_list[i][1])
            return random_inputs

        class ActiveSet:
            def __init__(self):
                self.States = []
                self.States.append(self.start_state)
                None
        class InactiveSet:
            def __init__(self):
                None
        class WitnessRegions:
            def __init__(self,x_0,d_s,cost):
                self.Regions = []
                region = self.Region(x_0,d_s,cost)
                self.Regions.append(region)

            def AddNewRegion(self,rep,d_s,cost):
                region = self.Region(rep,d_s,cost)
                self.Regions.append(region)

            class Region:
                def __init__(self,rep,d_s,cost):
                    self.representative = rep #current state that represents the region
                    x = rep.state[0]
                    y = rep.state[1]
                    z = rep.state[2]
                    self.cost = cost
                    regionSphere = trimesh.creation.icosphere(3,d_s)
                    regionSphere.apply_translation([x,y,z])
                    self.regionMesh = regionSphere
                    
                def ChangeRepresentative(self,x,cost):
                    self.representative = x
                    self.cost = cost

# %%
droneMeshOBJ = MeshObject(droneMesh,"DRONE")
x_0 = [droneMeshOBJ.X,droneMeshOBJ.Y,droneMeshOBJ.Z,droneMeshOBJ.beta,droneMeshOBJ.gamma,droneMeshOBJ.velocity]
envMeshOBJ = MeshObject(envMesh,"ENV")
boundaryMeshOBJ = MeshObject(boundingMesh,"BOUNDARY")

# %%
class Vertice:
    def __init__(self,state,cost):
        self.state=state
        self.cost = cost
        self.Parent = None
        self.Children = []

    def AddParent(self,parent):
        self.Parent = parent
    def AddChild(self,child):
        self.Children.append(child)

# %%
E = [] #trajectory list
V_active = [] #active state list
initialState = Vertice(x_0,0)
V_active.append(initialState)
V_inactive = [] #inactive state list
V = V_active+V_inactive #active and inactive states
G = [V,E]
S = PlanningAlgorithms.SST.WitnessRegions(initialState,delta_s,0)
print(V[0].state[0:3])
# Out:
# [300.0, -15.000001000000001, 5.0001225]

# %%
#CREATE THE COLLISION MANAGER WITH OUR ENVIRONMENT
print("Creating collision manager with environment...")
ENV_COLIS_MNGR = trimesh.collision.CollisionManager()
ENV_COLIS_MNGR.add_object("ENV",envMesh)
print("Done.")
# Out:
# Creating collision manager with environment...
# Done.

# %%
class StateSampler:
    def __init__(self,boundingMesh):
        self.boundingMesh = boundingMesh

    def StateSample(self,x_bounds=None,y_bounds=None,z_bounds=None,pitch_bounds=None,beta_bounds=None,yaw_bounds=None,velocity_bounds=None):
            if(self.boundingMesh is not None):
                boundingMesh = self.boundingMesh
                sample = None
                while(sample is None or len(sample) == 0):
                    sample = trimesh.sample.volume_mesh(boundingMesh,1)
                x = sample[0][0]
                y = sample[0][1]
                z = sample[0][2]
                #alpha = random.uniform(alpha_bounds[0],alpha_bounds[1])
                pitch = random.uniform(pitch_bounds[0],pitch_bounds[1])
                yaw = random.uniform(0,2*pi)
                velocity = random.uniform(velocity_bounds[0],velocity_bounds[1])

            else:
                x = random.uniform(x_bounds[0], x_bounds[1])
                y = random.uniform(y_bounds[0], y_bounds[1])
                z = random.uniform(z_bounds[0], z_bounds[1])
                #alpha = random.uniform(alpha_bounds[0],alpha_bounds[1])
                pitch = random.uniform(pitch_bounds[0],pitch_bounds[1])
                yaw = random.uniform(0,2*pi)
                velocity = random.uniform(velocity_bounds[0],velocity_bounds[1])

            return [x,y,z,pitch,yaw,velocity]

# %%
def ExtendBranch(state0,state1,delta_bn):
    #Get unit vector <x,y,z>
    state_diff = np.subtract(state1,state0)
    print("STATE 0: " +str(state0))
    # print(state_diff)
    vector = state_diff[0:3]
    abs_vector = math.sqrt(vector[0]**2+vector[1]**2+vector[2]**2)
    unit_vector = vector/abs_vector
    extension = unit_vector*delta_bn
    
    new_xyz = state0[0:3]+extension
    x_new = [new_xyz[0],new_xyz[1],new_xyz[2],state1[3],state1[4],state1[5]]
    return x_new

# %%
def Best_First_Selection_SST(X,V,delta_BestNeighbor,sampler):
            prob = random.uniform(0,1) 
            #need to include probability of x_rand being the goal state
            #to occasionaly attempt to reach the goal
            if(prob <= probability_goal):
                x_rand = goal_state
            else:
                x_rand = sampler.StateSample(sampler.boundingMesh,pitch_bounds=pitch_bounds,velocity_bounds=velocity_bounds)
            # print(x_rand)
            # x_nearList = [(Get3Ddist(V[i].state[0:3],x_rand[0:3]),i) for i in range(0,len(V)) if Get3Ddist(V[i].state[0:3],x_rand[0:3]) < delta_BestNeighbor]
            x_nearList = [[V[i].cost,i] for i in range(0,len(V)) if Get3Ddist(V[i].state[0:3],x_rand[0:3]) < delta_BestNeighbor]
            x_near = [[int(i),Get3Ddist(V[i].state[0:3],x_rand[0:3])] for i in range(0,len(V))]
            x_near = sorted(x_near, key = lambda x: x[1])
            # print("X_NEARLIST: "+str(x_near))
            closest = int(x_near[0][0])
            # print("CLOSEST NEIGHBOR: " x)
            # print(closest)
            if(len(x_nearList) == 0): #no neighbors within delta_BestNeighbor, use closest neighbor and extend branch by delta_BN
                x_new = ExtendBranch(V[closest].state,x_rand,delta_BestNeighbor)
                # print("X_NEW: "+str(x_new))
                mode = "Branch Extension"
                return x_new, closest, mode
            else:
                x_nearList.sort(key=lambda x: x[0])
                # print("X NEAR LIST: " +str(x_nearList))
                x_new_parent_idx = x_nearList[0][1]
                mode = "Best Neighbor"
                return x_rand, x_new_parent_idx, mode

# %%
def Is_Node_Locally_the_Best_SST(xnew, S = PlanningAlgorithms.SST.WitnessRegions.__init__, delta_s=1):
    rgnIdx = 0
    for witness_region in S.Regions: #check if new or old cost is better and make that one region rep
        if(witness_region.regionMesh.contains(([xnew.state[0:3]]))):
            if(witness_region.cost > xnew.cost):
                witness_region.ChangeRepresentative(xnew,xnew.cost)
                inOldRegion = True
                return True, rgnIdx
            else:
                return False, rgnIdx
        rgnIdx += 1
            

    #if it reaches this point, it was not in an old region, new witness region will be created
    S.AddNewRegion(xnew,delta_s,xnew.cost)
    rgnIdx += 1
    return True, rgnIdx

# %%
def In_Goal_Region(state,goal_state=goal_state,goal_radius=goal_radius):
    Goal_Sphere = trimesh.creation.icosphere(radius=goal_radius)
    Goal_Sphere = Goal_Sphere.apply_translation(goal_state[0:3])
    if(Goal_Sphere.contains([state[0:3]])):
        return True
    else:
        return False

# %%
# x,y,z = trimesh.sample.volume_mesh(boundingMesh,1)[0]
# print(x)
# print(y)
# print(z)

ss_sampler = StateSampler(boundingMesh)
x_selected, x_new_parentIdx, mode = Best_First_Selection_SST(STATE_SPACE,V_active,delta_bn,ss_sampler)
# print(x_selected)
# print(x_new_parentIdx)
# print(ss_sampler.StateSample(pitch_bounds=pitch_bounds,velocity_bounds=velocity_bounds))
scene = trimesh.Scene()
scene.add_geometry(envMesh)
for iteration in range(0,N):
    # print(iteration)
    x_selected, x_new_parentIdx, mode = Best_First_Selection_SST(STATE_SPACE,V_active,delta_bn,ss_sampler)
    print("PARENT INDEX: "+str(x_new_parentIdx)+", MODE: "+mode)
    x_selected_parent = V_active[int(x_new_parentIdx)].state
    x_new_cost = Get3Ddist(x_selected,x_selected_parent)+V_active[int(x_new_parentIdx)].cost
    x_new = Vertice(x_selected,x_new_cost)

    #CHECK IF SELECTED STATE IS COLLISION FREE
    #USING A SPHERE TO REPRESENT THE DRONE, USING THE DRONES MAXIMUM DIMENSION  IS THE SIMPLEST OPTION,
    #AS WE CAN CREATE THE SPHERE AT THE SPECIFIED XYZ TO HAVE IT REPRESENT ALL ORIENTATIONS
    #AND INSERT IT AND REMOVE IT FROM THE COLLISION MANAGER WITHOUT HAVING TO PERFORM TRANSFORMATIONS
    droneSphere = trimesh.creation.icosphere(3,droneMaxDim,(0,0,255))
    droneSphere = droneSphere.apply_translation(x_selected[0:3])
    # print(droneSphere.centroid)
    dronePosCollision = CheckForDroneCollision(ENV_COLIS_MNGR,droneSphere)

    #Need to check for collision in trajectory, can use cylinder to represent space the drone travels through
    trajCylinder = trimesh.creation.cylinder(droneMaxDim,segment=[x_selected[0:3],x_selected_parent[0:3]])
    trajCylinder.visual.face_colors = [255, 0, 0, 255]
    droneTrajCollision = CheckForDroneCollision(ENV_COLIS_MNGR,trajCylinder)
    # scene = trimesh.Scene()
    # scene.add_geometry(trajCylinder)
    # scene.add_geometry(droneSphere)
    # scene.add_geometry(envMesh)
    # scene.show()

    # if(dronePosCollision==True):
    #     print("POS COLLISION")
    # if(droneTrajCollision==True):
    #     print("TRAJ COLLISION")

    #IF NO COLLISION OCCURS, WE CAN MOVE ONTO CHECKING IF VERTICE IS BEST IN WITNESS REGION
    if(droneTrajCollision == False and dronePosCollision==False):
        isNodeBest, rgnIdx = Is_Node_Locally_the_Best_SST(x_new,S=S,delta_s=delta_s)
        if(isNodeBest):
            x_new.Parent = x_selected_parent
            V_active[int(x_new_parentIdx)].Children.append(x_new)
            V_active.append(x_new)

            E.append([V_active[int(x_new_parentIdx)],x_new])
            scene.add_geometry(droneSphere)
            scene.add_geometry(trajCylinder)
            # if(In_Goal_Region(x_new.state)):
            #     print("GOAL REACHED")
            #     break

        # print("NO COLLISION")
# for vertice in V_active:
#     print(vertice.state)
# Out:
# STATE 0: [300.0, -15.000001000000001, 5.0001225, 0, 0, 0]
# STATE 0: [300.0, -15.000001000000001, 5.0001225, 0, 0, 0]
# PARENT INDEX: 0, MODE: Branch Extension
# STATE 0: [297.87867965271886, -17.12132133983793, 5.000121588204412, 0, 0, 0]
# PARENT INDEX: 1, MODE: Branch Extension
# STATE 0: [296.99125180192544, -19.983677642883656, 5.1393631195466964, 0.9912674102414829, 6.258786623311354, 0.1135556286786128]
# PARENT INDEX: 2, MODE: Branch Extension
# STATE 0: [296.2337348940475, -22.886462063147704, 5.136085353334889, 0.2438568607672329, 4.944129835146946, 0.03701341341614239]
# PARENT INDEX: 3, MODE: Branch Extension
# STATE 0: [293.5969338117398, -24.31560654009942, 5.205555608404539, -0.8467323147354445, 3.6435947894744163, -0.7854920671136396]
# PARENT INDEX: 4, MODE: Branch Extension
# STATE 0: [293.4980664494599, -27.312819832695126, 5.28884860548967, 0.37164649006948847, 1.66573082986455, -0.2466324051925226]
# PARENT INDEX: 5, MODE: Branch Extension
# STATE 0: [293.18526784188447, -30.296466542357614, 5.2857919702372165, -0.8128036757291475, 4.795268338652388, -0.4714747768433676]
# PARENT INDEX: 6, MODE: Branch Extension
# STATE 0: [290.2871361748254, -31.071552274588143, 5.294449226273753, 0.1126557741499048, 5.203449950542973, -0.10548465187902689]
# PARENT INDEX: 7, MODE: Branch Extension
# STATE 0: [288.0450121677643, -33.06475655576274, 5.298527273308303, -0.4874869941707318, 2.172439017370007, -0.4768398233667308]
# PARENT INDEX: 8, MODE: Branch Extension
# STATE 0: [285.7644921420746, -35.013579074113, 5.334848126810204, 0.8865179614301251, 6.222033649689607, -0.3456504745925091]
# PARENT INDEX: 9, MODE: Branch Extension
# STATE 0: [283.2268522036861, -36.6136162736597, 5.318584573609387, -0.39167094773507094, 4.295974726934331, -0.09471852787927304]
# PARENT INDEX: 10, MODE: Branch Extension
# STATE 0: [281.2474858006985, -38.86762248845397, 5.358139932192451, -0.20100918282684432, 0.07344383599521148, 0.7334551857747742]
# PARENT INDEX: 11, MODE: Branch Extension
# STATE 0: [279.4238922386702, -41.247983135915206, 5.44973528440462, 0.9455427171480784, 5.819143903653402, -0.25415781194279674]
# PARENT INDEX: 12, MODE: Branch Extension
# STATE 0: [280.0729962201505, -44.17652797847551, 5.401890469222113, 0.23434645970165113, 0.5328384672412867, -0.42060676244206485]
# PARENT INDEX: 13, MODE: Branch Extension
# STATE 0: [280.0729962201505, -44.17652797847551, 5.401890469222113, 0.23434645970165113, 0.5328384672412867, -0.42060676244206485]
# PARENT INDEX: 13, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.0204329855391, -47.16095305791351, 5.70262964456959, -0.06848824330005443, 3.9960111249051637, -0.9478981523408581]
# PARENT INDEX: 14, MODE: Branch Extension
# STATE 0: [280.45947109975026, -50.12214358867351, 5.899088736512962, -0.41910130394309186, 3.0460777924316917, 0.4230398258511192]
# PARENT INDEX: 15, MODE: Branch Extension
# STATE 0: [280.45947109975026, -50.12214358867351, 5.899088736512962, -0.41910130394309186, 3.0460777924316917, 0.4230398258511192]
# PARENT INDEX: 15, MODE: Branch Extension
# STATE 0: [278.49147978364306, -52.38494565846637, 5.817009672996345, 0.8659445547743716, 6.08527221856602, 0.3758554195987083]
# PARENT INDEX: 17, MODE: Branch Extension
# STATE 0: [276.41145636102107, -54.54608537571896, 5.762441515089006, 0.7150016580900682, 0.9847680238310109, 0.08307738710064871]
# PARENT INDEX: 18, MODE: Branch Extension
# STATE 0: [276.44670540013396, -57.545853192326895, 5.750171564605682, -0.2957435455479688, 6.267869900659123, -0.0035907518365281277]
# PARENT INDEX: 19, MODE: Branch Extension
# STATE 0: [273.847152532174, -59.03852637790221, 5.869551829916164, 0.05285748350508346, 3.9445856510391764, -0.18336198137422532]
# PARENT INDEX: 20, MODE: Branch Extension
# STATE 0: [272.5698764395186, -61.753036581568004, 5.869922404209866, -0.7188558323645589, 3.3039594586782304, -0.7958954055326544]
# PARENT INDEX: 21, MODE: Branch Extension
# STATE 0: [272.58259872752456, -64.75256414841486, 5.921618817176992, -0.7929233973054368, 3.8218169801915987, -0.21850232368082945]
# PARENT INDEX: 22, MODE: Branch Extension
# STATE 0: [269.91567327221503, -66.12163833328155, 6.036268248722944, 0.016916751413879494, 6.1505021497324925, 0.10596050958980197]
# PARENT INDEX: 23, MODE: Branch Extension
# STATE 0: [267.0848149096089, -67.1100811036591, 6.132298559308657, -0.5663219632173719, 2.0058170403400144, -0.8417728442447086]
# PARENT INDEX: 24, MODE: Branch Extension
# STATE 0: [264.8345475380749, -69.0940843466725, 6.127017619823013, 0.8954890493155419, 4.230229476475407, -0.9737153208873157]
# PARENT INDEX: 25, MODE: Branch Extension
# STATE 0: [264.8345475380749, -69.0940843466725, 6.127017619823013, 0.8954890493155419, 4.230229476475407, -0.9737153208873157]
# PARENT INDEX: 25, MODE: Branch Extension
# STATE 0: [261.8421097423798, -68.90296636338068, 6.0332628580349725, -0.5945196784822575, 2.2935933080322854, -0.8782226135873274]
# PARENT INDEX: 26, MODE: Branch Extension
# STATE 0: [261.8421097423798, -68.90296636338068, 6.0332628580349725, -0.5945196784822575, 2.2935933080322854, -0.8782226135873274]
# PARENT INDEX: 26, MODE: Branch Extension
# STATE 0: [261.8421097423798, -68.90296636338068, 6.0332628580349725, -0.5945196784822575, 2.2935933080322854, -0.8782226135873274]
# PARENT INDEX: 26, MODE: Branch Extension
# STATE 0: [261.8421097423798, -68.90296636338068, 6.0332628580349725, -0.5945196784822575, 2.2935933080322854, -0.8782226135873274]
# PARENT INDEX: 26, MODE: Branch Extension
# STATE 0: [259.31113482906187, -70.51353283903138, 6.048806849325344, -0.7970850830957603, 3.4050888219457454, -0.7559695565992937]
# PARENT INDEX: 27, MODE: Branch Extension
# STATE 0: [256.31788458096963, -70.70781941726163, 5.996790718986972, 0.03479597828874037, 0.1385259163882726, 0.9410210631195057]
# PARENT INDEX: 28, MODE: Branch Extension
# STATE 0: [255.49604467620892, -73.59088020711899, 6.108771310743001, -0.7336191154742577, 2.8794472472790322, -0.7162666284131893]
# PARENT INDEX: 29, MODE: Branch Extension
# STATE 0: [253.8626511797467, -76.1062889545086, 6.17765178163836, 0.10720396182092906, 0.3639150005462222, 0.13797293238119535]
# PARENT INDEX: 30, MODE: Branch Extension
# STATE 0: [250.8900220857298, -75.70629179895244, 6.23663097247156, -0.4720683062568273, 0.3977592936510282, 0.8634641920376604]
# PARENT INDEX: 31, MODE: Branch Extension
# STATE 0: [249.28932208555062, -78.24302219213439, 6.184110293369939, -0.2706010527843187, 0.44431723426560527, -0.8875220293060646]
# PARENT INDEX: 32, MODE: Branch Extension
# STATE 0: [247.51337506143355, -80.65939751580723, 6.268623385105671, 0.9554969356290963, 1.9027118027653747, 0.35467388417973367]
# PARENT INDEX: 33, MODE: Branch Extension
# STATE 0: [247.51337506143355, -80.65939751580723, 6.268623385105671, 0.9554969356290963, 1.9027118027653747, 0.35467388417973367]
# PARENT INDEX: 33, MODE: Branch Extension
# STATE 0: [248.4965813325351, -83.49262644544334, 6.34684908893492, -0.20897884740820705, 0.7658251574442729, -0.18471326433511237]
# PARENT INDEX: 35, MODE: Branch Extension
# STATE 0: [279.4238922386702, -41.247983135915206, 5.44973528440462, 0.9455427171480784, 5.819143903653402, -0.25415781194279674]
# PARENT INDEX: 12, MODE: Branch Extension
# STATE 0: [244.54655897171725, -80.9140104075516, 6.633554289741009, 0.8856237049108304, 2.235851082876676, 0.20318714117805392]
# PARENT INDEX: 34, MODE: Branch Extension
# STATE 0: [248.51405671606773, -86.4916468707959, 6.272209291986734, 0.5976661734469637, 2.0817163570821124, 0.5201177046088266]
# PARENT INDEX: 36, MODE: Branch Extension
# STATE 0: [241.56867198990813, -80.56954576117623, 6.517221873926662, -0.7819377322233445, 3.877610928794003, -0.20263272581728775]
# PARENT INDEX: 38, MODE: Branch Extension
# STATE 0: [238.68580833065437, -81.3995774032964, 6.505197098114733, -0.343801006300814, 4.032802772643755, -0.8446921190866736]
# PARENT INDEX: 40, MODE: Branch Extension
# STATE 0: [247.52931970879067, -89.32018755150878, 6.444402915711132, -0.08181941609884469, 3.5336796355828044, -0.9968719203228333]
# PARENT INDEX: 39, MODE: Branch Extension
# STATE 0: [245.4176176266428, -91.45091174270932, 6.4713980501830015, 0.8665568108763155, 5.9399137669344855, -0.4025729923122119]
# PARENT INDEX: 42, MODE: Branch Extension
# STATE 0: [276.64199342000643, -40.157638758316146, 5.718413718513489, -0.12279964813875688, 1.8503844447280817, -0.96904393440382]
# PARENT INDEX: 37, MODE: Branch Extension
# STATE 0: [246.28795711672174, -94.31879609200342, 6.338174437099471, -0.12210055413579035, 3.5162326126350867, 0.005022884306244979]
# PARENT INDEX: 43, MODE: Branch Extension
# STATE 0: [235.85856301251445, -82.40156936305122, 6.557120345726789, 0.21705817731211186, 1.7781086296699784, 0.5388265799384517]
# PARENT INDEX: 41, MODE: Branch Extension
# STATE 0: [247.60701769243497, -97.01127051379156, 6.441425033299836, -0.1844033503548116, 2.6288443418228034, 0.7800463810628162]
# PARENT INDEX: 44, MODE: Branch Extension
# STATE 0: [276.64199342000643, -40.157638758316146, 5.718413718513489, -0.12279964813875688, 1.8503844447280817, -0.96904393440382]
# PARENT INDEX: 37, MODE: Branch Extension
# STATE 0: [233.0958163100725, -83.57051442703029, 6.528869760861827, -1.0013719912062353, 2.4094953294609254, -0.4902010627268807]
# PARENT INDEX: 45, MODE: Branch Extension
# STATE 0: [245.54263480866211, -99.03177636233228, 7.251288864569258, -0.9067594650290037, 2.924121307376758, 0.5103828822992864]
# PARENT INDEX: 46, MODE: Branch Extension
# STATE 0: [230.3984328253271, -82.30027015343734, 6.196301239159907, 0.19222739691605106, 4.181112933559901, -0.23366770912198498]
# PARENT INDEX: 48, MODE: Branch Extension
# STATE 0: [245.17232831853934, -102.00774085941616, 7.170614113442956, 0.1816162453315342, 2.100123056244155, -0.4969725725877061]
# PARENT INDEX: 49, MODE: Branch Extension
# STATE 0: [242.9141986308669, -103.98063027713668, 7.263121729879871, -0.7863923393864712, 2.5422152934594715, 0.17318121927761743]
# PARENT INDEX: 51, MODE: Branch Extension
# PARENT INDEX: 29, MODE: Best Neighbor
# STATE 0: [247.60701769243497, -97.01127051379156, 6.441425033299836, -0.1844033503548116, 2.6288443418228034, 0.7800463810628162]
# PARENT INDEX: 44, MODE: Branch Extension
# STATE 0: [296.2337348940475, -22.886462063147704, 5.136085353334889, 0.2438568607672329, 4.944129835146946, 0.03701341341614239]
# PARENT INDEX: 3, MODE: Branch Extension
# STATE 0: [297.87867965271886, -17.12132133983793, 5.000121588204412, 0, 0, 0]
# PARENT INDEX: 1, MODE: Branch Extension
# STATE 0: [227.64228882044682, -81.15159087736926, 6.486484190234246, -0.40388583208097606, 0.9246039185939432, 0.13263352192931976]
# PARENT INDEX: 50, MODE: Branch Extension
# STATE 0: [242.9141986308669, -103.98063027713668, 7.263121729879871, -0.7863923393864712, 2.5422152934594715, 0.17318121927761743]
# PARENT INDEX: 51, MODE: Branch Extension
# STATE 0: [243.56594533607623, -106.87677823256146, 7.696195918140528, -0.8097540144057889, 1.825139954731243, -0.3672930659004432]
# PARENT INDEX: 56, MODE: Branch Extension
# STATE 0: [241.35848308687903, -108.90787327188774, 7.738188293561652, -0.9050350397948341, 6.268111050921875, -0.289090434784268]
# PARENT INDEX: 57, MODE: Branch Extension
# STATE 0: [241.35848308687903, -108.90787327188774, 7.738188293561652, -0.9050350397948341, 6.268111050921875, -0.289090434784268]
# PARENT INDEX: 57, MODE: Branch Extension
# STATE 0: [241.35848308687903, -108.90787327188774, 7.738188293561652, -0.9050350397948341, 6.268111050921875, -0.289090434784268]
# PARENT INDEX: 57, MODE: Branch Extension
# STATE 0: [244.00003295403047, -110.32590857251836, 7.844913105660752, 0.18469050124783504, 5.618548487329676, -0.5145457927664792]
# PARENT INDEX: 58, MODE: Branch Extension
# STATE 0: [273.96120235137175, -38.81144444453982, 5.684945586137986, 0.7140934696564383, 4.966114914462365, -0.4867174077417431]
# PARENT INDEX: 47, MODE: Branch Extension
# STATE 0: [224.70642761116417, -81.75688895187325, 6.366762843636432, -0.01114085940529308, 5.674989941465511, 0.47132403596202743]
# PARENT INDEX: 55, MODE: Branch Extension
# STATE 0: [243.5389263933305, -113.29023391094864, 7.857404207279548, 0.014877020352785486, 1.3111983242529135, 0.22774338763453428]
# PARENT INDEX: 59, MODE: Branch Extension
# STATE 0: [242.91257437182477, -116.22364896653266, 7.909932835937277, 0.49415290618063556, 3.9719853804624674, 0.5784319397126649]
# PARENT INDEX: 62, MODE: Branch Extension
# STATE 0: [244.37343158313442, -118.84375256481425, 7.879056592052098, -0.49840808051560004, 6.1921600195368995, -0.8556683866571382]
# PARENT INDEX: 63, MODE: Branch Extension
# STATE 0: [242.5343123689746, -121.2092360004006, 7.730299635660586, -0.3728364969390585, 4.489842698860997, 0.4731331077594465]
# PARENT INDEX: 64, MODE: Branch Extension
# STATE 0: [221.919845287045, -80.64563600924266, 6.3754719424082955, 0.8566632813136632, 6.247733068170156, 0.176041921551102]
# PARENT INDEX: 61, MODE: Branch Extension
# STATE 0: [242.5343123689746, -121.2092360004006, 7.730299635660586, -0.3728364969390585, 4.489842698860997, 0.4731331077594465]
# PARENT INDEX: 64, MODE: Branch Extension
# STATE 0: [242.24045325288375, -124.1941018139271, 7.795283442343669, -0.44414665958352284, 4.73848257809787, -0.43113691466030724]
# PARENT INDEX: 65, MODE: Branch Extension
# STATE 0: [242.24045325288375, -124.1941018139271, 7.795283442343669, -0.44414665958352284, 4.73848257809787, -0.43113691466030724]
# PARENT INDEX: 65, MODE: Branch Extension
# STATE 0: [221.919845287045, -80.64563600924266, 6.3754719424082955, 0.8566632813136632, 6.247733068170156, 0.176041921551102]
# PARENT INDEX: 61, MODE: Branch Extension
# STATE 0: [221.919845287045, -80.64563600924266, 6.3754719424082955, 0.8566632813136632, 6.247733068170156, 0.176041921551102]
# PARENT INDEX: 61, MODE: Branch Extension
# STATE 0: [241.47844823154716, -127.09488781609288, 7.86448544446006, 0.8219951146511599, 4.802648468951621, 0.1944092900490193]
# PARENT INDEX: 66, MODE: Branch Extension
# STATE 0: [241.47844823154716, -127.09488781609288, 7.86448544446006, 0.8219951146511599, 4.802648468951621, 0.1944092900490193]
# PARENT INDEX: 66, MODE: Branch Extension
# STATE 0: [238.83317625063182, -128.50772803293466, 7.944602038613723, 0.47427453040673306, 5.819007828647991, -0.4091626363901384]
# PARENT INDEX: 68, MODE: Branch Extension
# STATE 0: [237.76378408075877, -131.3105890165942, 7.925348641684398, 0.33487430494819836, 5.43592616364433, -0.01158663184731723]
# PARENT INDEX: 69, MODE: Branch Extension
# STATE 0: [236.058294364047, -133.77828130976957, 7.882927274506066, -0.5609260113548263, 0.4549377123132284, -0.8965310228025305]
# PARENT INDEX: 70, MODE: Branch Extension
# STATE 0: [241.47844823154716, -127.09488781609288, 7.86448544446006, 0.8219951146511599, 4.802648468951621, 0.1944092900490193]
# PARENT INDEX: 66, MODE: Branch Extension
# STATE 0: [233.10574415583022, -134.28549428682695, 8.041616479758764, 0.16610370560034027, 5.946301064032037, 0.9659390641380381]
# PARENT INDEX: 71, MODE: Branch Extension
# STATE 0: [233.10574415583022, -134.28549428682695, 8.041616479758764, 0.16610370560034027, 5.946301064032037, 0.9659390641380381]
# PARENT INDEX: 71, MODE: Branch Extension
# STATE 0: [233.10574415583022, -134.28549428682695, 8.041616479758764, 0.16610370560034027, 5.946301064032037, 0.9659390641380381]
# PARENT INDEX: 71, MODE: Branch Extension
# STATE 0: [230.32933181203936, -133.16211980144203, 8.213559094696958, -0.5793834148303609, 4.602925337607895, 0.247197498245181]
# PARENT INDEX: 72, MODE: Branch Extension
# STATE 0: [219.12512409713065, -81.65178397061841, 5.954520935207709, -0.9266343846058641, 0.2696920765745043, -0.4055899387518771]
# PARENT INDEX: 67, MODE: Branch Extension
# STATE 0: [250.58778130481215, -97.12967198816892, 6.759276221740768, -0.7061868297061351, 1.5953109092309326, -0.5259203483786365]
# PARENT INDEX: 52, MODE: Branch Extension
# STATE 0: [216.18696392864064, -81.61744703919895, 6.559529860298403, 0.7710820649465626, 3.558821782342813, -0.560493220604187]
# PARENT INDEX: 74, MODE: Branch Extension
# STATE 0: [233.10574415583022, -134.28549428682695, 8.041616479758764, 0.16610370560034027, 5.946301064032037, 0.9659390641380381]
# PARENT INDEX: 71, MODE: Branch Extension
# STATE 0: [227.3486412617975, -133.49940994544284, 8.255022361076088, -0.16724456824515344, 0.33243731484733635, -0.7546626430134074]
# PARENT INDEX: 73, MODE: Branch Extension
# STATE 0: [241.56867198990813, -80.56954576117623, 6.517221873926662, -0.7819377322233445, 3.877610928794003, -0.20263272581728775]
# PARENT INDEX: 38, MODE: Branch Extension
# STATE 0: [213.29314327390944, -80.83980246650043, 6.704688176641504, -0.7291864739350513, 1.722602797221833, 0.9647403495174878]
# PARENT INDEX: 76, MODE: Branch Extension
# STATE 0: [233.71869084557542, -137.2221565395764, 8.059256457279156, 0.4380887878230124, 6.085093451512312, 0.08108813725870623]
# PARENT INDEX: 77, MODE: Branch Extension
# STATE 0: [224.98799706992048, -135.35036904987058, 8.218836824001562, 0, 0, 0]
# PARENT INDEX: 78, MODE: Branch Extension
# STATE 0: [222.62735287804347, -137.20132815429832, 8.182651286927035, 0, 0, 0]
# PARENT INDEX: 82, MODE: Branch Extension
# STATE 0: [272.5698764395186, -61.753036581568004, 5.869922404209866, -0.7188558323645589, 3.3039594586782304, -0.7958954055326544]
# PARENT INDEX: 21, MODE: Branch Extension
# STATE 0: [210.40659746942106, -80.02938803548686, 6.599418197086356, -0.2023946574994896, 1.9578192294197623, -0.5762374771431937]
# PARENT INDEX: 80, MODE: Branch Extension
# STATE 0: [242.9141986308669, -103.98063027713668, 7.263121729879871, -0.7863923393864712, 2.5422152934594715, 0.17318121927761743]
# PARENT INDEX: 51, MODE: Branch Extension
# STATE 0: [207.51540034387142, -80.82574584802174, 6.516996017861665, -0.4969746310428509, 4.262992105965976, -0.07429223380680972]
# PARENT INDEX: 85, MODE: Branch Extension
# STATE 0: [270.3504141354212, -61.073127533991574, 7.7703725529152665, -0.6417380038968827, 3.0893912574347424, -0.0320448680586336]
# PARENT INDEX: 84, MODE: Branch Extension
# STATE 0: [233.78805093926945, -140.22078786699544, 8.117560313274106, 0.8631585597541604, 1.9755229206733105, 0.4343069279811691]
# PARENT INDEX: 81, MODE: Branch Extension
# STATE 0: [235.32827583080237, -142.7928272520759, 8.006561731763787, -0.3628878866563485, 3.944268719578633, -0.7903810497147827]
# PARENT INDEX: 88, MODE: Branch Extension
# STATE 0: [220.26670868616645, -139.05228725872607, 8.146465749852508, 0, 0, 0]
# PARENT INDEX: 83, MODE: Branch Extension
# STATE 0: [271.3020177753307, -37.427473091101966, 5.569357163669504, -0.2814188021309948, 2.5051478086349563, -0.6058467919277064]
# PARENT INDEX: 60, MODE: Branch Extension
# STATE 0: [217.81745515407232, -140.78326010849955, 8.07653629345924, 0.6697328133522438, 0.5833006622840418, 0.9169580852261383]
# PARENT INDEX: 90, MODE: Branch Extension
# STATE 0: [216.23807947423415, -143.33259663935945, 8.156883753649076, -0.6966877781686679, 2.087065134725693, -0.4185285179849174]
# PARENT INDEX: 91, MODE: Branch Extension
# STATE 0: [213.27147448456975, -143.73999503177222, 7.974451889223735, 0.5479637105578208, 4.604258311128712, 0.7672274957062546]
# PARENT INDEX: 92, MODE: Branch Extension
# STATE 0: [210.30169854167727, -143.4467327927678, 8.281743457919074, -0.7846288473636086, 2.608264611783829, -0.6693255396018416]
# PARENT INDEX: 93, MODE: Branch Extension
# STATE 0: [283.3456991961773, -49.58137051142129, 5.284880421432249, -0.2208958016098147, 5.261444160312686, -0.36130540398872735]
# PARENT INDEX: 16, MODE: Branch Extension
# STATE 0: [236.49935266444234, -145.55227778472565, 7.8881902505243575, 0.11778182327875597, 2.0770154277554185, -0.12353630165469887]
# PARENT INDEX: 89, MODE: Branch Extension
# STATE 0: [241.35848308687903, -108.90787327188774, 7.738188293561652, -0.9050350397948341, 6.268111050921875, -0.289090434784268]
# PARENT INDEX: 57, MODE: Branch Extension
# STATE 0: [207.9611179806011, -145.32293528734064, 8.242413615928964, 0, 0, 0]
# PARENT INDEX: 94, MODE: Branch Extension
# STATE 0: [205.18097225345576, -78.9457329153288, 6.643474725894503, 0.5903398009664236, 4.227443047429186, 0.9210660252934231]
# PARENT INDEX: 86, MODE: Branch Extension
# STATE 0: [205.62053741952494, -147.1991377819135, 8.203083773938854, 0, 0, 0]
# PARENT INDEX: 97, MODE: Branch Extension
# STATE 0: [202.4244171244793, -77.76721584848953, 6.755284135525914, -0.9327518729509113, 5.956754011637487, -0.9815373000069854]
# PARENT INDEX: 98, MODE: Branch Extension
# STATE 0: [203.27995685844877, -149.07534027648634, 8.163753931948744, 0, 0, 0]
# PARENT INDEX: 99, MODE: Branch Extension
# STATE 0: [200.31958993377313, -149.35654462614798, 8.560177676214842, -0.7196360949861507, 1.3285192756462607, 0.5060956265351464]
# PARENT INDEX: 101, MODE: Branch Extension
# STATE 0: [199.43527944104304, -77.96624027018568, 6.914799617626274, 0.8913103428524944, 0.3883384840905806, -0.558185027681291]
# PARENT INDEX: 100, MODE: Branch Extension
# STATE 0: [199.02617872101465, -152.05938502905354, 8.412728732061689, -0.045304209097138504, 3.0879471317048584, -0.7780924956436195]
# PARENT INDEX: 102, MODE: Branch Extension
# STATE 0: [237.54387670253854, -148.36447366619598, 7.8653023043403785, -0.10499992658541468, 3.2122758939212934, -0.6112295411269819]
# PARENT INDEX: 96, MODE: Branch Extension
# STATE 0: [199.02617872101465, -152.05938502905354, 8.412728732061689, -0.045304209097138504, 3.0879471317048584, -0.7780924956436195]
# PARENT INDEX: 102, MODE: Branch Extension
# STATE 0: [240.53218124462308, -148.36574861014205, 8.129942320730251, 0.14827747520423107, 2.7097814481185067, 0.6375154011964819]
# PARENT INDEX: 104, MODE: Branch Extension
# STATE 0: [199.02617872101465, -152.05938502905354, 8.412728732061689, -0.045304209097138504, 3.0879471317048584, -0.7780924956436195]
# PARENT INDEX: 102, MODE: Branch Extension
# STATE 0: [199.02617872101465, -152.05938502905354, 8.412728732061689, -0.045304209097138504, 3.0879471317048584, -0.7780924956436195]
# PARENT INDEX: 102, MODE: Branch Extension
# STATE 0: [243.18285836528509, -149.77025324802298, 8.094199850615473, -0.5825512443493186, 1.5840710869019785, 0.8256719782980368]
# PARENT INDEX: 105, MODE: Branch Extension
# STATE 0: [199.02617872101465, -152.05938502905354, 8.412728732061689, -0.045304209097138504, 3.0879471317048584, -0.7780924956436195]
# PARENT INDEX: 102, MODE: Branch Extension
# STATE 0: [196.4373189819071, -77.98099613674769, 6.805185066313596, -0.3623095052556716, 3.371416192316669, 0.662436840726516]
# PARENT INDEX: 103, MODE: Branch Extension
# STATE 0: [267.9812721444547, -59.920958992459724, 6.335216157764006, -0.4376274020718721, 2.2514169104235773, 0.13691071619549833]
# PARENT INDEX: 87, MODE: Branch Extension
# STATE 0: [199.02617872101465, -152.05938502905354, 8.412728732061689, -0.045304209097138504, 3.0879471317048584, -0.7780924956436195]
# PARENT INDEX: 102, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [244.37343158313442, -118.84375256481425, 7.879056592052098, -0.49840808051560004, 6.1921600195368995, -0.8556683866571382]
# PARENT INDEX: 63, MODE: Branch Extension
# STATE 0: [196.03126413535716, -151.90973631384222, 8.502683646611969, -0.7032378439842155, 2.6001503531432664, 0.00818612943195629]
# PARENT INDEX: 109, MODE: Branch Extension
# STATE 0: [253.4831241304206, -97.16429307683231, 5.974552510860657, -0.17457501248937746, 0.16569780398590886, -0.3121041828409965]
# PARENT INDEX: 75, MODE: Branch Extension
# STATE 0: [193.7094877349915, -153.8090352056257, 8.457760752947758, 0, 0, 0]
# PARENT INDEX: 111, MODE: Branch Extension
# STATE 0: [190.74381086260394, -154.25126199203905, 8.553657353324974, 0.924742628110824, 3.8088948329545684, 0.7637288484505897]
# PARENT INDEX: 112, MODE: Branch Extension
# STATE 0: [190.74381086260394, -154.25126199203905, 8.553657353324974, 0.924742628110824, 3.8088948329545684, 0.7637288484505897]
# PARENT INDEX: 112, MODE: Branch Extension
# STATE 0: [188.62783825212097, -156.36597733958797, 8.328626443166097, 0.6493727036613652, 1.3656111083556723, 0.18069311638135832]
# PARENT INDEX: 113, MODE: Branch Extension
# STATE 0: [293.5969338117398, -24.31560654009942, 5.205555608404539, -0.8467323147354445, 3.6435947894744163, -0.7854920671136396]
# PARENT INDEX: 4, MODE: Branch Extension
# STATE 0: [186.70037026373205, -158.66322621785037, 8.415314072376843, 0.3358944779863602, 1.7000106080271808, -0.489851387974892]
# PARENT INDEX: 114, MODE: Branch Extension
# PARENT INDEX: 1, MODE: Best Neighbor
# STATE 0: [205.62053741952494, -147.1991377819135, 8.203083773938854, 0, 0, 0]
# PARENT INDEX: 97, MODE: Branch Extension
# STATE 0: [247.3702428419094, -118.82698439478791, 7.741793677346274, -0.012036151362778469, 1.3999301720320478, -0.7156962565676888]
# PARENT INDEX: 110, MODE: Branch Extension
# STATE 0: [244.2889049238793, -152.5565306478586, 7.978790746177679, -0.23672046621749443, 6.043345428275821, 0.9969867890142792]
# PARENT INDEX: 106, MODE: Branch Extension
# STATE 0: [184.83486810262403, -161.01259526505427, 8.434465232693709, -0.8273334686392163, 3.1712044550236724, -0.28456447994623746]
# PARENT INDEX: 116, MODE: Branch Extension
# STATE 0: [181.8380349074879, -160.9871305834326, 8.29903129854109, 1.0179813841039025, 2.3703440745399598, 0.45998866987839016]
# PARENT INDEX: 121, MODE: Branch Extension
# STATE 0: [181.45281342929653, -163.95517069145072, 8.504803818416416, 0.28536230075648694, 2.5276954950318373, 0.6457890103699229]
# PARENT INDEX: 122, MODE: Branch Extension
# STATE 0: [179.5290647737154, -166.2565450622901, 8.451258366756813, -1.0346312269921367, 0.05955028622643745, -0.07983479691896633]
# PARENT INDEX: 123, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [176.53700251629607, -166.07598129839187, 8.573570160520505, 0.8997690784025596, 1.5364756271446431, 0.3922863959880025]
# PARENT INDEX: 124, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [174.3081352430538, -168.0822108711318, 8.488755186999366, -0.9898594162219093, 4.629178062521842, 0.13625246820053327]
# PARENT INDEX: 125, MODE: Branch Extension
# STATE 0: [171.31878134699463, -168.33394292720448, 8.468899304718322, 0.08792520546665772, 1.7359501456203934, -0.5780705432872055]
# PARENT INDEX: 126, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [245.09404682219784, -155.44620281021488, 8.018050365065998, -0.7228300056187413, 5.2710817211679535, 0.8383729938885984]
# PARENT INDEX: 120, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [246.78821027509036, -157.92182699936671, 8.051142191393222, -0.9142258971316507, 6.097293864888271, 0.29282174935677596]
# PARENT INDEX: 128, MODE: Branch Extension
# STATE 0: [245.97020310282838, -160.7516642582806, 8.619372210127418, -0.431047083571248, 3.689094473526347, -0.37180076625161895]
# PARENT INDEX: 129, MODE: Branch Extension
# STATE 0: [246.78821027509036, -157.92182699936671, 8.051142191393222, -0.9142258971316507, 6.097293864888271, 0.29282174935677596]
# PARENT INDEX: 128, MODE: Branch Extension
# PARENT INDEX: 106, MODE: Best Neighbor
# STATE 0: [169.02458928758165, -170.26632251734534, 8.417988459769228, 0, 0, 0]
# PARENT INDEX: 127, MODE: Branch Extension
# PARENT INDEX: 99, MODE: Best Neighbor
# STATE 0: [166.72405931847078, -172.19014099512452, 8.498513771181976, -1.0003245547573745, 4.005882278379961, 0.8802743321503141]
# PARENT INDEX: 133, MODE: Branch Extension
# STATE 0: [249.7555414951321, -157.524106192845, 7.859403852437839, -0.983559739341719, 3.178629815261224, 0.008941342158328203]
# PARENT INDEX: 131, MODE: Branch Extension
# STATE 0: [179.5290647737154, -166.2565450622901, 8.451258366756813, -1.0346312269921367, 0.05955028622643745, -0.07983479691896633]
# PARENT INDEX: 123, MODE: Branch Extension
# STATE 0: [163.7315171736451, -172.40140468711382, 8.490821964552058, 0.12685801464092217, 3.002057265191192, -0.8006856388286956]
# PARENT INDEX: 135, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [160.80371177985032, -171.74765312516763, 8.51458056971, -0.33622460415731503, 1.6065371740430627, -0.478923007284102]
# PARENT INDEX: 138, MODE: Branch Extension
# STATE 0: [160.80371177985032, -171.74765312516763, 8.51458056971, -0.33622460415731503, 1.6065371740430627, -0.478923007284102]
# PARENT INDEX: 138, MODE: Branch Extension
# STATE 0: [196.4373189819071, -77.98099613674769, 6.805185066313596, -0.3623095052556716, 3.371416192316669, 0.662436840726516]
# PARENT INDEX: 103, MODE: Branch Extension
# STATE 0: [158.68057289329474, -169.63537135159635, 8.339803633491096, 0.4754095779148073, 5.253926725529387, -0.3552827536822347]
# PARENT INDEX: 139, MODE: Branch Extension
# STATE 0: [158.4853995570475, -173.6513515321003, 8.551469769281146, -0.2537303361257204, 4.453866581375952, 0.8345984359443743]
# PARENT INDEX: 140, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [156.08840518700327, -175.4553385124039, 8.558467259646875, -0.0613383633676684, 6.027646300085538, -0.6259512923472379]
# PARENT INDEX: 142, MODE: Branch Extension
# STATE 0: [157.09046434501474, -178.281677534068, 8.646132409302572, -0.36626656715658146, 2.9557980606738283, 0.968100971672361]
# PARENT INDEX: 143, MODE: Branch Extension
# STATE 0: [158.68057289329474, -169.63537135159635, 8.339803633491096, 0.4754095779148073, 5.253926725529387, -0.3552827536822347]
# PARENT INDEX: 139, MODE: Branch Extension
# STATE 0: [154.81254478584162, -180.2330016340558, 8.587679533039756, 0, 0, 0]
# PARENT INDEX: 144, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [152.5346252266685, -182.1843257340436, 8.52922665677694, 0, 0, 0]
# PARENT INDEX: 145, MODE: Branch Extension
# STATE 0: [149.80592001880123, -183.42680919239046, 8.631220501161536, -0.2728546911817423, 0.08644273059837022, 0.6244163225858848]
# PARENT INDEX: 146, MODE: Branch Extension
# STATE 0: [148.3769311267369, -186.0556628176432, 8.41415055079456, -0.6124339658697115, 2.7905747255149933, -0.26389368131142743]
# PARENT INDEX: 147, MODE: Branch Extension
# STATE 0: [146.49655999520647, -188.38147187246426, 8.648280105142819, -0.39990987422728563, 1.3755826660559345, 0.3652597994721052]
# PARENT INDEX: 148, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [144.9283899545624, -190.93853667022964, 8.600716004652549, 0.44853603756745275, 2.0568020583018924, -0.28636944736327496]
# PARENT INDEX: 149, MODE: Branch Extension
# STATE 0: [158.68057289329474, -169.63537135159635, 8.339803633491096, 0.4754095779148073, 5.253926725529387, -0.3552827536822347]
# PARENT INDEX: 139, MODE: Branch Extension
# STATE 0: [142.72092761888868, -192.96832157794137, 8.51655386941554, 0.8153182111569248, 5.796274860028272, 0.29196085304545183]
# PARENT INDEX: 150, MODE: Branch Extension
# STATE 0: [156.42755042287894, -167.66185596066, 8.169138026121582, 0.1066205675797427, 3.7868667680072776, 0.4593668217083158]
# PARENT INDEX: 151, MODE: Branch Extension
# STATE 0: [155.71834381081644, -164.75073572726882, 8.318820918087162, -0.6813229515590069, 3.33366798121492, -0.11997942849227328]
# PARENT INDEX: 153, MODE: Branch Extension
# STATE 0: [143.1926819981293, -195.92976694580366, 8.431177415786463, 0.06115409700927743, 5.8561168649625905, -0.5517395307699466]
# PARENT INDEX: 152, MODE: Branch Extension
# STATE 0: [145.13708749988444, -198.21411186195627, 8.398688205391954, 0.604609777295043, 4.163711877564425, -0.17610990929233927]
# PARENT INDEX: 155, MODE: Branch Extension
# STATE 0: [142.50773899054445, -199.65000314608, 8.555986128483942, -0.03736748801384038, 1.459908526927913, -0.1854604598131433]
# PARENT INDEX: 156, MODE: Branch Extension
# STATE 0: [152.93328383534433, -163.6369213078777, 8.265357171680854, 0.9687967341907073, 5.529036123106983, -0.7766668348513728]
# PARENT INDEX: 154, MODE: Branch Extension
# STATE 0: [142.69728133974894, -202.6369012563812, 8.762173850080094, 0.6625008391943095, 1.9707114085455448, 0.7577614947369871]
# PARENT INDEX: 157, MODE: Branch Extension
# STATE 0: [142.50773899054445, -199.65000314608, 8.555986128483942, -0.03736748801384038, 1.459908526927913, -0.1854604598131433]
# PARENT INDEX: 156, MODE: Branch Extension
# STATE 0: [143.03117715307727, -205.61746768386803, 8.83100231207332, 0.5587000455123097, 2.423890837531745, -0.17901155888168852]
# PARENT INDEX: 159, MODE: Branch Extension
# STATE 0: [145.69864101814366, -206.99027242506088, 8.824393898991291, 0.8468130552351087, 2.4351093069199186, 0.7962364422993011]
# PARENT INDEX: 161, MODE: Branch Extension
# STATE 0: [144.8493088446127, -209.86734380738446, 8.791301301331483, -0.683213775416843, 1.1699374756375256, 0.53701430580128]
# PARENT INDEX: 162, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [193.62305969638115, -77.02186355568968, 7.205196773372105, 0.8368344424037322, 5.380361560173794, 0.5049673218592394]
# PARENT INDEX: 107, MODE: Branch Extension
# STATE 0: [192.5247931376114, -74.2327738763709, 7.083585398059149, -0.16367702335441625, 4.967116520280842, -0.5749005145311012]
# PARENT INDEX: 164, MODE: Branch Extension
# STATE 0: [139.5078972882908, -199.61937728394943, 8.552548398338446, -0.36572012099466555, 2.4946528524091445, -0.4047220930500237]
# PARENT INDEX: 160, MODE: Branch Extension
# STATE 0: [150.21202073594455, -162.3756351229166, 8.203032991209383, -0.898288807003531, 2.404190809819597, 0.9711307144578747]
# PARENT INDEX: 158, MODE: Branch Extension
# STATE 0: [200.31958993377313, -149.35654462614798, 8.560177676214842, -0.7196360949861507, 1.3285192756462607, 0.5060956265351464]
# PARENT INDEX: 101, MODE: Branch Extension
# STATE 0: [142.40711401351564, -211.60882463999042, 8.845420767597199, -0.4991941940052811, 2.2726818952958703, 0.46411402583399486]
# PARENT INDEX: 163, MODE: Branch Extension
# STATE 0: [142.40711401351564, -211.60882463999042, 8.845420767597199, -0.4991941940052811, 2.2726818952958703, 0.46411402583399486]
# PARENT INDEX: 163, MODE: Branch Extension
# STATE 0: [292.6736706385405, -22.443308715987328, 3.0510055461318784, -0.06719825579079208, 3.076795047891852, 0.6225900372061388]
# PARENT INDEX: 115, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [147.21630234896705, -162.2963296772035, 8.063813767662113, 0.24315993604926622, 2.5872137534214485, -0.6236028129123918]
# PARENT INDEX: 167, MODE: Branch Extension
# STATE 0: [271.3020177753307, -37.427473091101966, 5.569357163669504, -0.2814188021309948, 2.5051478086349563, -0.6058467919277064]
# PARENT INDEX: 60, MODE: Branch Extension
# STATE 0: [289.8083218802381, -21.573829140645728, 3.234803699982331, -0.6792830793617655, 6.264311780858345, -0.08775767416969216]
# PARENT INDEX: 170, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [136.57578180748573, -198.9861779143076, 8.594469341893431, -0.2607434447305941, 5.437900032901461, 0.6592536001473266]
# PARENT INDEX: 166, MODE: Branch Extension
# STATE 0: [210.30169854167727, -143.4467327927678, 8.281743457919074, -0.7846288473636086, 2.608264611783829, -0.6693255396018416]
# PARENT INDEX: 93, MODE: Branch Extension
# STATE 0: [189.84283839518713, -72.89677596614496, 7.232677126400952, 0.9015655782351628, 6.221826363777806, -0.06442630687125117]
# PARENT INDEX: 165, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [252.71206595979655, -158.0310293357747, 7.9040358701252265, -1.0397768797380653, 5.606410988075129, 0.048975388706981704]
# PARENT INDEX: 136, MODE: Branch Extension
# STATE 0: [247.59170535200815, -163.27332534334917, 8.72871491887264, -0.9473238284608198, 3.620565169568706, 0.7835834795019465]
# PARENT INDEX: 130, MODE: Branch Extension
# STATE 0: [144.56087133005315, -160.9009896132157, 8.10519262241199, -0.46717637848772875, 4.192285049869172, 0.06900923784765456]
# PARENT INDEX: 171, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [253.4831241304206, -97.16429307683231, 5.974552510860657, -0.17457501248937746, 0.16569780398590886, -0.3121041828409965]
# PARENT INDEX: 75, MODE: Branch Extension
# PARENT INDEX: 114, MODE: Best Neighbor
# STATE 0: [187.03984579641747, -71.8276666825085, 7.248098892991404, -0.29718952257976183, 2.581452186416564, 0.16234081379435206]
# PARENT INDEX: 174, MODE: Branch Extension
# STATE 0: [142.72092761888868, -192.96832157794137, 8.51655386941554, 0.8153182111569248, 5.796274860028272, 0.29196085304545183]
# PARENT INDEX: 150, MODE: Branch Extension
# STATE 0: [187.03984579641747, -71.8276666825085, 7.248098892991404, -0.29718952257976183, 2.581452186416564, 0.16234081379435206]
# PARENT INDEX: 174, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [184.07745343701626, -72.28793634639798, 7.359379374048757, -0.055178129622851846, 3.690000926817347, 0.6381100219838451]
# PARENT INDEX: 180, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [250.29871530160324, -119.22488527810619, 8.257277857384151, 0.5490261611116012, 5.2177472606182205, 0.13944297962139895]
# PARENT INDEX: 119, MODE: Branch Extension
# STATE 0: [181.19818692719753, -73.0556278120199, 7.706473279278196, -0.459135298911044, 5.468570822567808, 0.962278688534804]
# PARENT INDEX: 181, MODE: Branch Extension
# STATE 0: [271.3020177753307, -37.427473091101966, 5.569357163669504, -0.2814188021309948, 2.5051478086349563, -0.6058467919277064]
# PARENT INDEX: 60, MODE: Branch Extension
# STATE 0: [136.57578180748573, -198.9861779143076, 8.594469341893431, -0.2607434447305941, 5.437900032901461, 0.6592536001473266]
# PARENT INDEX: 166, MODE: Branch Extension
# STATE 0: [187.50277093796802, -68.88156091139433, 6.922275169594448, 0.2778660402019244, 3.383310358565121, -0.8385096853236278]
# PARENT INDEX: 178, MODE: Branch Extension
# STATE 0: [178.2236604343617, -73.43760158673258, 7.627175241159277, -0.13856444957325564, 6.2507542326165595, -0.25967276742194945]
# PARENT INDEX: 182, MODE: Branch Extension
# PARENT INDEX: 133, MODE: Best Neighbor
# STATE 0: [248.6295539238509, -166.05974525243607, 8.330300019341887, -0.3921609389350862, 1.464972258441337, 0.7395270914248986]
# PARENT INDEX: 176, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [178.2236604343617, -73.43760158673258, 7.627175241159277, -0.13856444957325564, 6.2507542326165595, -0.25967276742194945]
# PARENT INDEX: 182, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [142.40711401351564, -211.60882463999042, 8.845420767597199, -0.4991941940052811, 2.2726818952958703, 0.46411402583399486]
# PARENT INDEX: 163, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [144.56087133005315, -160.9009896132157, 8.10519262241199, -0.46717637848772875, 4.192285049869172, 0.06900923784765456]
# PARENT INDEX: 171, MODE: Branch Extension
# STATE 0: [250.55794828466273, -168.34438949750847, 8.578686537991222, 1.0445684457334343, 1.6501653640761043, -0.7910007874225522]
# PARENT INDEX: 185, MODE: Branch Extension
# STATE 0: [175.26917375620437, -72.9189189167949, 7.582714511327953, -0.9979753190516184, 3.7509597493056708, 0.8085905899810919]
# PARENT INDEX: 186, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [290.2871361748254, -31.071552274588143, 5.294449226273753, 0.1126557741499048, 5.203449950542973, -0.10548465187902689]
# PARENT INDEX: 7, MODE: Branch Extension
# STATE 0: [266.6900766121145, -58.9522897211237, 8.863949821089207, -0.8279560520226119, 3.7311517869108948, -0.9122019371309313]
# PARENT INDEX: 108, MODE: Branch Extension
# STATE 0: [175.26917375620437, -72.9189189167949, 7.582714511327953, -0.9979753190516184, 3.7509597493056708, 0.8085905899810919]
# PARENT INDEX: 186, MODE: Branch Extension
# STATE 0: [141.73838215946589, -159.88600185219107, 8.047272618200136, 0.17527552651288114, 1.4735772815274284, -0.20564041090853102]
# PARENT INDEX: 187, MODE: Branch Extension
# STATE 0: [245.97020310282838, -160.7516642582806, 8.619372210127418, -0.431047083571248, 3.689094473526347, -0.37180076625161895]
# PARENT INDEX: 129, MODE: Branch Extension
# STATE 0: [175.26917375620437, -72.9189189167949, 7.582714511327953, -0.9979753190516184, 3.7509597493056708, 0.8085905899810919]
# PARENT INDEX: 186, MODE: Branch Extension
# STATE 0: [250.29871530160324, -119.22488527810619, 8.257277857384151, 0.5490261611116012, 5.2177472606182205, 0.13944297962139895]
# PARENT INDEX: 119, MODE: Branch Extension
# STATE 0: [141.73838215946589, -159.88600185219107, 8.047272618200136, 0.17527552651288114, 1.4735772815274284, -0.20564041090853102]
# PARENT INDEX: 187, MODE: Branch Extension
# STATE 0: [141.73838215946589, -159.88600185219107, 8.047272618200136, 0.17527552651288114, 1.4735772815274284, -0.20564041090853102]
# PARENT INDEX: 187, MODE: Branch Extension
# STATE 0: [175.26917375620437, -72.9189189167949, 7.582714511327953, -0.9979753190516184, 3.7509597493056708, 0.8085905899810919]
# PARENT INDEX: 186, MODE: Branch Extension
# STATE 0: [154.81254478584162, -180.2330016340558, 8.587679533039756, 0, 0, 0]
# PARENT INDEX: 144, MODE: Branch Extension
# STATE 0: [175.26917375620437, -72.9189189167949, 7.582714511327953, -0.9979753190516184, 3.7509597493056708, 0.8085905899810919]
# PARENT INDEX: 186, MODE: Branch Extension
# STATE 0: [136.57578180748573, -198.9861779143076, 8.594469341893431, -0.2607434447305941, 5.437900032901461, 0.6592536001473266]
# PARENT INDEX: 166, MODE: Branch Extension
# STATE 0: [136.57578180748573, -198.9861779143076, 8.594469341893431, -0.2607434447305941, 5.437900032901461, 0.6592536001473266]
# PARENT INDEX: 166, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [255.52299915088912, -157.15716778585897, 7.325226240978488, -1.0079324763626485, 1.8535390820114708, -0.5200890202543889]
# PARENT INDEX: 175, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# STATE 0: [141.73838215946589, -159.88600185219107, 8.047272618200136, 0.17527552651288114, 1.4735772815274284, -0.20564041090853102]
# PARENT INDEX: 187, MODE: Branch Extension
# STATE 0: [208.824804664794, -140.968578871907, 9.10487019235728, -0.4441738701306972, 0.3103304595541793, -0.49346576986166824]
# PARENT INDEX: 173, MODE: Branch Extension
# STATE 0: [141.73838215946589, -159.88600185219107, 8.047272618200136, 0.17527552651288114, 1.4735772815274284, -0.20564041090853102]
# PARENT INDEX: 187, MODE: Branch Extension
# STATE 0: [245.54263480866211, -99.03177636233228, 7.251288864569258, -0.9067594650290037, 2.924121307376758, 0.5103828822992864]
# PARENT INDEX: 46, MODE: Branch Extension
# STATE 0: [143.52187904185416, -214.37782964425364, 9.145271093524372, -0.5992573918604667, 3.341965718594829, -0.2805362292476392]
# PARENT INDEX: 169, MODE: Branch Extension
# ...
# PARENT INDEX: 5131, MODE: Branch Extension
# STATE 0: [183.7842850444362, -49.24589217357676, 8.664173593156002, 0.8333219263383831, 2.3503473615713815, -0.7914316617124719]
# PARENT INDEX: 2014, MODE: Branch Extension
# STATE 0: [225.66436852468397, -229.6746990371508, 7.392876733660362, 0.9777918540238162, 2.4135636201918005, -0.8437435784918839]
# PARENT INDEX: 4595, MODE: Branch Extension
# PARENT INDEX: 1532, MODE: Best Neighbor
# PARENT INDEX: 135, MODE: Best Neighbor
# PARENT INDEX: 1580, MODE: Best Neighbor
# PARENT INDEX: 4762, MODE: Best Neighbor
# PARENT INDEX: 3336, MODE: Best Neighbor
# PARENT INDEX: 2012, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# PARENT INDEX: 5196, MODE: Best Neighbor
# STATE 0: [54.92089683889613, -248.89444304972073, 4.482063003465749, -0.5049664352148091, 1.4313473979923774, -0.6804574320957493]
# PARENT INDEX: 6368, MODE: Branch Extension
# PARENT INDEX: 951, MODE: Best Neighbor
# PARENT INDEX: 4858, MODE: Best Neighbor
# STATE 0: [77.6297459853756, -8.20858265116254, 9.270671306004918, -0.766378418136868, 4.400690525750412, 0.980894754385665]
# PARENT INDEX: 6604, MODE: Branch Extension
# PARENT INDEX: 1799, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [291.0227450830902, -73.70298290234149, 5.871065843307613, -0.15738421156875848, 1.2296472664164697, -0.6182846440670158]
# PARENT INDEX: 2139, MODE: Branch Extension
# PARENT INDEX: 3923, MODE: Best Neighbor
# STATE 0: [7.9203376032946196, -193.15862727231988, 4.825410636931345, -0.011803364800938576, 0.8888917441791934, 0.15832045336613065]
# PARENT INDEX: 5432, MODE: Branch Extension
# PARENT INDEX: 5128, MODE: Best Neighbor
# STATE 0: [20.69161370942652, -139.51154683462616, 8.621937252140464, 0.00838583166818685, 3.265506839064136, 0.08219626701401661]
# PARENT INDEX: 4454, MODE: Branch Extension
# STATE 0: [12.04168798687844, -249.3304532355018, 12.295513034562473, 0.5430422271820476, 1.0361338411990937, 0.6666463536711937]
# PARENT INDEX: 6834, MODE: Branch Extension
# PARENT INDEX: 3858, MODE: Best Neighbor
# PARENT INDEX: 2378, MODE: Best Neighbor
# STATE 0: [137.74818980384393, -37.90440512344241, 5.361012977804631, -0.5875237102881359, 1.4356111408977397, -0.16988532767411857]
# PARENT INDEX: 1439, MODE: Branch Extension
# PARENT INDEX: 2965, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [205.1838394882805, -98.33235607410218, 8.675736255380903, 0.9127451879283086, 2.9510586076787586, 0.8066832925092338]
# PARENT INDEX: 6008, MODE: Branch Extension
# PARENT INDEX: 1001, MODE: Best Neighbor
# PARENT INDEX: 1942, MODE: Best Neighbor
# STATE 0: [284.0338385072701, -146.15844103258055, 7.946929402888217, -0.11993943153836428, 0.9413990948879368, 0.03484057449378741]
# PARENT INDEX: 6875, MODE: Branch Extension
# STATE 0: [289.78869438949005, -287.70173427372123, 12.852617959176403, 1.0100547901503443, 5.876502566690923, 0.9830039941447404]
# PARENT INDEX: 4046, MODE: Branch Extension
# PARENT INDEX: 1532, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# PARENT INDEX: 1053, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# PARENT INDEX: 4845, MODE: Best Neighbor
# STATE 0: [130.048802632828, -159.26726809987227, 4.3459534421717, 0.5118405052410762, 1.7019577320796824, 0.6291747024691017]
# PARENT INDEX: 3670, MODE: Branch Extension
# PARENT INDEX: 760, MODE: Best Neighbor
# PARENT INDEX: 548, MODE: Best Neighbor
# PARENT INDEX: 4666, MODE: Best Neighbor
# PARENT INDEX: 1831, MODE: Best Neighbor
# STATE 0: [127.48724807176445, -238.50942396172593, 9.050623662436614, 0.8461341123654653, 5.325739029312433, 0.9704180017946822]
# PARENT INDEX: 6331, MODE: Branch Extension
# PARENT INDEX: 4085, MODE: Best Neighbor
# STATE 0: [307.1825433740917, -149.22488894057383, 6.053201826549667, -0.1051575426375756, 1.8572524114384974, 0.6765031104910404]
# PARENT INDEX: 3467, MODE: Branch Extension
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [237.07423283160827, -66.94966679660396, 8.014381691616336, -0.4313784083341553, 6.0616271146356215, 0.7745620164682514]
# PARENT INDEX: 5444, MODE: Branch Extension
# STATE 0: [8.450794016440467, -164.40439377814982, 11.992771323688261, 0.08079744296022362, 4.627921592035151, -0.5009206111210571]
# PARENT INDEX: 6379, MODE: Branch Extension
# PARENT INDEX: 5322, MODE: Best Neighbor
# STATE 0: [237.43329958805975, -265.7885239988983, 15.558258180662543, 1.0071464989460648, 5.30789764625899, -0.02344278492284846]
# PARENT INDEX: 6835, MODE: Branch Extension
# STATE 0: [216.56092617312618, -58.245988038542315, 3.9757552453643252, 0.5205577912431489, 3.013488962828735, 0.8417707083606554]
# PARENT INDEX: 6094, MODE: Branch Extension
# STATE 0: [114.6588234060646, -270.6665447132661, 9.380743728273439, -0.5634086924963702, 2.874277960336993, -0.6744639737702867]
# PARENT INDEX: 6648, MODE: Branch Extension
# PARENT INDEX: 3544, MODE: Best Neighbor
# STATE 0: [9.74488028836169, -109.67631042861441, 7.461612325920336, -0.48266314235684105, 2.9876752804016684, -0.7657507523535674]
# PARENT INDEX: 5423, MODE: Branch Extension
# PARENT INDEX: 5712, MODE: Best Neighbor
# STATE 0: [281.64653568650886, -294.5018959297056, 11.758136014430498, 0.3282752009826473, 0.9070333452307318, 0.024991036363832375]
# PARENT INDEX: 5645, MODE: Branch Extension
# PARENT INDEX: 6025, MODE: Best Neighbor
# PARENT INDEX: 6043, MODE: Best Neighbor
# STATE 0: [257.9067855220049, -135.2484146600598, 8.273627918723633, -0.4306533363610676, 3.7668890800372465, -0.9385283118679406]
# PARENT INDEX: 5829, MODE: Branch Extension
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [228.73679048008407, -246.19467587312894, 5.684859354750429, 0.8051274534517854, 6.258938395139307, -0.07549540759190321]
# PARENT INDEX: 5825, MODE: Branch Extension
# STATE 0: [105.03880819591373, -29.165255737212288, 7.649170487900365, 0.5398962782307948, 3.9388577987638995, 0.43747400203432396]
# PARENT INDEX: 4882, MODE: Branch Extension
# PARENT INDEX: 3250, MODE: Best Neighbor
# STATE 0: [220.63074729854122, -221.20355726106035, 3.674108815798334, -0.4800569086974552, 5.420377243501013, 0.17469128647102705]
# PARENT INDEX: 5799, MODE: Branch Extension
# PARENT INDEX: 3817, MODE: Best Neighbor
# STATE 0: [93.6753336385651, -100.66629342791329, 6.793757657546992, 0.7728979625458978, 3.0089134873967454, 0.7595283445279626]
# PARENT INDEX: 1202, MODE: Branch Extension
# PARENT INDEX: 6640, MODE: Best Neighbor
# STATE 0: [269.8621384944841, -301.9826300403643, 7.345689115492316, -0.9717549222210238, 3.545467859432804, 0.24525431486087124]
# PARENT INDEX: 6880, MODE: Branch Extension
# PARENT INDEX: 2239, MODE: Best Neighbor
# PARENT INDEX: 768, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [158.73373330210498, -121.27998058020992, 12.005123614337249, -0.5331750772200439, 3.528533856613887, -0.7022581480550938]
# PARENT INDEX: 4405, MODE: Branch Extension
# STATE 0: [246.8337115363073, -253.04378757203986, 7.781529238332526, 0.2576171933171354, 1.2333654679587127, -0.9145931184208669]
# PARENT INDEX: 3981, MODE: Branch Extension
# STATE 0: [100.76443566451998, -206.9071617780455, 11.359094948038527, 0.5701728605111382, 6.149129906687841, 0.4194634077998809]
# PARENT INDEX: 5224, MODE: Branch Extension
# STATE 0: [192.2564056930764, -211.03450588672672, 6.8399076308441735, 0.07809561738857895, 1.323095560609423, -0.9451690491379716]
# PARENT INDEX: 3773, MODE: Branch Extension
# PARENT INDEX: 2256, MODE: Best Neighbor
# PARENT INDEX: 4163, MODE: Best Neighbor
# STATE 0: [197.1391025216157, -116.4184613008154, 8.560761922512034, 0.049850815406713433, 1.3354418664886571, 0.8794572693738822]
# PARENT INDEX: 4268, MODE: Branch Extension
# PARENT INDEX: 1480, MODE: Best Neighbor
# PARENT INDEX: 1247, MODE: Best Neighbor
# STATE 0: [93.94625471092706, -21.751416960033453, 10.332609629128298, -0.47543937574301254, 1.3065800831092351, -0.865164925147059]
# PARENT INDEX: 4956, MODE: Branch Extension
# STATE 0: [145.0692851093307, -5.084173665573266, 6.798951423599335, 0.35861470542068363, 0.8464326629810335, -0.02865869424205747]
# PARENT INDEX: 6637, MODE: Branch Extension
# PARENT INDEX: 5613, MODE: Best Neighbor
# PARENT INDEX: 4216, MODE: Best Neighbor
# PARENT INDEX: 1648, MODE: Best Neighbor
# PARENT INDEX: 2570, MODE: Best Neighbor
# PARENT INDEX: 1957, MODE: Best Neighbor
# PARENT INDEX: 3900, MODE: Best Neighbor
# PARENT INDEX: 4473, MODE: Best Neighbor
# STATE 0: [304.0064170941234, -172.0702648872532, 15.92027290986094, 1.0315696513582957, 3.2291071101632687, -0.7155223057719762]
# PARENT INDEX: 6578, MODE: Branch Extension
# PARENT INDEX: 3952, MODE: Best Neighbor
# STATE 0: [161.19032436487225, -131.56711908907022, 14.946912263441085, -0.592329138982091, 6.042119335635839, -0.18055781208208876]
# PARENT INDEX: 5840, MODE: Branch Extension
# PARENT INDEX: 37, MODE: Best Neighbor
# STATE 0: [94.99433528986728, -145.68469624371238, 13.930997501716343, 0.5227591093111381, 1.2163769468731993, 0.3493849011238339]
# PARENT INDEX: 4406, MODE: Branch Extension
# PARENT INDEX: 722, MODE: Best Neighbor
# PARENT INDEX: 2151, MODE: Best Neighbor
# PARENT INDEX: 4501, MODE: Best Neighbor
# STATE 0: [57.07984237929191, -126.35122184656373, 10.834587297846397, 0.5379927998214322, 5.175962391722771, 0.8405317415723048]
# PARENT INDEX: 4408, MODE: Branch Extension
# STATE 0: [52.04265486876189, -238.5205622820049, 9.641833916861474, 0.7714951356727124, 1.7620414852462076, -0.2320928577291379]
# PARENT INDEX: 5510, MODE: Branch Extension
# PARENT INDEX: 3580, MODE: Best Neighbor
# STATE 0: [172.98432914919894, -108.43060896258272, 8.27009309394545, 0.5073158529487096, 5.68583608065275, -0.31456913792836616]
# PARENT INDEX: 6440, MODE: Branch Extension
# PARENT INDEX: 6733, MODE: Best Neighbor
# STATE 0: [112.1737146325078, -312.32442735792836, 8.374190297963615, -0.811441825008266, 6.098401750792765, 0.7675604838901555]
# PARENT INDEX: 6178, MODE: Branch Extension
# STATE 0: [140.40759945168946, -134.18893919945447, 9.498057267647152, 0.7183597851269232, 2.1047634083242444, 0.11136029670638958]
# PARENT INDEX: 5802, MODE: Branch Extension
# PARENT INDEX: 2662, MODE: Best Neighbor
# STATE 0: [305.9763674072266, -270.6165278920757, 12.914293166601416, -0.009090121189311517, 5.701134153602593, 0.046900524215651274]
# PARENT INDEX: 3745, MODE: Branch Extension
# PARENT INDEX: 2026, MODE: Best Neighbor
# PARENT INDEX: 5938, MODE: Best Neighbor
# PARENT INDEX: 2785, MODE: Best Neighbor
# PARENT INDEX: 532, MODE: Best Neighbor
# PARENT INDEX: 5863, MODE: Best Neighbor
# STATE 0: [272.04693583113993, -23.269323794395007, 9.007094475599047, 0.11606448626098231, 3.125933495998161, 0.3764219908374329]
# PARENT INDEX: 6984, MODE: Branch Extension
# PARENT INDEX: 4525, MODE: Best Neighbor
# PARENT INDEX: 3056, MODE: Best Neighbor
# PARENT INDEX: 5936, MODE: Best Neighbor
# STATE 0: [130.67305773488502, -188.66126800515323, 6.786104520106094, 0.45312765471679217, 2.2859021936161015, -0.8934963388081738]
# PARENT INDEX: 2863, MODE: Branch Extension
# PARENT INDEX: 2558, MODE: Best Neighbor
# PARENT INDEX: 4125, MODE: Best Neighbor
# PARENT INDEX: 5579, MODE: Best Neighbor
# PARENT INDEX: 2283, MODE: Best Neighbor
# PARENT INDEX: 3309, MODE: Best Neighbor
# STATE 0: [240.45573150453723, -268.12045078973597, 14.579863756920824, -0.5388267828406524, 5.520708951708631, 0.8399799171849185]
# PARENT INDEX: 6098, MODE: Branch Extension
# PARENT INDEX: 1274, MODE: Best Neighbor
# PARENT INDEX: 856, MODE: Best Neighbor
# PARENT INDEX: 1009, MODE: Best Neighbor
# PARENT INDEX: 4700, MODE: Best Neighbor
# STATE 0: [189.22553597227332, -87.83786067830516, 8.855604112861533, 0.8675748065783007, 0.839300473445354, -0.36901976712168216]
# PARENT INDEX: 458, MODE: Branch Extension
# STATE 0: [4.685025455824393, -49.8241714912338, 9.64377490347635, 1.036713701685202, 3.4409419344689685, 0.5510678403896805]
# PARENT INDEX: 6671, MODE: Branch Extension
# PARENT INDEX: 722, MODE: Best Neighbor
# PARENT INDEX: 1487, MODE: Best Neighbor
# STATE 0: [181.89871156996986, -71.36500944537605, 16.912074549103966, -0.3140417813005627, 3.6485708193881456, -0.8065532519375123]
# PARENT INDEX: 3401, MODE: Branch Extension
# PARENT INDEX: 5291, MODE: Best Neighbor
# PARENT INDEX: 1922, MODE: Best Neighbor
# PARENT INDEX: 5535, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [71.36562355612458, -86.68158511263978, 7.065690802978038, -0.2669648754399765, 1.4875046924573017, -0.5330316956383161]
# PARENT INDEX: 6644, MODE: Branch Extension
# STATE 0: [140.02738454456954, -21.644931935907827, 6.949528802549588, 0.3451452145016787, 3.942943038643343, 0.4915802430505627]
# PARENT INDEX: 4354, MODE: Branch Extension
# STATE 0: [118.29135478152484, -290.41489829263844, 15.266745938655722, -0.3715985074929059, 0.14058293660472695, -0.16408596216383353]
# PARENT INDEX: 6402, MODE: Branch Extension
# PARENT INDEX: 4295, MODE: Best Neighbor
# PARENT INDEX: 2153, MODE: Best Neighbor
# PARENT INDEX: 2514, MODE: Best Neighbor
# STATE 0: [33.39288826707499, -232.33480196973315, 9.345313151699955, 0.47213972713856256, 1.0517781884740893, 0.7243751518328398]
# PARENT INDEX: 5684, MODE: Branch Extension
# STATE 0: [122.05617525056113, -221.32449872033663, 4.939779393828365, -0.4742285753046379, 4.894753645144888, 0.06461429275727748]
# PARENT INDEX: 5056, MODE: Branch Extension
# STATE 0: [4.375689190042299, -255.7275950580623, 7.175202446362959, 0.08501179537904302, 4.394555447501933, -0.9176371090198052]
# PARENT INDEX: 6283, MODE: Branch Extension
# STATE 0: [70.5858192890727, -48.98911930970514, 13.988771857933088, -0.11387787692610896, 5.915011340302189, -0.47967958581240033]
# PARENT INDEX: 3425, MODE: Branch Extension
# PARENT INDEX: 5036, MODE: Best Neighbor
# STATE 0: [259.6793894241225, -282.8647896828444, 2.8748975184618386, -0.23078681830510817, 3.029815888596946, -0.5284933857334857]
# PARENT INDEX: 6850, MODE: Branch Extension
# PARENT INDEX: 6535, MODE: Best Neighbor
# PARENT INDEX: 1431, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [13.0233551096239, -158.44723371988985, 8.920730228721979, 0.3192636275909624, 5.529607898909859, -0.4395641425551775]
# PARENT INDEX: 4623, MODE: Branch Extension
# STATE 0: [49.04694429499378, -68.06124067185476, 7.792773167143916, 0.9994735599929296, 5.5856807025910244, -0.6179226535377624]
# PARENT INDEX: 6942, MODE: Branch Extension
# PARENT INDEX: 2316, MODE: Best Neighbor
# PARENT INDEX: 986, MODE: Best Neighbor
# STATE 0: [297.688531046237, -99.14775060405515, 12.532890744091441, -0.9959983821052757, 3.116924408711333, 0.4529090292638338]
# PARENT INDEX: 6420, MODE: Branch Extension
# PARENT INDEX: 2302, MODE: Best Neighbor
# PARENT INDEX: 722, MODE: Best Neighbor
# STATE 0: [248.65680626896904, -4.398203700281897, 11.229998517350108, -0.4265297423859914, 5.205300165052559, -0.427953787359064]
# PARENT INDEX: 6234, MODE: Branch Extension
# PARENT INDEX: 722, MODE: Best Neighbor
# PARENT INDEX: 3998, MODE: Best Neighbor
# STATE 0: [103.35955753100158, -170.37321885779787, 8.744225497438205, 0.6011199169551056, 3.667053331742875, 0.8462088185380905]
# PARENT INDEX: 5654, MODE: Branch Extension
# PARENT INDEX: 59, MODE: Best Neighbor
# PARENT INDEX: 649, MODE: Best Neighbor
# STATE 0: [202.45223873745132, -134.27355015546797, 7.967684710537643, -0.390505539838777, 4.070291124093184, 0.31477227358949067]
# PARENT INDEX: 6745, MODE: Branch Extension
# PARENT INDEX: 2632, MODE: Best Neighbor
# PARENT INDEX: 5218, MODE: Best Neighbor
# PARENT INDEX: 2433, MODE: Best Neighbor
# STATE 0: [251.91163183681365, -295.6236615572021, 6.978053416492256, 0.9822318855530108, 2.326818872299209, 0.6726140770806561]
# PARENT INDEX: 3689, MODE: Branch Extension
# PARENT INDEX: 2735, MODE: Best Neighbor
# PARENT INDEX: 5497, MODE: Best Neighbor
# PARENT INDEX: 981, MODE: Best Neighbor
# PARENT INDEX: 6392, MODE: Best Neighbor
# STATE 0: [216.56092617312618, -58.245988038542315, 3.9757552453643252, 0.5205577912431489, 3.013488962828735, 0.8417707083606554]
# PARENT INDEX: 6094, MODE: Branch Extension
# STATE 0: [94.1897370614777, -38.30778150961082, 6.890765648301632, -0.9691984945980885, 6.207447964240547, -0.8850019233373476]
# PARENT INDEX: 640, MODE: Branch Extension
