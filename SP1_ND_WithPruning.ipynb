# %%
import trimesh
from trimesh import viewer
from trimesh.viewer import windowed
from trimesh import creation, transformations
import numpy as np
import math
import sys
from scipy.spatial.transform import Rotation as R
import random

# %%
#Set up all parameters to be used in the planner here
pi = math.pi
yaw_rate_bounds = [-pi/6, pi/6]
pitch_rate_bounds = [-pi/6, pi/6]
lin_acc_rate_bounds = [-0.5, 0.5]

pitch_bounds = [-pi/3,pi/3]
velocity_bounds = [-1,1]
delta_s = 2
delta_bn = 3
T_prop = 2
probability_goal = 0.05
dynamic_bounds = {"PITCH":pitch_bounds,"VEL":velocity_bounds}
goal_state = [15, -300, 5, 0,0,0]
goal_radius = 2

N = 10000 #number of iterations
STATE_SPACE = {"X":None,"Y":None,"Z":None,"PITCH":None,"YAW":None,"VEL":None}
U = {"PITCH_RATE":yaw_rate_bounds,"YAW_RATE":pitch_rate_bounds,"LIN_ACC":lin_acc_rate_bounds}

# %%
#### LOAD IN STL MODELS ####
#########print("Loading environment stl...")
envMesh = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/FlatSlopes_WithTrees.stl",process=False)
envMesh = trimesh.Trimesh(envMesh.vertices,envMesh.faces,envMesh.face_normals,envMesh.vertex_normals)
#####print("Done.")

# %%
print("Loading drone stl...")
droneSTL = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/DroneGeneral_Smaller.stl")
droneSTL = trimesh.Trimesh(droneSTL.vertices,droneSTL.faces,droneSTL.face_normals,droneSTL.vertex_normals)
print("Done.")
#Get max dimension of the drone
bounds = droneSTL.bounds
x_dim = bounds[1][0]-bounds[0][0]
y_dim = bounds[1][1]-bounds[0][1]
z_dim = bounds[1][2]-bounds[0][2]
droneMaxDim = math.sqrt(x_dim**2+y_dim**2+z_dim**2)
print("Drone Max Dimension: " + str(droneMaxDim))
# Out:
# Loading drone stl...
# Done.
# Drone Max Dimension: 0.4856526011604424

# %%
print("Loading bounding mesh stl...")
boundingMesh = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/FlatSlopes_BoundingVolume.stl")
boundingMesh = trimesh.Trimesh(boundingMesh.vertices,boundingMesh.faces,boundingMesh.face_normals,boundingMesh.vertex_normals)
print("Done.")
# Out:
# Loading bounding mesh stl...
# Done.

# %%
print("Loading drone obj...")
droneMesh = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/DroneGeneral_Smaller.obj")
#droneMesh = trimesh.Trimesh(droneMesh.vertices,droneMesh.faces,droneMesh.face_normals,droneMesh.vertex_normals)
print("Done.")
# Out:
# Loading drone obj...
# Done.

# %%
print("Loading drone stl...")
droneSTL = trimesh.load_mesh("C:/Users/mcgra/source/repos/AMP_FinalProject_Python/AMP_FinalProject_Python/DroneGeneral_Smaller.stl")
droneSTL = trimesh.Trimesh(droneSTL.vertices,droneSTL.faces,droneSTL.face_normals,droneSTL.vertex_normals)
print("Done.")
#Get max dimension of the drone
bounds = droneSTL.bounds
x_dim = bounds[1][0]-bounds[0][0]
y_dim = bounds[1][1]-bounds[0][1]
z_dim = bounds[1][2]-bounds[0][2]
droneMaxDim = math.sqrt(x_dim**2+y_dim**2+z_dim**2)
print("Drone Max Dimension: " + str(droneMaxDim))
# Out:
# Loading drone stl...
# Done.
# Drone Max Dimension: 0.4856526011604424

# %%
def Runge_Kutta_Integration_fourth_order(T_sampled,input_array,dynamic_bounds):
    None

def Get3Ddist(xyz1,xyz2):
    dist = math.sqrt((xyz1[0]-xyz2[0])**2 + (xyz1[1]-xyz2[1])**2 + (xyz1[1]-xyz2[1])**2)
    # print("DIST: " + str(dist))
    return dist


def CreateRotationMatrix(alpha = 0, beta = 0, gamma = 0):
    #NO INPUTS CREATES IDENTITY MATRIX
    r_x = transformations.rotation_matrix(alpha,[1,0,0])
    r_y = transformations.rotation_matrix(beta,[0,1,0])
    r_z = transformations.rotation_matrix(gamma,[0,0,1])
    R = np.matmul(np.matmul(r_z,r_y),r_x)
    return R


def CombineRotTransMatrices(rotationMatrix,translationMatrix):
    rotMatShape = np.shape(rotationMatrix)
    tranMatShape = np.shape(translationMatrix)
    if(rotMatShape != (4,4) and rotMatShape != (3,3)):
        raise Exception("Expecting rotation matrix with shape (4, 4) or (3, 3), given matrix of shape "+str(rotMatShape))
        sys.exit()
    elif(tranMatShape != (4,4) and tranMatShape != (4,1)):
        raise Exception("Expecting translation Matrix matrix with shape (4, 4) or (4, 1), given matrix of shape "+str(tranMatShape))
        sys.exit()

        
    tranMat = translationMatrix[0:3,3]
    combinedMatrix = np.zeros([4,4])

    if(rotMatShape != (3,3)):
        rotMat = rotationMatrix[0:3,0:3]
        rotMatTrans = rotationMatrix[0:3,3]
        combinedMatrix[0:3,3] = tranMat + rotMatTrans
    else:
        rotMat = rotationMatrix
        combinedMatrix[0:3,3] = tranMat

    combinedMatrix[0:3,0:3] = rotMat
    combinedMatrix[3,:] = np.array([0,0,0,1])
    return combinedMatrix

def CheckForDroneCollision(collision_manager_with_env = trimesh.collision.CollisionManager().__init__,drone_mesh=None,transform=None):
    collision_manager_with_env.add_object("Drone",drone_mesh,transform=transform)
    isCollision = collision_manager_with_env.in_collision_internal()
    collision_manager_with_env.remove_object("Drone")
    return isCollision

def CalculateFinalTransform(TransformationList):
    #Transformation list is a list of transformations from 1st to last
    #THIS WONT WORK -  NEED TO FIGURE OUT

    prevTransform = np.zeros([4,4])
    for i in range(len(TransformationList),0,-1):
        if(i == 0):
            break
        else:
            if(i == len(TransformationList)):
                prevTransform = np.matmul(TransformationList[i],TransformationList[i-1])
            else:
                prevTransform = np.matmul(prevTransform,TransformationList[i-1])

    return prevTransform ####XXXXXX

# %%
class MeshObject:
    def __init__(self,mesh,name):
        self.name = name
        self.mesh = mesh

        self.scene = trimesh.Scene()
        self.scene.add_geometry(mesh)
        self.centroid = self.scene.centroid
        self.X = self.centroid[0]
        self.Y = self.centroid[1]
        self.Z = self.centroid[2]
        self.alpha = 0 #rotation about X, roll
        self.beta = 0  #rotation about Y, pitch
        self.gamma = 0 #rotation about Z, yaw
        self.velocity = 0
        self.ROTATION_MATRIX = np.array([[1,0,0],[0,1,0],[0,0,1]])
        self.TRANSLATION_MATRIX = np.array([self.X,self.Y,self.Z])
    
    def GetEulerAnglesFromMatrix(self):
        r = R.from_matrix(self.ROTATION_MATRIX)
        xyz = r.as_euler('xyz',degrees=False)
        self.alpha = xyz[0]
        self.beta = xyz[1]
        self.gamma = xyz[2]

    def RotateMesh(self,rot_mat):
        self.ROTATION_MATRIX = np.matmul(self.ROTATION_MATRIX,rot_mat)
        self.GetEulerAnglesFromMatrix()

    def TranslateMesh(self,transl_mat):
        self.TRANSLATION_MATRIX = np.add(self.TRANSLATION_MATRIX,transl_mat)
        self.X = self.TRANSLATION_MATRIX[0]
        self.Y = self.TRANSLATION_MATRIX[1]
        self.Z = self.TRANSLATION_MATRIX[2]
        
    def GetMeshCentroid(self,mesh):
        scene = trimesh.Scene()
        scene.add_geometry(self.mesh)
        centroid = scene.centroid
        return centroid

    def CalculateTrajectory():
        None

# %%
class Vertice:
    def __init__(self,state,cost):
        self.state=state
        self.cost = cost
        self.Parent = None
        self.Children = []

    def AddParent(self,parent):
        self.Parent = parent
    def AddChild(self,child):
        self.Children.append(child)

# %%
class PlanningAlgorithms:
    def __init__(self):
        None

    class SST: #We will be using the drone model from the exam
        def __init__(self,start_state=None,goal_state=None,u_bounds_list=None,StateSpace=None):
            self.start_state = start_state
            self.goal_state = goal_state
            self.Witness_Regions = self.WitnessRegions()
            self.Active_Set = self.ActiveSet()
            self.Inactive_Set = self.InactiveSet()
            #self.Active_Set.Has_Witness = False
            self.StateSpace = StateSpace
            None
        def SST(X,U,x_0,T_prop,N,delta_BestNeighbor,delta_s):
            None

        def Is_Node_Locally_Best_SST(X_new,S,delta_s):
            None
        def Prune_Dominated_Nodes_SST(X_new,V_active,V_inactive,E):
            None
        def Best_First_Selection_SST(X,V,delta_BestNeighbor):
            x_rand = StateValidation.StateSample(boundingMesh,pitch_bounds=pitch_bounds,velocity_bounds=velocity_bounds)
            x_nearList = [(Get3Ddist(V[i][0:3],x_rand[0:3]),i) for i in range(0,len(V)) if Get3Ddist(V[i][0:3],x_rand[0:3]) < delta_BestNeighbor]
            x_near = [V[i] for i in range(0,len(V)) if Get3Ddist(V[i][0:3],x_rand[0:3]) < delta_BestNeighbor]
            if(len(x_near) == 0): #no neighbors within delta_BestNeighbor
                None

        def MonteCarlo_Prop(x_selected,U,T_prop):
            #x_selected is chosen neighbor, U is input bounds dict, T is max propagation time
            numInputs = len(U)
            random_inputs = np.empty([1,numInputs])
            for input in range(0,numInputs):
                inputBounds = input.value #get bounds of input from dictionary
                inputSample = random.uniform(inputBounds[0],inputBounds[1])
                random_inputs[0][input] = random.uniform(U[input][0],U[input][1])
            t = random.uniform(0,T_prop)

        def Randomized_Inputs(u_bounds_list):
            random_inputs = np.empty([1,len(u_bounds_list)])
            numInputs = len(u_bounds_list)
            
            for i in range(0,numInputs):
                random_inputs[0][i] = random.uniform(u_bounds_list[i][0],u_bounds_list[i][1])
            return random_inputs

        class ActiveSet:
            def __init__(self):
                self.States = []
                self.States.append(self.start_state)
                None
        class InactiveSet:
            def __init__(self):
                None
        class WitnessRegions:
            def __init__(self,x_0,d_s,cost):
                self.Regions = []
                self.regionID = 0
                region = self.Region(x_0,d_s,cost,self.regionID)
                self.Regions.append(region)
                
            def AddNewRegion(self,rep,d_s,cost,regionID):
                region = self.Region(rep,d_s,cost,regionID)
                self.Regions.append(region)
                self.regionID = self.regionID + 1

            class Region:
                def __init__(self,rep,d_s,cost,regionID):
                    self.representative = rep #current state that represents the region
                    x = rep.state[0]
                    y = rep.state[1]
                    z = rep.state[2]
                    self.cost = cost
                    regionSphere = trimesh.creation.icosphere(3,d_s)
                    regionSphere.apply_translation([x,y,z])
                    self.regionMesh = regionSphere
                    self.regionID = regionID
                    
                def ChangeRepresentative(self,x,cost):
                    self.representative = x
                    self.cost = cost

# %%
droneMeshOBJ = MeshObject(droneMesh,"DRONE")
x_0 = [droneMeshOBJ.X,droneMeshOBJ.Y,droneMeshOBJ.Z,droneMeshOBJ.beta,droneMeshOBJ.gamma,droneMeshOBJ.velocity]
envMeshOBJ = MeshObject(envMesh,"ENV")
boundaryMeshOBJ = MeshObject(boundingMesh,"BOUNDARY")

# %%
class Vertice:
    def __init__(self,state,cost):
        self.state=state
        self.cost = cost
        self.Parent = None
        self.Children = []

    def AddParent(self,parent):
        self.Parent = parent
    def AddChild(self,child):
        self.Children.append(child)

# %%
#CREATE THE COLLISION MANAGER WITH OUR ENVIRONMENT
print("Creating collision manager with environment...")
ENV_COLIS_MNGR = trimesh.collision.CollisionManager()
ENV_COLIS_MNGR.add_object("ENV",envMesh)
print("Done.")
# Out:
# Creating collision manager with environment...
# Done.

# %%
E = [] #trajectory list
V_active = [] #active state list
initialState = Vertice(x_0,0)
V_active.append(initialState)
V_inactive = [] #inactive state list
V = V_active+V_inactive #active and inactive states
G = [V,E]
S = PlanningAlgorithms.SST.WitnessRegions(initialState,delta_s,0)
print(V[0].state[0:3])
# Out:
# [300.0, -15.000001000000001, 5.0001225]

# %%
class StateSampler:
    def __init__(self,boundingMesh):
        self.boundingMesh = boundingMesh

    def StateSample(self,x_bounds=None,y_bounds=None,z_bounds=None,pitch_bounds=None,beta_bounds=None,yaw_bounds=None,velocity_bounds=None):
            if(self.boundingMesh is not None):
                boundingMesh = self.boundingMesh
                sample = None
                while(sample is None or len(sample) == 0):
                    sample = trimesh.sample.volume_mesh(boundingMesh,1)
                x = sample[0][0]
                y = sample[0][1]
                z = sample[0][2]
                #alpha = random.uniform(alpha_bounds[0],alpha_bounds[1])
                pitch = random.uniform(pitch_bounds[0],pitch_bounds[1])
                yaw = random.uniform(0,2*pi)
                velocity = random.uniform(velocity_bounds[0],velocity_bounds[1])

            else:
                x = random.uniform(x_bounds[0], x_bounds[1])
                y = random.uniform(y_bounds[0], y_bounds[1])
                z = random.uniform(z_bounds[0], z_bounds[1])
                #alpha = random.uniform(alpha_bounds[0],alpha_bounds[1])
                pitch = random.uniform(pitch_bounds[0],pitch_bounds[1])
                yaw = random.uniform(0,2*pi)
                velocity = random.uniform(velocity_bounds[0],velocity_bounds[1])

            return [x,y,z,pitch,yaw,velocity]

# %%
def ExtendBranch(state0,state1,delta_bn):
    #Get unit vector <x,y,z>
    state_diff = np.subtract(state1,state0)
    # print("STATE 0: " +str(state0))
    # print(state_diff)
    vector = state_diff[0:3]
    abs_vector = math.sqrt(vector[0]**2+vector[1]**2+vector[2]**2)
    unit_vector = vector/abs_vector
    extension = unit_vector*delta_bn
    
    new_xyz = state0[0:3]+extension
    x_new = [new_xyz[0],new_xyz[1],new_xyz[2],state1[3],state1[4],state1[5]]
    return x_new

# %%
def Best_First_Selection_SST(X,V,delta_BestNeighbor,sampler):
            prob = random.uniform(0,1)
            if(prob <= probability_goal):
                x_rand = goal_state
            else:
                x_rand = sampler.StateSample(sampler.boundingMesh,pitch_bounds=pitch_bounds,velocity_bounds=velocity_bounds)
            # print(x_rand)
            # x_nearList = [(Get3Ddist(V[i].state[0:3],x_rand[0:3]),i) for i in range(0,len(V)) if Get3Ddist(V[i].state[0:3],x_rand[0:3]) < delta_BestNeighbor]
            x_nearList = [[V[i].cost,i] for i in range(0,len(V)) if Get3Ddist(V[i].state[0:3],x_rand[0:3]) < delta_BestNeighbor]
            x_near = [[int(i),Get3Ddist(V[i].state[0:3],x_rand[0:3])] for i in range(0,len(V))]
            x_near = sorted(x_near, key = lambda x: x[1])
            # print("X_NEARLIST: "+str(x_near))
            closest = int(x_near[0][0])
            # print("CLOSEST NEIGHBOR: " x)
            # print(closest)
            if(len(x_nearList) == 0): #no neighbors within delta_BestNeighbor, use closest neighbor and extend branch by delta_BN
                x_new = ExtendBranch(V[closest].state,x_rand,delta_BestNeighbor)
                # print("X_NEW: "+str(x_new))
                mode = "Branch Extension"
                return x_new, closest, mode
            else:
                x_nearList.sort(key=lambda x: x[0])
                # print("X NEAR LIST: " +str(x_nearList))
                x_new_parent_idx = x_nearList[0][1]
                mode = "Best Neighbor"
                return x_rand, x_new_parent_idx, mode

# %%
def Is_Node_Locally_the_Best_SST(xnew, S = PlanningAlgorithms.SST.WitnessRegions.__init__, delta_s=1):
    rgnIdx = 0
    regionID = None
    for witness_region in S.Regions: #check if new or old cost is better and make that one region rep
        regionID = witness_region.regionID
        if(witness_region.regionMesh.contains(([xnew.state[0:3]]))):
            if(witness_region.cost > xnew.cost):
                # witness_region.ChangeRepresentative(xnew,xnew.cost)
                regionID = witness_region.regionID
                inOldRegion = True
                return True, regionID, inOldRegion
            else:
                return False, regionID, rgnIdx
        rgnIdx += 1
            

    #if it reaches this point, it was not in an old region, new witness region will be created
    regionID += 1
    S.AddNewRegion(xnew,delta_s,xnew.cost,regionID)
    rgnIdx += 1
    inOldRegion = False
    return True, regionID, inOldRegion

# %%
def Prune_Dominated_Nodes_SST(xnew, V_active, V_inactive, E, rgnIdx, S,isOldRegion):
    s_new = None
    idx = 0
    for i in range(0,len(S.Regions)):
        if(S.Regions[i].regionID == rgnID):
            s_new = S.Regions[i]
            break
        else:
            idx+=1
    # s_new = [S.Regions[i] for i in range(0,len(S.Regions)) if S.Regions[i].regionID == rgnID] #S.Regions[rgnIdx] #witness region on new node
    x_peer = s_new.representative
    if(isOldRegion and x_peer is not None): #move x_peer from active to inactive
        V_active.remove(x_peer)             
        V_inactive.append(x_peer)   
    S.Regions[idx].representative = xnew
    while(x_peer is not None and len(x_peer.Children)==0 and x_peer in V_inactive):
        print(x_peer)
        x_parent = x_peer.Parent
        print(x_parent)
        if([x_parent,x_peer] in E):
            E.remove([x_parent,x_peer])
        V_inactive.remove(x_peer)
        x_peer = x_parent

# %%
def In_Goal_Region(state,goal_state=goal_state,goal_radius=goal_radius):
    Goal_Sphere = trimesh.creation.icosphere(radius=goal_radius)
    Goal_Sphere = Goal_Sphere.apply_translation(goal_state[0:3])
    if(Goal_Sphere.contains([state[0:3]])):
        return True
    else:
        return False

# %%
# x,y,z = trimesh.sample.volume_mesh(boundingMesh,1)[0]
# print(x)
# print(y)
# print(z)

ss_sampler = StateSampler(boundingMesh)
x_selected, x_new_parentIdx, mode = Best_First_Selection_SST(STATE_SPACE,V_active,delta_bn,ss_sampler)
# print(x_selected)
# print(x_new_parentIdx)
# print(ss_sampler.StateSample(pitch_bounds=pitch_bounds,velocity_bounds=velocity_bounds))
scene = trimesh.Scene()
scene.add_geometry(envMesh)
for iteration in range(0,N):
    print("ACTIVE NODES: " + str(len(V_active)))
    print("INACTIVE NODES: " + str(len(V_inactive)))
    print("WITNESS REGIONS: " + str(len(S.Regions)))
    x_selected, x_new_parentIdx, mode = Best_First_Selection_SST(STATE_SPACE,V_active,delta_bn,ss_sampler)
    # print("PARENT INDEX: "+str(x_new_parentIdx)+", MODE: "+mode)
    x_selected_parent = V_active[int(x_new_parentIdx)]
    x_selected_parent_state = x_selected_parent.state
    x_new_cost = Get3Ddist(x_selected,x_selected_parent_state)+x_selected_parent.cost
    x_new = Vertice(x_selected,x_new_cost)

    #CHECK IF SELECTED STATE IS COLLISION FREE
    #USING A SPHERE TO REPRESENT THE DRONE, USING THE DRONES MAXIMUM DIMENSION  IS THE SIMPLEST OPTION,
    #AS WE CAN CREATE THE SPHERE AT THE SPECIFIED XYZ TO HAVE IT REPRESENT ALL ORIENTATIONS
    #AND INSERT IT AND REMOVE IT FROM THE COLLISION MANAGER WITHOUT HAVING TO PERFORM TRANSFORMATIONS
    droneSphere = trimesh.creation.icosphere(3,droneMaxDim,(0,0,255))
    droneSphere = droneSphere.apply_translation(x_selected[0:3])
    # print(droneSphere.centroid)
    dronePosCollision = CheckForDroneCollision(ENV_COLIS_MNGR,droneSphere)

    #Need to check for collision in trajectory, can use cylinder to represent space the drone travels through
    trajCylinder = trimesh.creation.cylinder(droneMaxDim,segment=[x_selected[0:3],x_selected_parent_state[0:3]])
    trajCylinder.visual.face_colors = [255, 0, 0, 255]
    droneTrajCollision = CheckForDroneCollision(ENV_COLIS_MNGR,trajCylinder)
    # scene = trimesh.Scene()
    # scene.add_geometry(trajCylinder)
    # scene.add_geometry(droneSphere)
    # scene.add_geometry(envMesh)
    # scene.show()

    # if(dronePosCollision==True):
    #     print("POS COLLISION")
    # if(droneTrajCollision==True):
    #     print("TRAJ COLLISION")

    #IF NO COLLISION OCCURS, WE CAN MOVE ONTO CHECKING IF VERTICE IS BEST IN WITNESS REGION
    if(droneTrajCollision == False and dronePosCollision==False):
        isNodeBest, rgnID, inOldRegion = Is_Node_Locally_the_Best_SST(x_new,S=S,delta_s=delta_s)
        if(isNodeBest):
            x_new.Parent = x_selected_parent
            # x_parent = 
            # V_active.remove(V_active[int(x_new_parentIdx)])
            V_active[int(x_new_parentIdx)].Children.append(x_new)
            # V_active.append()
            V_active.append(x_new)

            E.append([V_active[int(x_new_parentIdx)],x_new])
            Prune_Dominated_Nodes_SST(x_new,V_active, V_inactive, E, rgnID, S,inOldRegion)
            V = V_active+V_inactive
            G = (V,E)
            # scene.add_geometry(droneSphere)
            # scene.add_geometry(trajCylinder)
            # if(In_Goal_Region(x_new.state)):
            #     print("GOAL REACHED")
            #     break

        # print("NO COLLISION")
# for vertice in V_active:
#     print(vertice.state)
# Out:
# ACTIVE NODES: 1
# INACTIVE NODES: 0
# WITNESS REGIONS: 1
# ACTIVE NODES: 2
# INACTIVE NODES: 0
# WITNESS REGIONS: 2
# ACTIVE NODES: 3
# INACTIVE NODES: 0
# WITNESS REGIONS: 3
# ACTIVE NODES: 4
# INACTIVE NODES: 0
# WITNESS REGIONS: 4
# ACTIVE NODES: 5
# INACTIVE NODES: 0
# WITNESS REGIONS: 5
# ACTIVE NODES: 6
# INACTIVE NODES: 0
# WITNESS REGIONS: 6
# ACTIVE NODES: 7
# INACTIVE NODES: 0
# WITNESS REGIONS: 7
# ACTIVE NODES: 8
# INACTIVE NODES: 0
# WITNESS REGIONS: 8
# ACTIVE NODES: 9
# INACTIVE NODES: 0
# WITNESS REGIONS: 9
# ACTIVE NODES: 10
# INACTIVE NODES: 0
# WITNESS REGIONS: 10
# ACTIVE NODES: 11
# INACTIVE NODES: 0
# WITNESS REGIONS: 11
# ACTIVE NODES: 12
# INACTIVE NODES: 0
# WITNESS REGIONS: 12
# ACTIVE NODES: 13
# INACTIVE NODES: 0
# WITNESS REGIONS: 13
# ACTIVE NODES: 14
# INACTIVE NODES: 0
# WITNESS REGIONS: 14
# ACTIVE NODES: 14
# INACTIVE NODES: 0
# WITNESS REGIONS: 14
# ACTIVE NODES: 14
# INACTIVE NODES: 0
# WITNESS REGIONS: 14
# ACTIVE NODES: 15
# INACTIVE NODES: 0
# WITNESS REGIONS: 15
# ACTIVE NODES: 16
# INACTIVE NODES: 0
# WITNESS REGIONS: 16
# ACTIVE NODES: 17
# INACTIVE NODES: 0
# WITNESS REGIONS: 17
# ACTIVE NODES: 18
# INACTIVE NODES: 0
# WITNESS REGIONS: 18
# ACTIVE NODES: 18
# INACTIVE NODES: 0
# WITNESS REGIONS: 18
# ACTIVE NODES: 19
# INACTIVE NODES: 0
# WITNESS REGIONS: 19
# ACTIVE NODES: 20
# INACTIVE NODES: 0
# WITNESS REGIONS: 20
# ACTIVE NODES: 21
# INACTIVE NODES: 0
# WITNESS REGIONS: 21
# ACTIVE NODES: 21
# INACTIVE NODES: 0
# WITNESS REGIONS: 21
# ACTIVE NODES: 21
# INACTIVE NODES: 0
# WITNESS REGIONS: 21
# ACTIVE NODES: 22
# INACTIVE NODES: 0
# WITNESS REGIONS: 22
# ACTIVE NODES: 22
# INACTIVE NODES: 0
# WITNESS REGIONS: 22
# ACTIVE NODES: 23
# INACTIVE NODES: 0
# WITNESS REGIONS: 23
# ACTIVE NODES: 24
# INACTIVE NODES: 0
# WITNESS REGIONS: 24
# ACTIVE NODES: 25
# INACTIVE NODES: 0
# WITNESS REGIONS: 25
# ACTIVE NODES: 26
# INACTIVE NODES: 0
# WITNESS REGIONS: 26
# ACTIVE NODES: 27
# INACTIVE NODES: 0
# WITNESS REGIONS: 27
# ACTIVE NODES: 28
# INACTIVE NODES: 0
# WITNESS REGIONS: 28
# ACTIVE NODES: 29
# INACTIVE NODES: 0
# WITNESS REGIONS: 29
# ACTIVE NODES: 30
# INACTIVE NODES: 0
# WITNESS REGIONS: 30
# ACTIVE NODES: 30
# INACTIVE NODES: 0
# WITNESS REGIONS: 30
# ACTIVE NODES: 31
# INACTIVE NODES: 0
# WITNESS REGIONS: 31
# ACTIVE NODES: 32
# INACTIVE NODES: 0
# WITNESS REGIONS: 32
# ACTIVE NODES: 33
# INACTIVE NODES: 0
# WITNESS REGIONS: 33
# ACTIVE NODES: 34
# INACTIVE NODES: 0
# WITNESS REGIONS: 34
# ACTIVE NODES: 35
# INACTIVE NODES: 0
# WITNESS REGIONS: 35
# ACTIVE NODES: 35
# INACTIVE NODES: 0
# WITNESS REGIONS: 35
# ACTIVE NODES: 35
# INACTIVE NODES: 0
# WITNESS REGIONS: 35
# ACTIVE NODES: 36
# INACTIVE NODES: 0
# WITNESS REGIONS: 36
# ACTIVE NODES: 37
# INACTIVE NODES: 0
# WITNESS REGIONS: 37
# ACTIVE NODES: 37
# INACTIVE NODES: 0
# WITNESS REGIONS: 37
# ACTIVE NODES: 37
# INACTIVE NODES: 0
# WITNESS REGIONS: 37
# ACTIVE NODES: 37
# INACTIVE NODES: 0
# WITNESS REGIONS: 37
# ACTIVE NODES: 38
# INACTIVE NODES: 0
# WITNESS REGIONS: 38
# ACTIVE NODES: 38
# INACTIVE NODES: 0
# WITNESS REGIONS: 38
# ACTIVE NODES: 38
# INACTIVE NODES: 0
# WITNESS REGIONS: 38
# ACTIVE NODES: 39
# INACTIVE NODES: 0
# WITNESS REGIONS: 39
# ACTIVE NODES: 40
# INACTIVE NODES: 0
# WITNESS REGIONS: 40
# ACTIVE NODES: 41
# INACTIVE NODES: 0
# WITNESS REGIONS: 41
# ACTIVE NODES: 42
# INACTIVE NODES: 0
# WITNESS REGIONS: 42
# ACTIVE NODES: 42
# INACTIVE NODES: 0
# WITNESS REGIONS: 42
# ACTIVE NODES: 43
# INACTIVE NODES: 0
# WITNESS REGIONS: 43
# ACTIVE NODES: 44
# INACTIVE NODES: 0
# WITNESS REGIONS: 44
# ACTIVE NODES: 45
# INACTIVE NODES: 0
# WITNESS REGIONS: 45
# ACTIVE NODES: 45
# INACTIVE NODES: 0
# WITNESS REGIONS: 45
# ACTIVE NODES: 46
# INACTIVE NODES: 0
# WITNESS REGIONS: 46
# ACTIVE NODES: 47
# INACTIVE NODES: 0
# WITNESS REGIONS: 47
# ACTIVE NODES: 48
# INACTIVE NODES: 0
# WITNESS REGIONS: 48
# ACTIVE NODES: 48
# INACTIVE NODES: 0
# WITNESS REGIONS: 48
# ACTIVE NODES: 49
# INACTIVE NODES: 0
# WITNESS REGIONS: 49
# ACTIVE NODES: 49
# INACTIVE NODES: 0
# WITNESS REGIONS: 49
# ACTIVE NODES: 50
# INACTIVE NODES: 0
# WITNESS REGIONS: 50
# ACTIVE NODES: 51
# INACTIVE NODES: 0
# WITNESS REGIONS: 51
# ACTIVE NODES: 52
# INACTIVE NODES: 0
# WITNESS REGIONS: 52
# ACTIVE NODES: 53
# INACTIVE NODES: 0
# WITNESS REGIONS: 53
# ACTIVE NODES: 53
# INACTIVE NODES: 0
# WITNESS REGIONS: 53
# ACTIVE NODES: 54
# INACTIVE NODES: 0
# WITNESS REGIONS: 54
# ACTIVE NODES: 55
# INACTIVE NODES: 0
# WITNESS REGIONS: 55
# ACTIVE NODES: 56
# INACTIVE NODES: 0
# WITNESS REGIONS: 56
# ACTIVE NODES: 57
# INACTIVE NODES: 0
# WITNESS REGIONS: 57
# ACTIVE NODES: 57
# INACTIVE NODES: 0
# WITNESS REGIONS: 57
# ACTIVE NODES: 58
# INACTIVE NODES: 0
# WITNESS REGIONS: 58
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 59
# INACTIVE NODES: 0
# WITNESS REGIONS: 59
# ACTIVE NODES: 60
# INACTIVE NODES: 0
# WITNESS REGIONS: 60
# ACTIVE NODES: 60
# INACTIVE NODES: 0
# WITNESS REGIONS: 60
# ACTIVE NODES: 60
# INACTIVE NODES: 0
# WITNESS REGIONS: 60
# ACTIVE NODES: 61
# INACTIVE NODES: 0
# WITNESS REGIONS: 61
# ACTIVE NODES: 62
# INACTIVE NODES: 0
# WITNESS REGIONS: 62
# ACTIVE NODES: 63
# INACTIVE NODES: 0
# WITNESS REGIONS: 63
# ACTIVE NODES: 64
# INACTIVE NODES: 0
# WITNESS REGIONS: 64
# ACTIVE NODES: 65
# INACTIVE NODES: 0
# WITNESS REGIONS: 65
# ACTIVE NODES: 66
# INACTIVE NODES: 0
# WITNESS REGIONS: 66
# ACTIVE NODES: 66
# INACTIVE NODES: 0
# WITNESS REGIONS: 66
# ACTIVE NODES: 67
# INACTIVE NODES: 0
# WITNESS REGIONS: 67
# ACTIVE NODES: 68
# INACTIVE NODES: 0
# WITNESS REGIONS: 68
# ACTIVE NODES: 69
# INACTIVE NODES: 0
# WITNESS REGIONS: 69
# ACTIVE NODES: 70
# INACTIVE NODES: 0
# WITNESS REGIONS: 70
# ACTIVE NODES: 71
# INACTIVE NODES: 0
# WITNESS REGIONS: 71
# ACTIVE NODES: 72
# INACTIVE NODES: 0
# WITNESS REGIONS: 72
# ACTIVE NODES: 73
# INACTIVE NODES: 0
# WITNESS REGIONS: 73
# ACTIVE NODES: 74
# INACTIVE NODES: 0
# WITNESS REGIONS: 74
# ACTIVE NODES: 75
# INACTIVE NODES: 0
# WITNESS REGIONS: 75
# ACTIVE NODES: 76
# INACTIVE NODES: 0
# WITNESS REGIONS: 76
# ACTIVE NODES: 77
# INACTIVE NODES: 0
# WITNESS REGIONS: 77
# ACTIVE NODES: 78
# INACTIVE NODES: 0
# WITNESS REGIONS: 78
# ACTIVE NODES: 79
# INACTIVE NODES: 0
# WITNESS REGIONS: 79
# ACTIVE NODES: 80
# INACTIVE NODES: 0
# WITNESS REGIONS: 80
# ACTIVE NODES: 80
# INACTIVE NODES: 0
# WITNESS REGIONS: 80
# ACTIVE NODES: 80
# INACTIVE NODES: 0
# WITNESS REGIONS: 80
# ACTIVE NODES: 81
# INACTIVE NODES: 0
# WITNESS REGIONS: 81
# ACTIVE NODES: 82
# INACTIVE NODES: 0
# WITNESS REGIONS: 82
# ACTIVE NODES: 82
# INACTIVE NODES: 0
# WITNESS REGIONS: 82
# ACTIVE NODES: 82
# INACTIVE NODES: 0
# WITNESS REGIONS: 82
# ACTIVE NODES: 82
# INACTIVE NODES: 0
# WITNESS REGIONS: 82
# ACTIVE NODES: 83
# INACTIVE NODES: 0
# WITNESS REGIONS: 83
# ACTIVE NODES: 84
# INACTIVE NODES: 0
# WITNESS REGIONS: 84
# ACTIVE NODES: 85
# INACTIVE NODES: 0
# WITNESS REGIONS: 85
# ACTIVE NODES: 86
# INACTIVE NODES: 0
# WITNESS REGIONS: 86
# ACTIVE NODES: 87
# INACTIVE NODES: 0
# WITNESS REGIONS: 87
# ACTIVE NODES: 88
# INACTIVE NODES: 0
# WITNESS REGIONS: 88
# ACTIVE NODES: 89
# INACTIVE NODES: 0
# WITNESS REGIONS: 89
# ACTIVE NODES: 90
# INACTIVE NODES: 0
# WITNESS REGIONS: 90
# ACTIVE NODES: 90
# INACTIVE NODES: 0
# WITNESS REGIONS: 90
# ACTIVE NODES: 91
# INACTIVE NODES: 0
# WITNESS REGIONS: 91
# ACTIVE NODES: 91
# INACTIVE NODES: 0
# WITNESS REGIONS: 91
# ACTIVE NODES: 92
# INACTIVE NODES: 0
# WITNESS REGIONS: 92
# ACTIVE NODES: 92
# INACTIVE NODES: 0
# WITNESS REGIONS: 92
# ACTIVE NODES: 93
# INACTIVE NODES: 0
# WITNESS REGIONS: 93
# ACTIVE NODES: 94
# INACTIVE NODES: 0
# WITNESS REGIONS: 94
# ACTIVE NODES: 95
# INACTIVE NODES: 0
# WITNESS REGIONS: 95
# ACTIVE NODES: 96
# INACTIVE NODES: 0
# WITNESS REGIONS: 96
# ACTIVE NODES: 97
# INACTIVE NODES: 0
# WITNESS REGIONS: 97
# ACTIVE NODES: 98
# INACTIVE NODES: 0
# WITNESS REGIONS: 98
# ACTIVE NODES: 98
# INACTIVE NODES: 0
# WITNESS REGIONS: 98
# ACTIVE NODES: 99
# INACTIVE NODES: 0
# WITNESS REGIONS: 99
# ACTIVE NODES: 100
# INACTIVE NODES: 0
# WITNESS REGIONS: 100
# ACTIVE NODES: 100
# INACTIVE NODES: 0
# WITNESS REGIONS: 100
# ACTIVE NODES: 100
# INACTIVE NODES: 0
# WITNESS REGIONS: 100
# ACTIVE NODES: 100
# INACTIVE NODES: 0
# WITNESS REGIONS: 100
# ACTIVE NODES: 100
# INACTIVE NODES: 0
# WITNESS REGIONS: 100
# ACTIVE NODES: 100
# INACTIVE NODES: 0
# WITNESS REGIONS: 100
# ACTIVE NODES: 100
# INACTIVE NODES: 0
# WITNESS REGIONS: 100
# ACTIVE NODES: 101
# INACTIVE NODES: 0
# WITNESS REGIONS: 101
# ACTIVE NODES: 102
# INACTIVE NODES: 0
# WITNESS REGIONS: 102
# ACTIVE NODES: 103
# INACTIVE NODES: 0
# WITNESS REGIONS: 103
# ACTIVE NODES: 104
# INACTIVE NODES: 0
# WITNESS REGIONS: 104
# ACTIVE NODES: 104
# INACTIVE NODES: 0
# WITNESS REGIONS: 104
# ACTIVE NODES: 105
# INACTIVE NODES: 0
# WITNESS REGIONS: 105
# ACTIVE NODES: 106
# INACTIVE NODES: 0
# WITNESS REGIONS: 106
# ACTIVE NODES: 107
# INACTIVE NODES: 0
# WITNESS REGIONS: 107
# ACTIVE NODES: 108
# INACTIVE NODES: 0
# WITNESS REGIONS: 108
# ACTIVE NODES: 109
# INACTIVE NODES: 0
# WITNESS REGIONS: 109
# ACTIVE NODES: 109
# INACTIVE NODES: 0
# WITNESS REGIONS: 109
# ACTIVE NODES: 110
# INACTIVE NODES: 0
# WITNESS REGIONS: 110
# ACTIVE NODES: 111
# INACTIVE NODES: 0
# WITNESS REGIONS: 111
# ACTIVE NODES: 111
# INACTIVE NODES: 0
# WITNESS REGIONS: 111
# ACTIVE NODES: 112
# INACTIVE NODES: 0
# WITNESS REGIONS: 112
# ACTIVE NODES: 113
# INACTIVE NODES: 0
# WITNESS REGIONS: 113
# ACTIVE NODES: 114
# INACTIVE NODES: 0
# WITNESS REGIONS: 114
# ACTIVE NODES: 115
# INACTIVE NODES: 0
# WITNESS REGIONS: 115
# ACTIVE NODES: 116
# INACTIVE NODES: 0
# WITNESS REGIONS: 116
# ACTIVE NODES: 117
# INACTIVE NODES: 0
# WITNESS REGIONS: 117
# ACTIVE NODES: 118
# INACTIVE NODES: 0
# WITNESS REGIONS: 118
# ACTIVE NODES: 119
# INACTIVE NODES: 0
# WITNESS REGIONS: 119
# ACTIVE NODES: 119
# INACTIVE NODES: 0
# WITNESS REGIONS: 119
# ACTIVE NODES: 120
# INACTIVE NODES: 0
# WITNESS REGIONS: 120
# ACTIVE NODES: 121
# INACTIVE NODES: 0
# WITNESS REGIONS: 121
# ACTIVE NODES: 121
# INACTIVE NODES: 0
# WITNESS REGIONS: 121
# ACTIVE NODES: 121
# INACTIVE NODES: 0
# WITNESS REGIONS: 121
# ACTIVE NODES: 122
# INACTIVE NODES: 0
# WITNESS REGIONS: 122
# ACTIVE NODES: 122
# INACTIVE NODES: 0
# WITNESS REGIONS: 122
# ACTIVE NODES: 122
# INACTIVE NODES: 0
# WITNESS REGIONS: 122
# ACTIVE NODES: 122
# INACTIVE NODES: 0
# WITNESS REGIONS: 122
# ACTIVE NODES: 122
# INACTIVE NODES: 0
# WITNESS REGIONS: 122
# ACTIVE NODES: 122
# INACTIVE NODES: 0
# WITNESS REGIONS: 122
# ACTIVE NODES: 123
# INACTIVE NODES: 0
# WITNESS REGIONS: 123
# ACTIVE NODES: 124
# INACTIVE NODES: 0
# WITNESS REGIONS: 124
# ACTIVE NODES: 125
# INACTIVE NODES: 0
# WITNESS REGIONS: 125
# ACTIVE NODES: 126
# INACTIVE NODES: 0
# WITNESS REGIONS: 126
# ACTIVE NODES: 126
# INACTIVE NODES: 0
# WITNESS REGIONS: 126
# ACTIVE NODES: 126
# INACTIVE NODES: 0
# WITNESS REGIONS: 126
# ACTIVE NODES: 126
# INACTIVE NODES: 0
# WITNESS REGIONS: 126
# ACTIVE NODES: 126
# INACTIVE NODES: 0
# WITNESS REGIONS: 126
# ACTIVE NODES: 127
# INACTIVE NODES: 0
# WITNESS REGIONS: 127
# ACTIVE NODES: 128
# INACTIVE NODES: 0
# WITNESS REGIONS: 128
# ACTIVE NODES: 128
# INACTIVE NODES: 0
# WITNESS REGIONS: 128
# ACTIVE NODES: 129
# INACTIVE NODES: 0
# WITNESS REGIONS: 129
# ACTIVE NODES: 130
# INACTIVE NODES: 0
# WITNESS REGIONS: 130
# ACTIVE NODES: 131
# INACTIVE NODES: 0
# WITNESS REGIONS: 131
# ACTIVE NODES: 132
# INACTIVE NODES: 0
# WITNESS REGIONS: 132
# ACTIVE NODES: 132
# INACTIVE NODES: 0
# WITNESS REGIONS: 132
# ACTIVE NODES: 133
# INACTIVE NODES: 0
# WITNESS REGIONS: 133
# ACTIVE NODES: 134
# INACTIVE NODES: 0
# WITNESS REGIONS: 134
# ACTIVE NODES: 135
# INACTIVE NODES: 0
# WITNESS REGIONS: 135
# ACTIVE NODES: 136
# INACTIVE NODES: 0
# WITNESS REGIONS: 136
# ACTIVE NODES: 137
# INACTIVE NODES: 0
# WITNESS REGIONS: 137
# ACTIVE NODES: 138
# INACTIVE NODES: 0
# WITNESS REGIONS: 138
# ACTIVE NODES: 138
# INACTIVE NODES: 0
# WITNESS REGIONS: 138
# ACTIVE NODES: 139
# INACTIVE NODES: 0
# WITNESS REGIONS: 139
# ACTIVE NODES: 139
# INACTIVE NODES: 0
# WITNESS REGIONS: 139
# ACTIVE NODES: 139
# INACTIVE NODES: 0
# WITNESS REGIONS: 139
# ACTIVE NODES: 139
# INACTIVE NODES: 0
# WITNESS REGIONS: 139
# ACTIVE NODES: 139
# INACTIVE NODES: 0
# WITNESS REGIONS: 139
# ACTIVE NODES: 139
# INACTIVE NODES: 0
# WITNESS REGIONS: 139
# ACTIVE NODES: 140
# INACTIVE NODES: 0
# WITNESS REGIONS: 140
# ACTIVE NODES: 141
# INACTIVE NODES: 0
# WITNESS REGIONS: 141
# ACTIVE NODES: 142
# INACTIVE NODES: 0
# WITNESS REGIONS: 142
# ACTIVE NODES: 143
# INACTIVE NODES: 0
# WITNESS REGIONS: 143
# ACTIVE NODES: 144
# INACTIVE NODES: 0
# WITNESS REGIONS: 144
# ACTIVE NODES: 144
# INACTIVE NODES: 0
# WITNESS REGIONS: 144
# ACTIVE NODES: 144
# INACTIVE NODES: 0
# WITNESS REGIONS: 144
# ACTIVE NODES: 144
# INACTIVE NODES: 0
# WITNESS REGIONS: 144
# ACTIVE NODES: 145
# INACTIVE NODES: 0
# WITNESS REGIONS: 145
# ACTIVE NODES: 146
# INACTIVE NODES: 0
# WITNESS REGIONS: 146
# ACTIVE NODES: 147
# INACTIVE NODES: 0
# WITNESS REGIONS: 147
# ACTIVE NODES: 148
# INACTIVE NODES: 0
# WITNESS REGIONS: 148
# ACTIVE NODES: 149
# INACTIVE NODES: 0
# WITNESS REGIONS: 149
# ACTIVE NODES: 149
# INACTIVE NODES: 0
# WITNESS REGIONS: 149
# ACTIVE NODES: 149
# INACTIVE NODES: 0
# WITNESS REGIONS: 149
# ACTIVE NODES: 150
# INACTIVE NODES: 0
# WITNESS REGIONS: 150
# ACTIVE NODES: 150
# INACTIVE NODES: 0
# WITNESS REGIONS: 150
# ACTIVE NODES: 150
# INACTIVE NODES: 0
# WITNESS REGIONS: 150
# ACTIVE NODES: 151
# INACTIVE NODES: 0
# WITNESS REGIONS: 151
# ACTIVE NODES: 152
# INACTIVE NODES: 0
# WITNESS REGIONS: 152
# ACTIVE NODES: 153
# INACTIVE NODES: 0
# WITNESS REGIONS: 153
# ACTIVE NODES: 154
# INACTIVE NODES: 0
# WITNESS REGIONS: 154
# ACTIVE NODES: 154
# INACTIVE NODES: 0
# WITNESS REGIONS: 154
# ACTIVE NODES: 154
# INACTIVE NODES: 0
# WITNESS REGIONS: 154
# ACTIVE NODES: 155
# INACTIVE NODES: 0
# WITNESS REGIONS: 155
# ACTIVE NODES: 155
# INACTIVE NODES: 0
# WITNESS REGIONS: 155
# ACTIVE NODES: 155
# INACTIVE NODES: 0
# WITNESS REGIONS: 155
# ACTIVE NODES: 155
# INACTIVE NODES: 0
# WITNESS REGIONS: 155
# ACTIVE NODES: 156
# INACTIVE NODES: 0
# WITNESS REGIONS: 156
# ACTIVE NODES: 157
# INACTIVE NODES: 0
# WITNESS REGIONS: 157
# ACTIVE NODES: 158
# INACTIVE NODES: 0
# WITNESS REGIONS: 158
# ACTIVE NODES: 159
# INACTIVE NODES: 0
# WITNESS REGIONS: 159
# ACTIVE NODES: 160
# INACTIVE NODES: 0
# WITNESS REGIONS: 160
# ACTIVE NODES: 160
# INACTIVE NODES: 0
# WITNESS REGIONS: 160
# ACTIVE NODES: 160
# INACTIVE NODES: 0
# WITNESS REGIONS: 160
# ACTIVE NODES: 161
# INACTIVE NODES: 0
# WITNESS REGIONS: 161
# ACTIVE NODES: 162
# INACTIVE NODES: 0
# WITNESS REGIONS: 162
# ACTIVE NODES: 162
# INACTIVE NODES: 0
# WITNESS REGIONS: 162
# ACTIVE NODES: 162
# INACTIVE NODES: 0
# WITNESS REGIONS: 162
# ACTIVE NODES: 163
# INACTIVE NODES: 0
# WITNESS REGIONS: 163
# ACTIVE NODES: 164
# INACTIVE NODES: 0
# WITNESS REGIONS: 164
# ACTIVE NODES: 164
# INACTIVE NODES: 0
# WITNESS REGIONS: 164
# ACTIVE NODES: 165
# INACTIVE NODES: 0
# WITNESS REGIONS: 165
# ACTIVE NODES: 166
# INACTIVE NODES: 0
# WITNESS REGIONS: 166
# ACTIVE NODES: 166
# INACTIVE NODES: 0
# WITNESS REGIONS: 166
# ACTIVE NODES: 167
# INACTIVE NODES: 0
# WITNESS REGIONS: 167
# ACTIVE NODES: 167
# INACTIVE NODES: 0
# WITNESS REGIONS: 167
# ACTIVE NODES: 167
# INACTIVE NODES: 0
# WITNESS REGIONS: 167
# ACTIVE NODES: 167
# INACTIVE NODES: 0
# WITNESS REGIONS: 167
# ACTIVE NODES: 167
# INACTIVE NODES: 0
# WITNESS REGIONS: 167
# ACTIVE NODES: 167
# INACTIVE NODES: 0
# WITNESS REGIONS: 167
# ACTIVE NODES: 168
# INACTIVE NODES: 0
# WITNESS REGIONS: 168
# ACTIVE NODES: 169
# INACTIVE NODES: 0
# WITNESS REGIONS: 169
# ACTIVE NODES: 169
# INACTIVE NODES: 0
# WITNESS REGIONS: 169
# ACTIVE NODES: 170
# INACTIVE NODES: 0
# WITNESS REGIONS: 170
# ACTIVE NODES: 171
# INACTIVE NODES: 0
# WITNESS REGIONS: 171
# ACTIVE NODES: 171
# INACTIVE NODES: 0
# WITNESS REGIONS: 171
# ACTIVE NODES: 171
# INACTIVE NODES: 0
# WITNESS REGIONS: 171
# ACTIVE NODES: 172
# INACTIVE NODES: 0
# WITNESS REGIONS: 172
# ACTIVE NODES: 173
# INACTIVE NODES: 0
# WITNESS REGIONS: 173
# ACTIVE NODES: 174
# INACTIVE NODES: 0
# WITNESS REGIONS: 174
# ACTIVE NODES: 175
# INACTIVE NODES: 0
# WITNESS REGIONS: 175
# ACTIVE NODES: 176
# INACTIVE NODES: 0
# WITNESS REGIONS: 176
# ACTIVE NODES: 176
# INACTIVE NODES: 0
# WITNESS REGIONS: 176
# ACTIVE NODES: 177
# INACTIVE NODES: 0
# WITNESS REGIONS: 177
# ACTIVE NODES: 177
# INACTIVE NODES: 0
# WITNESS REGIONS: 177
# ACTIVE NODES: 177
# INACTIVE NODES: 0
# WITNESS REGIONS: 177
# ACTIVE NODES: 178
# INACTIVE NODES: 0
# WITNESS REGIONS: 178
# ACTIVE NODES: 179
# INACTIVE NODES: 0
# WITNESS REGIONS: 179
# ACTIVE NODES: 180
# INACTIVE NODES: 0
# WITNESS REGIONS: 180
# ACTIVE NODES: 181
# INACTIVE NODES: 0
# WITNESS REGIONS: 181
# ACTIVE NODES: 181
# INACTIVE NODES: 0
# WITNESS REGIONS: 181
# ACTIVE NODES: 182
# INACTIVE NODES: 0
# WITNESS REGIONS: 182
# ACTIVE NODES: 183
# INACTIVE NODES: 0
# WITNESS REGIONS: 183
# ACTIVE NODES: 184
# INACTIVE NODES: 0
# WITNESS REGIONS: 184
# ACTIVE NODES: 185
# INACTIVE NODES: 0
# WITNESS REGIONS: 185
# ACTIVE NODES: 185
# INACTIVE NODES: 0
# WITNESS REGIONS: 185
# ACTIVE NODES: 185
# INACTIVE NODES: 0
# WITNESS REGIONS: 185
# ACTIVE NODES: 186
# INACTIVE NODES: 0
# WITNESS REGIONS: 186
# ACTIVE NODES: 187
# INACTIVE NODES: 0
# WITNESS REGIONS: 187
# ACTIVE NODES: 187
# INACTIVE NODES: 0
# WITNESS REGIONS: 187
# ACTIVE NODES: 187
# INACTIVE NODES: 0
# WITNESS REGIONS: 187
# ACTIVE NODES: 188
# INACTIVE NODES: 0
# WITNESS REGIONS: 188
# ACTIVE NODES: 189
# INACTIVE NODES: 0
# WITNESS REGIONS: 189
# ACTIVE NODES: 190
# INACTIVE NODES: 0
# WITNESS REGIONS: 190
# ACTIVE NODES: 190
# INACTIVE NODES: 0
# WITNESS REGIONS: 190
# ACTIVE NODES: 191
# INACTIVE NODES: 0
# WITNESS REGIONS: 191
# ACTIVE NODES: 192
# INACTIVE NODES: 0
# WITNESS REGIONS: 192
# ACTIVE NODES: 193
# INACTIVE NODES: 0
# WITNESS REGIONS: 193
# ACTIVE NODES: 194
# INACTIVE NODES: 0
# WITNESS REGIONS: 194
# ACTIVE NODES: 195
# INACTIVE NODES: 0
# WITNESS REGIONS: 195
# ACTIVE NODES: 195
# INACTIVE NODES: 0
# WITNESS REGIONS: 195
# ACTIVE NODES: 195
# INACTIVE NODES: 0
# WITNESS REGIONS: 195
# ACTIVE NODES: 195
# INACTIVE NODES: 0
# WITNESS REGIONS: 195
# ACTIVE NODES: 196
# INACTIVE NODES: 0
# WITNESS REGIONS: 196
# ACTIVE NODES: 196
# INACTIVE NODES: 0
# WITNESS REGIONS: 196
# ACTIVE NODES: 197
# INACTIVE NODES: 0
# WITNESS REGIONS: 197
# ACTIVE NODES: 198
# INACTIVE NODES: 0
# WITNESS REGIONS: 198
# ACTIVE NODES: 199
# INACTIVE NODES: 0
# WITNESS REGIONS: 199
# ACTIVE NODES: 200
# INACTIVE NODES: 0
# WITNESS REGIONS: 200
# ACTIVE NODES: 201
# INACTIVE NODES: 0
# WITNESS REGIONS: 201
# ACTIVE NODES: 202
# INACTIVE NODES: 0
# WITNESS REGIONS: 202
# ACTIVE NODES: 203
# INACTIVE NODES: 0
# WITNESS REGIONS: 203
# ACTIVE NODES: 204
# INACTIVE NODES: 0
# WITNESS REGIONS: 204
# ACTIVE NODES: 205
# INACTIVE NODES: 0
# WITNESS REGIONS: 205
# ACTIVE NODES: 205
# INACTIVE NODES: 0
# WITNESS REGIONS: 205
# ACTIVE NODES: 205
# INACTIVE NODES: 0
# WITNESS REGIONS: 205
# ACTIVE NODES: 206
# INACTIVE NODES: 0
# WITNESS REGIONS: 206
# ACTIVE NODES: 207
# INACTIVE NODES: 0
# WITNESS REGIONS: 207
# ACTIVE NODES: 208
# INACTIVE NODES: 0
# WITNESS REGIONS: 208
# ACTIVE NODES: 209
# INACTIVE NODES: 0
# WITNESS REGIONS: 209
# ACTIVE NODES: 209
# INACTIVE NODES: 0
# WITNESS REGIONS: 209
# ACTIVE NODES: 209
# INACTIVE NODES: 0
# WITNESS REGIONS: 209
# ACTIVE NODES: 209
# INACTIVE NODES: 0
# WITNESS REGIONS: 209
# ACTIVE NODES: 209
# INACTIVE NODES: 0
# WITNESS REGIONS: 209
# ACTIVE NODES: 209
# INACTIVE NODES: 0
# WITNESS REGIONS: 209
# ACTIVE NODES: 210
# INACTIVE NODES: 0
# WITNESS REGIONS: 210
# ACTIVE NODES: 211
# INACTIVE NODES: 0
# WITNESS REGIONS: 211
# ACTIVE NODES: 212
# INACTIVE NODES: 0
# WITNESS REGIONS: 212
# ACTIVE NODES: 213
# INACTIVE NODES: 0
# WITNESS REGIONS: 213
# ACTIVE NODES: 213
# INACTIVE NODES: 0
# WITNESS REGIONS: 213
# ACTIVE NODES: 213
# INACTIVE NODES: 0
# WITNESS REGIONS: 213
# ACTIVE NODES: 214
# INACTIVE NODES: 0
# WITNESS REGIONS: 214
# ACTIVE NODES: 215
# INACTIVE NODES: 0
# WITNESS REGIONS: 215
# ACTIVE NODES: 215
# INACTIVE NODES: 0
# WITNESS REGIONS: 215
# ACTIVE NODES: 216
# INACTIVE NODES: 0
# WITNESS REGIONS: 216
# ACTIVE NODES: 217
# INACTIVE NODES: 0
# WITNESS REGIONS: 217
# ACTIVE NODES: 218
# INACTIVE NODES: 0
# WITNESS REGIONS: 218
# ACTIVE NODES: 219
# INACTIVE NODES: 0
# WITNESS REGIONS: 219
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 220
# INACTIVE NODES: 0
# WITNESS REGIONS: 220
# ACTIVE NODES: 221
# INACTIVE NODES: 0
# WITNESS REGIONS: 221
# ACTIVE NODES: 221
# INACTIVE NODES: 0
# WITNESS REGIONS: 221
# ACTIVE NODES: 222
# INACTIVE NODES: 0
# WITNESS REGIONS: 222
# ACTIVE NODES: 222
# INACTIVE NODES: 0
# WITNESS REGIONS: 222
# ACTIVE NODES: 222
# INACTIVE NODES: 0
# WITNESS REGIONS: 222
# ACTIVE NODES: 222
# INACTIVE NODES: 0
# WITNESS REGIONS: 222
# ACTIVE NODES: 223
# INACTIVE NODES: 0
# WITNESS REGIONS: 223
# ACTIVE NODES: 224
# INACTIVE NODES: 0
# WITNESS REGIONS: 224
# ACTIVE NODES: 224
# INACTIVE NODES: 0
# WITNESS REGIONS: 224
# ACTIVE NODES: 224
# INACTIVE NODES: 0
# WITNESS REGIONS: 224
# ACTIVE NODES: 224
# INACTIVE NODES: 0
# WITNESS REGIONS: 224
# ACTIVE NODES: 224
# INACTIVE NODES: 0
# WITNESS REGIONS: 224
# ACTIVE NODES: 225
# INACTIVE NODES: 0
# WITNESS REGIONS: 225
# ACTIVE NODES: 225
# INACTIVE NODES: 0
# WITNESS REGIONS: 225
# ACTIVE NODES: 225
# INACTIVE NODES: 0
# WITNESS REGIONS: 225
# ACTIVE NODES: 226
# INACTIVE NODES: 0
# WITNESS REGIONS: 226
# ACTIVE NODES: 226
# INACTIVE NODES: 0
# WITNESS REGIONS: 226
# ACTIVE NODES: 227
# INACTIVE NODES: 0
# WITNESS REGIONS: 227
# ACTIVE NODES: 227
# INACTIVE NODES: 0
# WITNESS REGIONS: 227
# ACTIVE NODES: 227
# INACTIVE NODES: 0
# WITNESS REGIONS: 227
# ACTIVE NODES: 228
# INACTIVE NODES: 0
# WITNESS REGIONS: 228
# ACTIVE NODES: 228
# INACTIVE NODES: 0
# WITNESS REGIONS: 228
# ACTIVE NODES: 228
# INACTIVE NODES: 0
# WITNESS REGIONS: 228
# ACTIVE NODES: 229
# INACTIVE NODES: 0
# WITNESS REGIONS: 229
# ACTIVE NODES: 229
# INACTIVE NODES: 0
# WITNESS REGIONS: 229
# ACTIVE NODES: 229
# INACTIVE NODES: 0
# WITNESS REGIONS: 229
# ACTIVE NODES: 229
# INACTIVE NODES: 0
# WITNESS REGIONS: 229
# ACTIVE NODES: 229
# INACTIVE NODES: 0
# WITNESS REGIONS: 229
# ACTIVE NODES: 230
# INACTIVE NODES: 0
# WITNESS REGIONS: 230
# ACTIVE NODES: 230
# INACTIVE NODES: 0
# WITNESS REGIONS: 230
# ACTIVE NODES: 231
# INACTIVE NODES: 0
# WITNESS REGIONS: 231
# ACTIVE NODES: 232
# INACTIVE NODES: 0
# WITNESS REGIONS: 232
# ACTIVE NODES: 233
# INACTIVE NODES: 0
# WITNESS REGIONS: 233
# ACTIVE NODES: 234
# INACTIVE NODES: 0
# WITNESS REGIONS: 234
# ACTIVE NODES: 235
# INACTIVE NODES: 0
# WITNESS REGIONS: 235
# ACTIVE NODES: 236
# INACTIVE NODES: 0
# WITNESS REGIONS: 236
# ACTIVE NODES: 237
# INACTIVE NODES: 0
# WITNESS REGIONS: 237
# ACTIVE NODES: 238
# INACTIVE NODES: 0
# WITNESS REGIONS: 238
# ACTIVE NODES: 238
# INACTIVE NODES: 0
# WITNESS REGIONS: 238
# ACTIVE NODES: 238
# INACTIVE NODES: 0
# WITNESS REGIONS: 238
# ACTIVE NODES: 238
# INACTIVE NODES: 0
# WITNESS REGIONS: 238
# ACTIVE NODES: 239
# INACTIVE NODES: 0
# WITNESS REGIONS: 239
# ACTIVE NODES: 240
# INACTIVE NODES: 0
# WITNESS REGIONS: 240
# ACTIVE NODES: 241
# INACTIVE NODES: 0
# WITNESS REGIONS: 241
# ACTIVE NODES: 241
# INACTIVE NODES: 0
# WITNESS REGIONS: 241
# ACTIVE NODES: 241
# INACTIVE NODES: 0
# WITNESS REGIONS: 241
# ACTIVE NODES: 241
# INACTIVE NODES: 0
# WITNESS REGIONS: 241
# ACTIVE NODES: 241
# INACTIVE NODES: 0
# WITNESS REGIONS: 241
# ACTIVE NODES: 242
# INACTIVE NODES: 0
# WITNESS REGIONS: 242
# ACTIVE NODES: 243
# INACTIVE NODES: 0
# WITNESS REGIONS: 243
# ACTIVE NODES: 244
# INACTIVE NODES: 0
# WITNESS REGIONS: 244
# ACTIVE NODES: 245
# INACTIVE NODES: 0
# WITNESS REGIONS: 245
# ACTIVE NODES: 246
# INACTIVE NODES: 0
# WITNESS REGIONS: 246
# ACTIVE NODES: 247
# INACTIVE NODES: 0
# WITNESS REGIONS: 247
# ACTIVE NODES: 247
# INACTIVE NODES: 0
# WITNESS REGIONS: 247
# ACTIVE NODES: 248
# INACTIVE NODES: 0
# WITNESS REGIONS: 248
# ACTIVE NODES: 249
# INACTIVE NODES: 0
# WITNESS REGIONS: 249
# ACTIVE NODES: 250
# INACTIVE NODES: 0
# WITNESS REGIONS: 250
# ACTIVE NODES: 251
# INACTIVE NODES: 0
# WITNESS REGIONS: 251
# ACTIVE NODES: 252
# INACTIVE NODES: 0
# WITNESS REGIONS: 252
# ACTIVE NODES: 253
# INACTIVE NODES: 0
# WITNESS REGIONS: 253
# ACTIVE NODES: 253
# INACTIVE NODES: 0
# WITNESS REGIONS: 253
# ACTIVE NODES: 254
# INACTIVE NODES: 0
# WITNESS REGIONS: 254
# ACTIVE NODES: 255
# INACTIVE NODES: 0
# WITNESS REGIONS: 255
# ACTIVE NODES: 256
# INACTIVE NODES: 0
# WITNESS REGIONS: 256
# ACTIVE NODES: 257
# INACTIVE NODES: 0
# WITNESS REGIONS: 257
# ACTIVE NODES: 258
# INACTIVE NODES: 0
# WITNESS REGIONS: 258
# ACTIVE NODES: 259
# INACTIVE NODES: 0
# WITNESS REGIONS: 259
# ACTIVE NODES: 260
# INACTIVE NODES: 0
# WITNESS REGIONS: 260
# ACTIVE NODES: 261
# INACTIVE NODES: 0
# WITNESS REGIONS: 261
# ACTIVE NODES: 261
# INACTIVE NODES: 0
# WITNESS REGIONS: 261
# ACTIVE NODES: 262
# INACTIVE NODES: 0
# WITNESS REGIONS: 262
# ACTIVE NODES: 263
# INACTIVE NODES: 0
# WITNESS REGIONS: 263
# ACTIVE NODES: 264
# INACTIVE NODES: 0
# WITNESS REGIONS: 264
# ACTIVE NODES: 264
# INACTIVE NODES: 0
# WITNESS REGIONS: 264
# ACTIVE NODES: 265
# INACTIVE NODES: 0
# WITNESS REGIONS: 265
# ACTIVE NODES: 266
# INACTIVE NODES: 0
# WITNESS REGIONS: 266
# ACTIVE NODES: 267
# INACTIVE NODES: 0
# WITNESS REGIONS: 267
# ACTIVE NODES: 267
# INACTIVE NODES: 0
# WITNESS REGIONS: 267
# ACTIVE NODES: 268
# INACTIVE NODES: 0
# WITNESS REGIONS: 268
# ACTIVE NODES: 268
# INACTIVE NODES: 0
# WITNESS REGIONS: 268
# ACTIVE NODES: 269
# INACTIVE NODES: 0
# WITNESS REGIONS: 269
# ACTIVE NODES: 270
# INACTIVE NODES: 0
# WITNESS REGIONS: 270
# ACTIVE NODES: 270
# INACTIVE NODES: 0
# WITNESS REGIONS: 270
# ACTIVE NODES: 271
# INACTIVE NODES: 0
# WITNESS REGIONS: 271
# ACTIVE NODES: 272
# INACTIVE NODES: 0
# WITNESS REGIONS: 272
# ACTIVE NODES: 273
# INACTIVE NODES: 0
# WITNESS REGIONS: 273
# ACTIVE NODES: 273
# INACTIVE NODES: 0
# WITNESS REGIONS: 273
# ACTIVE NODES: 274
# INACTIVE NODES: 0
# WITNESS REGIONS: 274
# ACTIVE NODES: 275
# INACTIVE NODES: 0
# WITNESS REGIONS: 275
# ACTIVE NODES: 275
# INACTIVE NODES: 0
# WITNESS REGIONS: 275
# ACTIVE NODES: 276
# INACTIVE NODES: 0
# WITNESS REGIONS: 276
# ACTIVE NODES: 277
# INACTIVE NODES: 0
# WITNESS REGIONS: 277
# ACTIVE NODES: 278
# INACTIVE NODES: 0
# WITNESS REGIONS: 278
# ACTIVE NODES: 279
# INACTIVE NODES: 0
# WITNESS REGIONS: 279
# ACTIVE NODES: 280
# INACTIVE NODES: 0
# WITNESS REGIONS: 280
# ACTIVE NODES: 281
# INACTIVE NODES: 0
# WITNESS REGIONS: 281
# ACTIVE NODES: 282
# INACTIVE NODES: 0
# WITNESS REGIONS: 282
# ACTIVE NODES: 282
# INACTIVE NODES: 0
# WITNESS REGIONS: 282
# ACTIVE NODES: 283
# INACTIVE NODES: 0
# WITNESS REGIONS: 283
# ACTIVE NODES: 284
# INACTIVE NODES: 0
# WITNESS REGIONS: 284
# ACTIVE NODES: 285
# INACTIVE NODES: 0
# WITNESS REGIONS: 285
# ACTIVE NODES: 286
# INACTIVE NODES: 0
# WITNESS REGIONS: 286
# ACTIVE NODES: 286
# INACTIVE NODES: 0
# WITNESS REGIONS: 286
# ACTIVE NODES: 287
# INACTIVE NODES: 0
# WITNESS REGIONS: 287
# ACTIVE NODES: 287
# INACTIVE NODES: 0
# WITNESS REGIONS: 287
# ACTIVE NODES: 288
# INACTIVE NODES: 0
# WITNESS REGIONS: 288
# ACTIVE NODES: 289
# INACTIVE NODES: 0
# WITNESS REGIONS: 289
# ACTIVE NODES: 289
# INACTIVE NODES: 0
# WITNESS REGIONS: 289
# ACTIVE NODES: 290
# INACTIVE NODES: 0
# WITNESS REGIONS: 290
# ACTIVE NODES: 291
# INACTIVE NODES: 0
# WITNESS REGIONS: 291
# ACTIVE NODES: 292
# INACTIVE NODES: 0
# WITNESS REGIONS: 292
# ACTIVE NODES: 292
# INACTIVE NODES: 0
# WITNESS REGIONS: 292
# ACTIVE NODES: 292
# INACTIVE NODES: 0
# WITNESS REGIONS: 292
# ACTIVE NODES: 293
# INACTIVE NODES: 0
# WITNESS REGIONS: 293
# ACTIVE NODES: 294
# INACTIVE NODES: 0
# WITNESS REGIONS: 294
# ACTIVE NODES: 295
# INACTIVE NODES: 0
# WITNESS REGIONS: 295
# ACTIVE NODES: 296
# INACTIVE NODES: 0
# WITNESS REGIONS: 296
# ACTIVE NODES: 297
# INACTIVE NODES: 0
# WITNESS REGIONS: 297
# ACTIVE NODES: 298
# INACTIVE NODES: 0
# WITNESS REGIONS: 298
# ACTIVE NODES: 299
# INACTIVE NODES: 0
# WITNESS REGIONS: 299
# ACTIVE NODES: 300
# INACTIVE NODES: 0
# WITNESS REGIONS: 300
# ACTIVE NODES: 301
# INACTIVE NODES: 0
# WITNESS REGIONS: 301
# ACTIVE NODES: 301
# INACTIVE NODES: 0
# WITNESS REGIONS: 301
# ACTIVE NODES: 302
# INACTIVE NODES: 0
# WITNESS REGIONS: 302
# ACTIVE NODES: 302
# INACTIVE NODES: 0
# WITNESS REGIONS: 302
# ACTIVE NODES: 303
# INACTIVE NODES: 0
# WITNESS REGIONS: 303
# ACTIVE NODES: 304
# INACTIVE NODES: 0
# WITNESS REGIONS: 304
# ACTIVE NODES: 305
# INACTIVE NODES: 0
# WITNESS REGIONS: 305
# ACTIVE NODES: 306
# INACTIVE NODES: 0
# WITNESS REGIONS: 306
# ACTIVE NODES: 307
# INACTIVE NODES: 0
# WITNESS REGIONS: 307
# ACTIVE NODES: 308
# INACTIVE NODES: 0
# WITNESS REGIONS: 308
# ACTIVE NODES: 309
# INACTIVE NODES: 0
# WITNESS REGIONS: 309
# ACTIVE NODES: 310
# INACTIVE NODES: 0
# WITNESS REGIONS: 310
# ACTIVE NODES: 311
# INACTIVE NODES: 0
# WITNESS REGIONS: 311
# ACTIVE NODES: 311
# INACTIVE NODES: 0
# WITNESS REGIONS: 311
# ACTIVE NODES: 312
# INACTIVE NODES: 0
# WITNESS REGIONS: 312
# ACTIVE NODES: 313
# INACTIVE NODES: 0
# WITNESS REGIONS: 313
# ACTIVE NODES: 314
# INACTIVE NODES: 0
# WITNESS REGIONS: 314
# ACTIVE NODES: 315
# INACTIVE NODES: 0
# WITNESS REGIONS: 315
# ACTIVE NODES: 316
# INACTIVE NODES: 0
# WITNESS REGIONS: 316
# ACTIVE NODES: 317
# INACTIVE NODES: 0
# WITNESS REGIONS: 317
# ACTIVE NODES: 318
# INACTIVE NODES: 0
# WITNESS REGIONS: 318
# ACTIVE NODES: 319
# INACTIVE NODES: 0
# WITNESS REGIONS: 319
# ACTIVE NODES: 319
# INACTIVE NODES: 0
# WITNESS REGIONS: 319
# ACTIVE NODES: 320
# INACTIVE NODES: 0
# WITNESS REGIONS: 320
# ACTIVE NODES: 321
# INACTIVE NODES: 0
# WITNESS REGIONS: 321
# ACTIVE NODES: 322
# INACTIVE NODES: 0
# WITNESS REGIONS: 322
# ACTIVE NODES: 323
# INACTIVE NODES: 0
# WITNESS REGIONS: 323
# ACTIVE NODES: 324
# INACTIVE NODES: 0
# WITNESS REGIONS: 324
# ACTIVE NODES: 325
# INACTIVE NODES: 0
# WITNESS REGIONS: 325
# ACTIVE NODES: 326
# INACTIVE NODES: 0
# WITNESS REGIONS: 326
# ACTIVE NODES: 327
# INACTIVE NODES: 0
# WITNESS REGIONS: 327
# ACTIVE NODES: 328
# INACTIVE NODES: 0
# WITNESS REGIONS: 328
# ACTIVE NODES: 328
# INACTIVE NODES: 0
# WITNESS REGIONS: 328
# ACTIVE NODES: 328
# INACTIVE NODES: 0
# WITNESS REGIONS: 328
# ACTIVE NODES: 328
# INACTIVE NODES: 0
# WITNESS REGIONS: 328
# ACTIVE NODES: 329
# INACTIVE NODES: 0
# WITNESS REGIONS: 329
# ACTIVE NODES: 330
# INACTIVE NODES: 0
# WITNESS REGIONS: 330
# ACTIVE NODES: 331
# INACTIVE NODES: 0
# WITNESS REGIONS: 331
# ACTIVE NODES: 331
# INACTIVE NODES: 0
# WITNESS REGIONS: 331
# ACTIVE NODES: 332
# INACTIVE NODES: 0
# WITNESS REGIONS: 332
# ACTIVE NODES: 333
# INACTIVE NODES: 0
# WITNESS REGIONS: 333
# ACTIVE NODES: 334
# INACTIVE NODES: 0
# WITNESS REGIONS: 334
# ACTIVE NODES: 335
# INACTIVE NODES: 0
# WITNESS REGIONS: 335
# ACTIVE NODES: 336
# INACTIVE NODES: 0
# WITNESS REGIONS: 336
# ACTIVE NODES: 337
# INACTIVE NODES: 0
# WITNESS REGIONS: 337
# ACTIVE NODES: 337
# INACTIVE NODES: 0
# WITNESS REGIONS: 337
# ACTIVE NODES: 338
# INACTIVE NODES: 0
# WITNESS REGIONS: 338
# ACTIVE NODES: 339
# INACTIVE NODES: 0
# WITNESS REGIONS: 339
# ACTIVE NODES: 339
# INACTIVE NODES: 0
# WITNESS REGIONS: 339
# ACTIVE NODES: 340
# INACTIVE NODES: 0
# WITNESS REGIONS: 340
# ACTIVE NODES: 341
# INACTIVE NODES: 0
# WITNESS REGIONS: 341
# ACTIVE NODES: 342
# INACTIVE NODES: 0
# WITNESS REGIONS: 342
# ACTIVE NODES: 343
# INACTIVE NODES: 0
# WITNESS REGIONS: 343
# ACTIVE NODES: 344
# INACTIVE NODES: 0
# WITNESS REGIONS: 344
# ACTIVE NODES: 345
# INACTIVE NODES: 0
# WITNESS REGIONS: 345
# ACTIVE NODES: 346
# INACTIVE NODES: 0
# WITNESS REGIONS: 346
# ACTIVE NODES: 346
# INACTIVE NODES: 0
# WITNESS REGIONS: 346
# ACTIVE NODES: 346
# INACTIVE NODES: 0
# WITNESS REGIONS: 346
# ACTIVE NODES: 347
# INACTIVE NODES: 0
# WITNESS REGIONS: 347
# ACTIVE NODES: 347
# INACTIVE NODES: 0
# WITNESS REGIONS: 347
# ACTIVE NODES: 347
# INACTIVE NODES: 0
# WITNESS REGIONS: 347
# ACTIVE NODES: 348
# INACTIVE NODES: 0
# WITNESS REGIONS: 348
# ACTIVE NODES: 348
# INACTIVE NODES: 0
# WITNESS REGIONS: 348
# ACTIVE NODES: 349
# INACTIVE NODES: 0
# WITNESS REGIONS: 349
# ACTIVE NODES: 349
# INACTIVE NODES: 0
# WITNESS REGIONS: 349
# ACTIVE NODES: 349
# INACTIVE NODES: 0
# WITNESS REGIONS: 349
# ACTIVE NODES: 349
# INACTIVE NODES: 0
# WITNESS REGIONS: 349
# ACTIVE NODES: 350
# INACTIVE NODES: 0
# WITNESS REGIONS: 350
# ACTIVE NODES: 350
# INACTIVE NODES: 0
# WITNESS REGIONS: 350
# ACTIVE NODES: 350
# INACTIVE NODES: 0
# WITNESS REGIONS: 350
# ACTIVE NODES: 350
# INACTIVE NODES: 0
# WITNESS REGIONS: 350
# ACTIVE NODES: 351
# INACTIVE NODES: 0
# WITNESS REGIONS: 351
# ACTIVE NODES: 351
# INACTIVE NODES: 0
# WITNESS REGIONS: 351
# ACTIVE NODES: 352
# INACTIVE NODES: 0
# WITNESS REGIONS: 352
# ACTIVE NODES: 353
# INACTIVE NODES: 0
# WITNESS REGIONS: 353
# ACTIVE NODES: 353
# INACTIVE NODES: 0
# WITNESS REGIONS: 353
# ACTIVE NODES: 354
# INACTIVE NODES: 0
# WITNESS REGIONS: 354
# ACTIVE NODES: 355
# INACTIVE NODES: 0
# WITNESS REGIONS: 355
# ACTIVE NODES: 356
# INACTIVE NODES: 0
# WITNESS REGIONS: 356
# ACTIVE NODES: 356
# INACTIVE NODES: 0
# WITNESS REGIONS: 356
# ACTIVE NODES: 356
# INACTIVE NODES: 0
# WITNESS REGIONS: 356
# ACTIVE NODES: 357
# INACTIVE NODES: 0
# WITNESS REGIONS: 357
# ACTIVE NODES: 358
# INACTIVE NODES: 0
# WITNESS REGIONS: 358
# ACTIVE NODES: 359
# INACTIVE NODES: 0
# WITNESS REGIONS: 359
# ACTIVE NODES: 360
# INACTIVE NODES: 0
# WITNESS REGIONS: 360
# ACTIVE NODES: 361
# INACTIVE NODES: 0
# WITNESS REGIONS: 361
# ACTIVE NODES: 361
# INACTIVE NODES: 0
# WITNESS REGIONS: 361
# ACTIVE NODES: 361
# INACTIVE NODES: 0
# WITNESS REGIONS: 361
# ACTIVE NODES: 361
# INACTIVE NODES: 1
# WITNESS REGIONS: 361
# ACTIVE NODES: 361
# INACTIVE NODES: 1
# WITNESS REGIONS: 361
# ACTIVE NODES: 361
# INACTIVE NODES: 1
# WITNESS REGIONS: 361
# ACTIVE NODES: 362
# INACTIVE NODES: 1
# WITNESS REGIONS: 362
# ACTIVE NODES: 363
# INACTIVE NODES: 1
# WITNESS REGIONS: 363
# ACTIVE NODES: 364
# INACTIVE NODES: 1
# WITNESS REGIONS: 364
# ACTIVE NODES: 365
# INACTIVE NODES: 1
# WITNESS REGIONS: 365
# ACTIVE NODES: 365
# INACTIVE NODES: 1
# WITNESS REGIONS: 365
# ACTIVE NODES: 365
# INACTIVE NODES: 1
# WITNESS REGIONS: 365
# ACTIVE NODES: 365
# INACTIVE NODES: 1
# WITNESS REGIONS: 365
# ACTIVE NODES: 365
# INACTIVE NODES: 1
# WITNESS REGIONS: 365
# ACTIVE NODES: 366
# INACTIVE NODES: 1
# WITNESS REGIONS: 366
# ACTIVE NODES: 367
# INACTIVE NODES: 1
# WITNESS REGIONS: 367
# ACTIVE NODES: 367
# INACTIVE NODES: 1
# WITNESS REGIONS: 367
# ACTIVE NODES: 368
# INACTIVE NODES: 1
# WITNESS REGIONS: 368
# ACTIVE NODES: 368
# INACTIVE NODES: 1
# WITNESS REGIONS: 368
# ACTIVE NODES: 368
# INACTIVE NODES: 1
# WITNESS REGIONS: 368
# ACTIVE NODES: 368
# INACTIVE NODES: 1
# WITNESS REGIONS: 368
# ACTIVE NODES: 368
# INACTIVE NODES: 1
# WITNESS REGIONS: 368
# ACTIVE NODES: 368
# INACTIVE NODES: 1
# WITNESS REGIONS: 368
# ACTIVE NODES: 368
# INACTIVE NODES: 1
# WITNESS REGIONS: 368
# ACTIVE NODES: 369
# INACTIVE NODES: 1
# WITNESS REGIONS: 369
# ACTIVE NODES: 370
# INACTIVE NODES: 1
# WITNESS REGIONS: 370
# ACTIVE NODES: 370
# INACTIVE NODES: 1
# WITNESS REGIONS: 370
# ACTIVE NODES: 370
# INACTIVE NODES: 1
# WITNESS REGIONS: 370
# ACTIVE NODES: 371
# INACTIVE NODES: 1
# WITNESS REGIONS: 371
# ACTIVE NODES: 371
# INACTIVE NODES: 1
# WITNESS REGIONS: 371
# ACTIVE NODES: 372
# INACTIVE NODES: 1
# WITNESS REGIONS: 372
# ACTIVE NODES: 372
# INACTIVE NODES: 1
# WITNESS REGIONS: 372
# ACTIVE NODES: 373
# INACTIVE NODES: 1
# WITNESS REGIONS: 373
# ACTIVE NODES: 374
# INACTIVE NODES: 1
# WITNESS REGIONS: 374
# ACTIVE NODES: 374
# INACTIVE NODES: 1
# WITNESS REGIONS: 374
# ACTIVE NODES: 374
# INACTIVE NODES: 1
# WITNESS REGIONS: 374
# ACTIVE NODES: 375
# INACTIVE NODES: 1
# WITNESS REGIONS: 375
# ACTIVE NODES: 375
# INACTIVE NODES: 1
# WITNESS REGIONS: 375
# ACTIVE NODES: 375
# INACTIVE NODES: 1
# WITNESS REGIONS: 375
# ACTIVE NODES: 376
# INACTIVE NODES: 1
# WITNESS REGIONS: 376
# ACTIVE NODES: 377
# INACTIVE NODES: 1
# WITNESS REGIONS: 377
# ACTIVE NODES: 377
# INACTIVE NODES: 1
# WITNESS REGIONS: 377
# ACTIVE NODES: 378
# INACTIVE NODES: 1
# WITNESS REGIONS: 378
# ACTIVE NODES: 378
# INACTIVE NODES: 1
# WITNESS REGIONS: 378
# ACTIVE NODES: 378
# INACTIVE NODES: 1
# WITNESS REGIONS: 378
# ACTIVE NODES: 378
# INACTIVE NODES: 1
# WITNESS REGIONS: 378
# ACTIVE NODES: 379
# INACTIVE NODES: 1
# WITNESS REGIONS: 379
# ACTIVE NODES: 379
# INACTIVE NODES: 1
# WITNESS REGIONS: 379
# ACTIVE NODES: 379
# INACTIVE NODES: 1
# WITNESS REGIONS: 379
# ACTIVE NODES: 380
# INACTIVE NODES: 1
# WITNESS REGIONS: 380
# ACTIVE NODES: 380
# INACTIVE NODES: 1
# WITNESS REGIONS: 380
# ACTIVE NODES: 380
# INACTIVE NODES: 1
# WITNESS REGIONS: 380
# ACTIVE NODES: 381
# INACTIVE NODES: 1
# WITNESS REGIONS: 381
# ACTIVE NODES: 382
# INACTIVE NODES: 1
# WITNESS REGIONS: 382
# ACTIVE NODES: 382
# INACTIVE NODES: 1
# WITNESS REGIONS: 382
# ACTIVE NODES: 383
# INACTIVE NODES: 1
# WITNESS REGIONS: 383
# ACTIVE NODES: 383
# INACTIVE NODES: 1
# WITNESS REGIONS: 383
# ACTIVE NODES: 384
# INACTIVE NODES: 1
# WITNESS REGIONS: 384
# ACTIVE NODES: 385
# INACTIVE NODES: 1
# WITNESS REGIONS: 385
# ACTIVE NODES: 386
# INACTIVE NODES: 1
# WITNESS REGIONS: 386
# ACTIVE NODES: 387
# INACTIVE NODES: 1
# WITNESS REGIONS: 387
# ACTIVE NODES: 387
# INACTIVE NODES: 1
# WITNESS REGIONS: 387
# ACTIVE NODES: 388
# INACTIVE NODES: 1
# WITNESS REGIONS: 388
# ACTIVE NODES: 389
# INACTIVE NODES: 1
# WITNESS REGIONS: 389
# ACTIVE NODES: 390
# INACTIVE NODES: 1
# WITNESS REGIONS: 390
# ACTIVE NODES: 390
# INACTIVE NODES: 1
# WITNESS REGIONS: 390
# ACTIVE NODES: 391
# INACTIVE NODES: 1
# WITNESS REGIONS: 391
# ACTIVE NODES: 391
# INACTIVE NODES: 1
# WITNESS REGIONS: 391
# ACTIVE NODES: 392
# INACTIVE NODES: 1
# WITNESS REGIONS: 392
# ACTIVE NODES: 393
# INACTIVE NODES: 1
# WITNESS REGIONS: 393
# ACTIVE NODES: 393
# INACTIVE NODES: 1
# WITNESS REGIONS: 393
# ACTIVE NODES: 393
# INACTIVE NODES: 1
# WITNESS REGIONS: 393
# ACTIVE NODES: 393
# INACTIVE NODES: 1
# WITNESS REGIONS: 393
# ACTIVE NODES: 393
# INACTIVE NODES: 1
# WITNESS REGIONS: 393
# ACTIVE NODES: 394
# INACTIVE NODES: 1
# WITNESS REGIONS: 394
# ACTIVE NODES: 395
# INACTIVE NODES: 1
# WITNESS REGIONS: 395
# ACTIVE NODES: 396
# INACTIVE NODES: 1
# WITNESS REGIONS: 396
# ACTIVE NODES: 396
# INACTIVE NODES: 1
# WITNESS REGIONS: 396
# ACTIVE NODES: 396
# INACTIVE NODES: 1
# WITNESS REGIONS: 396
# ACTIVE NODES: 396
# INACTIVE NODES: 1
# WITNESS REGIONS: 396
# ACTIVE NODES: 397
# INACTIVE NODES: 1
# WITNESS REGIONS: 397
# ACTIVE NODES: 398
# INACTIVE NODES: 1
# WITNESS REGIONS: 398
# ACTIVE NODES: 399
# INACTIVE NODES: 1
# WITNESS REGIONS: 399
# ACTIVE NODES: 399
# INACTIVE NODES: 1
# WITNESS REGIONS: 399
# ACTIVE NODES: 400
# INACTIVE NODES: 1
# WITNESS REGIONS: 400
# ACTIVE NODES: 401
# INACTIVE NODES: 1
# WITNESS REGIONS: 401
# ACTIVE NODES: 401
# INACTIVE NODES: 1
# WITNESS REGIONS: 401
# ACTIVE NODES: 402
# INACTIVE NODES: 1
# WITNESS REGIONS: 402
# ACTIVE NODES: 403
# INACTIVE NODES: 1
# WITNESS REGIONS: 403
# ACTIVE NODES: 404
# INACTIVE NODES: 1
# WITNESS REGIONS: 404
# ACTIVE NODES: 405
# INACTIVE NODES: 1
# WITNESS REGIONS: 405
# ACTIVE NODES: 406
# INACTIVE NODES: 1
# WITNESS REGIONS: 406
# ACTIVE NODES: 407
# INACTIVE NODES: 1
# WITNESS REGIONS: 407
# ACTIVE NODES: 407
# INACTIVE NODES: 1
# WITNESS REGIONS: 407
# ACTIVE NODES: 407
# INACTIVE NODES: 1
# WITNESS REGIONS: 407
# ACTIVE NODES: 408
# INACTIVE NODES: 1
# WITNESS REGIONS: 408
# ACTIVE NODES: 409
# INACTIVE NODES: 1
# WITNESS REGIONS: 409
# ACTIVE NODES: 410
# INACTIVE NODES: 1
# WITNESS REGIONS: 410
# ACTIVE NODES: 410
# INACTIVE NODES: 1
# WITNESS REGIONS: 410
# ACTIVE NODES: 410
# INACTIVE NODES: 1
# WITNESS REGIONS: 410
# ACTIVE NODES: 410
# INACTIVE NODES: 1
# WITNESS REGIONS: 410
# ACTIVE NODES: 411
# INACTIVE NODES: 1
# WITNESS REGIONS: 411
# ACTIVE NODES: 412
# INACTIVE NODES: 1
# WITNESS REGIONS: 412
# ACTIVE NODES: 413
# INACTIVE NODES: 1
# WITNESS REGIONS: 413
# ACTIVE NODES: 414
# INACTIVE NODES: 1
# WITNESS REGIONS: 414
# ACTIVE NODES: 414
# INACTIVE NODES: 1
# WITNESS REGIONS: 414
# ACTIVE NODES: 415
# INACTIVE NODES: 1
# WITNESS REGIONS: 415
# ACTIVE NODES: 415
# INACTIVE NODES: 1
# WITNESS REGIONS: 415
# ACTIVE NODES: 415
# INACTIVE NODES: 1
# WITNESS REGIONS: 415
# ACTIVE NODES: 416
# INACTIVE NODES: 1
# WITNESS REGIONS: 416
# ACTIVE NODES: 416
# INACTIVE NODES: 1
# WITNESS REGIONS: 416
# ACTIVE NODES: 416
# INACTIVE NODES: 1
# WITNESS REGIONS: 416
# ACTIVE NODES: 417
# INACTIVE NODES: 1
# WITNESS REGIONS: 417
# ACTIVE NODES: 418
# INACTIVE NODES: 1
# WITNESS REGIONS: 418
# ACTIVE NODES: 418
# INACTIVE NODES: 1
# WITNESS REGIONS: 418
# ACTIVE NODES: 418
# INACTIVE NODES: 1
# WITNESS REGIONS: 418
# ACTIVE NODES: 419
# INACTIVE NODES: 1
# WITNESS REGIONS: 419
# ACTIVE NODES: 420
# INACTIVE NODES: 1
# WITNESS REGIONS: 420
# ACTIVE NODES: 421
# INACTIVE NODES: 1
# WITNESS REGIONS: 421
# ACTIVE NODES: 421
# INACTIVE NODES: 1
# WITNESS REGIONS: 421
# ACTIVE NODES: 422
# INACTIVE NODES: 1
# WITNESS REGIONS: 422
# ACTIVE NODES: 422
# INACTIVE NODES: 1
# WITNESS REGIONS: 422
# ACTIVE NODES: 423
# INACTIVE NODES: 1
# WITNESS REGIONS: 423
# ACTIVE NODES: 424
# INACTIVE NODES: 1
# WITNESS REGIONS: 424
# ACTIVE NODES: 424
# INACTIVE NODES: 1
# WITNESS REGIONS: 424
# ACTIVE NODES: 425
# INACTIVE NODES: 1
# WITNESS REGIONS: 425
# ACTIVE NODES: 426
# INACTIVE NODES: 1
# WITNESS REGIONS: 426
# ACTIVE NODES: 426
# INACTIVE NODES: 1
# WITNESS REGIONS: 426
# ACTIVE NODES: 427
# INACTIVE NODES: 1
# WITNESS REGIONS: 427
# ACTIVE NODES: 428
# INACTIVE NODES: 1
# WITNESS REGIONS: 428
# ACTIVE NODES: 429
# INACTIVE NODES: 1
# WITNESS REGIONS: 429
# ACTIVE NODES: 429
# INACTIVE NODES: 1
# WITNESS REGIONS: 429
# ACTIVE NODES: 429
# INACTIVE NODES: 1
# WITNESS REGIONS: 429
# ACTIVE NODES: 430
# INACTIVE NODES: 1
# WITNESS REGIONS: 430
# ACTIVE NODES: 431
# INACTIVE NODES: 1
# WITNESS REGIONS: 431
# ACTIVE NODES: 432
# INACTIVE NODES: 1
# WITNESS REGIONS: 432
# ACTIVE NODES: 433
# INACTIVE NODES: 1
# WITNESS REGIONS: 433
# ACTIVE NODES: 434
# INACTIVE NODES: 1
# WITNESS REGIONS: 434
# ACTIVE NODES: 435
# INACTIVE NODES: 1
# WITNESS REGIONS: 435
# ACTIVE NODES: 436
# INACTIVE NODES: 1
# WITNESS REGIONS: 436
# ACTIVE NODES: 436
# INACTIVE NODES: 1
# WITNESS REGIONS: 436
# ACTIVE NODES: 436
# INACTIVE NODES: 1
# WITNESS REGIONS: 436
# ACTIVE NODES: 437
# INACTIVE NODES: 1
# WITNESS REGIONS: 437
# ACTIVE NODES: 437
# INACTIVE NODES: 1
# WITNESS REGIONS: 437
# ACTIVE NODES: 437
# INACTIVE NODES: 1
# WITNESS REGIONS: 437
# ACTIVE NODES: 438
# INACTIVE NODES: 1
# WITNESS REGIONS: 438
# ACTIVE NODES: 439
# INACTIVE NODES: 1
# WITNESS REGIONS: 439
# ACTIVE NODES: 440
# INACTIVE NODES: 1
# WITNESS REGIONS: 440
# ACTIVE NODES: 441
# INACTIVE NODES: 1
# WITNESS REGIONS: 441
# ACTIVE NODES: 442
# INACTIVE NODES: 1
# WITNESS REGIONS: 442
# ACTIVE NODES: 443
# INACTIVE NODES: 1
# WITNESS REGIONS: 443
# ACTIVE NODES: 444
# INACTIVE NODES: 1
# WITNESS REGIONS: 444
# ACTIVE NODES: 445
# INACTIVE NODES: 1
# WITNESS REGIONS: 445
# ACTIVE NODES: 445
# INACTIVE NODES: 1
# WITNESS REGIONS: 445
# ACTIVE NODES: 446
# INACTIVE NODES: 1
# WITNESS REGIONS: 446
# ACTIVE NODES: 447
# INACTIVE NODES: 1
# WITNESS REGIONS: 447
# ACTIVE NODES: 447
# INACTIVE NODES: 1
# WITNESS REGIONS: 447
# ACTIVE NODES: 448
# INACTIVE NODES: 1
# WITNESS REGIONS: 448
# ACTIVE NODES: 448
# INACTIVE NODES: 1
# WITNESS REGIONS: 448
# ACTIVE NODES: 449
# INACTIVE NODES: 1
# WITNESS REGIONS: 449
# ACTIVE NODES: 449
# INACTIVE NODES: 1
# WITNESS REGIONS: 449
# ACTIVE NODES: 450
# INACTIVE NODES: 1
# WITNESS REGIONS: 450
# ACTIVE NODES: 451
# INACTIVE NODES: 1
# WITNESS REGIONS: 451
# ACTIVE NODES: 452
# INACTIVE NODES: 1
# WITNESS REGIONS: 452
# ACTIVE NODES: 452
# INACTIVE NODES: 1
# WITNESS REGIONS: 452
# ACTIVE NODES: 453
# INACTIVE NODES: 1
# WITNESS REGIONS: 453
# ACTIVE NODES: 453
# INACTIVE NODES: 1
# WITNESS REGIONS: 453
# ACTIVE NODES: 453
# INACTIVE NODES: 1
# WITNESS REGIONS: 453
# ACTIVE NODES: 454
# INACTIVE NODES: 1
# WITNESS REGIONS: 454
# ACTIVE NODES: 454
# INACTIVE NODES: 1
# WITNESS REGIONS: 454
# ACTIVE NODES: 455
# INACTIVE NODES: 1
# WITNESS REGIONS: 455
# ACTIVE NODES: 456
# INACTIVE NODES: 1
# WITNESS REGIONS: 456
# ACTIVE NODES: 457
# INACTIVE NODES: 1
# WITNESS REGIONS: 457
# ACTIVE NODES: 458
# INACTIVE NODES: 1
# WITNESS REGIONS: 458
# ACTIVE NODES: 459
# INACTIVE NODES: 1
# WITNESS REGIONS: 459
# ACTIVE NODES: 460
# INACTIVE NODES: 1
# WITNESS REGIONS: 460
# ACTIVE NODES: 461
# INACTIVE NODES: 1
# WITNESS REGIONS: 461
# ACTIVE NODES: 462
# INACTIVE NODES: 1
# WITNESS REGIONS: 462
# ACTIVE NODES: 462
# INACTIVE NODES: 1
# WITNESS REGIONS: 462
# ACTIVE NODES: 463
# INACTIVE NODES: 1
# WITNESS REGIONS: 463
# ACTIVE NODES: 464
# INACTIVE NODES: 1
# WITNESS REGIONS: 464
# ACTIVE NODES: 465
# INACTIVE NODES: 1
# WITNESS REGIONS: 465
# ACTIVE NODES: 465
# INACTIVE NODES: 1
# WITNESS REGIONS: 465
# ACTIVE NODES: 466
# INACTIVE NODES: 1
# WITNESS REGIONS: 466
# ACTIVE NODES: 467
# INACTIVE NODES: 1
# WITNESS REGIONS: 467
# ACTIVE NODES: 468
# INACTIVE NODES: 1
# WITNESS REGIONS: 468
# ACTIVE NODES: 469
# INACTIVE NODES: 1
# WITNESS REGIONS: 469
# ACTIVE NODES: 470
# INACTIVE NODES: 1
# WITNESS REGIONS: 470
# ACTIVE NODES: 471
# INACTIVE NODES: 1
# WITNESS REGIONS: 471
# ACTIVE NODES: 472
# INACTIVE NODES: 1
# WITNESS REGIONS: 472
# ACTIVE NODES: 473
# INACTIVE NODES: 1
# WITNESS REGIONS: 473
# ACTIVE NODES: 474
# INACTIVE NODES: 1
# WITNESS REGIONS: 474
# ACTIVE NODES: 475
# INACTIVE NODES: 1
# WITNESS REGIONS: 475
# ACTIVE NODES: 476
# INACTIVE NODES: 1
# WITNESS REGIONS: 476
# ACTIVE NODES: 477
# INACTIVE NODES: 1
# WITNESS REGIONS: 477
# ACTIVE NODES: 478
# INACTIVE NODES: 1
# WITNESS REGIONS: 478
# ACTIVE NODES: 479
# INACTIVE NODES: 1
# WITNESS REGIONS: 479
# ACTIVE NODES: 480
# INACTIVE NODES: 1
# WITNESS REGIONS: 480
# ACTIVE NODES: 481
# INACTIVE NODES: 1
# WITNESS REGIONS: 481
# ACTIVE NODES: 481
# INACTIVE NODES: 1
# WITNESS REGIONS: 481
# ACTIVE NODES: 482
# INACTIVE NODES: 1
# WITNESS REGIONS: 482
# ACTIVE NODES: 483
# INACTIVE NODES: 1
# WITNESS REGIONS: 483
# ACTIVE NODES: 484
# INACTIVE NODES: 1
# WITNESS REGIONS: 484
# ACTIVE NODES: 485
# INACTIVE NODES: 1
# WITNESS REGIONS: 485
# ACTIVE NODES: 486
# INACTIVE NODES: 1
# WITNESS REGIONS: 486
# ACTIVE NODES: 487
# INACTIVE NODES: 1
# WITNESS REGIONS: 487
# ACTIVE NODES: 488
# INACTIVE NODES: 1
# WITNESS REGIONS: 488
# ACTIVE NODES: 488
# INACTIVE NODES: 1
# WITNESS REGIONS: 488
# ACTIVE NODES: 489
# INACTIVE NODES: 1
# WITNESS REGIONS: 489
# ACTIVE NODES: 489
# INACTIVE NODES: 1
# WITNESS REGIONS: 489
# ACTIVE NODES: 489
# INACTIVE NODES: 1
# WITNESS REGIONS: 489
# ACTIVE NODES: 490
# INACTIVE NODES: 1
# WITNESS REGIONS: 490
# ACTIVE NODES: 491
# INACTIVE NODES: 1
# WITNESS REGIONS: 491
# ACTIVE NODES: 492
# INACTIVE NODES: 1
# WITNESS REGIONS: 492
# ACTIVE NODES: 493
# INACTIVE NODES: 1
# WITNESS REGIONS: 493
# ACTIVE NODES: 493
# INACTIVE NODES: 1
# WITNESS REGIONS: 493
# ACTIVE NODES: 493
# INACTIVE NODES: 1
# WITNESS REGIONS: 493
# ACTIVE NODES: 494
# INACTIVE NODES: 1
# WITNESS REGIONS: 494
# ACTIVE NODES: 495
# INACTIVE NODES: 1
# WITNESS REGIONS: 495
# ACTIVE NODES: 496
# INACTIVE NODES: 1
# WITNESS REGIONS: 496
# ACTIVE NODES: 497
# INACTIVE NODES: 1
# WITNESS REGIONS: 497
# ACTIVE NODES: 497
# INACTIVE NODES: 1
# WITNESS REGIONS: 497
# ACTIVE NODES: 497
# INACTIVE NODES: 1
# WITNESS REGIONS: 497
# ACTIVE NODES: 498
# INACTIVE NODES: 1
# WITNESS REGIONS: 498
# ACTIVE NODES: 499
# INACTIVE NODES: 1
# WITNESS REGIONS: 499
# ACTIVE NODES: 500
# INACTIVE NODES: 1
# WITNESS REGIONS: 500
# ACTIVE NODES: 501
# INACTIVE NODES: 1
# WITNESS REGIONS: 501
# ACTIVE NODES: 502
# INACTIVE NODES: 1
# WITNESS REGIONS: 502
# ACTIVE NODES: 502
# INACTIVE NODES: 1
# WITNESS REGIONS: 502
# ACTIVE NODES: 503
# INACTIVE NODES: 1
# WITNESS REGIONS: 503
# ACTIVE NODES: 504
# INACTIVE NODES: 1
# WITNESS REGIONS: 504
# ACTIVE NODES: 505
# INACTIVE NODES: 1
# WITNESS REGIONS: 505
# ACTIVE NODES: 506
# INACTIVE NODES: 1
# WITNESS REGIONS: 506
# ACTIVE NODES: 506
# INACTIVE NODES: 1
# WITNESS REGIONS: 506
# ACTIVE NODES: 507
# INACTIVE NODES: 1
# WITNESS REGIONS: 507
# ACTIVE NODES: 508
# INACTIVE NODES: 1
# WITNESS REGIONS: 508
# ACTIVE NODES: 509
# INACTIVE NODES: 1
# WITNESS REGIONS: 509
# ACTIVE NODES: 510
# INACTIVE NODES: 1
# WITNESS REGIONS: 510
# ACTIVE NODES: 511
# INACTIVE NODES: 1
# WITNESS REGIONS: 511
# ACTIVE NODES: 512
# INACTIVE NODES: 1
# WITNESS REGIONS: 512
# ACTIVE NODES: 513
# INACTIVE NODES: 1
# WITNESS REGIONS: 513
# ACTIVE NODES: 513
# INACTIVE NODES: 1
# WITNESS REGIONS: 513
# ACTIVE NODES: 514
# INACTIVE NODES: 1
# WITNESS REGIONS: 514
# ACTIVE NODES: 515
# INACTIVE NODES: 1
# WITNESS REGIONS: 515
# ACTIVE NODES: 516
# INACTIVE NODES: 1
# WITNESS REGIONS: 516
# ACTIVE NODES: 517
# INACTIVE NODES: 1
# WITNESS REGIONS: 517
# ACTIVE NODES: 518
# INACTIVE NODES: 1
# WITNESS REGIONS: 518
# ACTIVE NODES: 519
# INACTIVE NODES: 1
# WITNESS REGIONS: 519
# ACTIVE NODES: 520
# INACTIVE NODES: 1
# WITNESS REGIONS: 520
# ACTIVE NODES: 521
# INACTIVE NODES: 1
# WITNESS REGIONS: 521
# ACTIVE NODES: 522
# INACTIVE NODES: 1
# WITNESS REGIONS: 522
# ACTIVE NODES: 523
# INACTIVE NODES: 1
# WITNESS REGIONS: 523
# ACTIVE NODES: 524
# INACTIVE NODES: 1
# WITNESS REGIONS: 524
# ACTIVE NODES: 524
# INACTIVE NODES: 1
# WITNESS REGIONS: 524
# ACTIVE NODES: 525
# INACTIVE NODES: 1
# WITNESS REGIONS: 525
# ACTIVE NODES: 526
# INACTIVE NODES: 1
# WITNESS REGIONS: 526
# ACTIVE NODES: 527
# INACTIVE NODES: 1
# WITNESS REGIONS: 527
# ACTIVE NODES: 528
# INACTIVE NODES: 1
# WITNESS REGIONS: 528
# ACTIVE NODES: 529
# INACTIVE NODES: 1
# WITNESS REGIONS: 529
# ACTIVE NODES: 530
# INACTIVE NODES: 1
# WITNESS REGIONS: 530
# ACTIVE NODES: 531
# INACTIVE NODES: 1
# WITNESS REGIONS: 531
# ACTIVE NODES: 531
# INACTIVE NODES: 1
# WITNESS REGIONS: 531
# ACTIVE NODES: 532
# INACTIVE NODES: 1
# WITNESS REGIONS: 532
# ACTIVE NODES: 533
# INACTIVE NODES: 1
# WITNESS REGIONS: 533
# ACTIVE NODES: 534
# INACTIVE NODES: 1
# WITNESS REGIONS: 534
# ACTIVE NODES: 534
# INACTIVE NODES: 1
# WITNESS REGIONS: 534
# ACTIVE NODES: 535
# INACTIVE NODES: 1
# WITNESS REGIONS: 535
# ACTIVE NODES: 535
# INACTIVE NODES: 1
# WITNESS REGIONS: 535
# ACTIVE NODES: 535
# INACTIVE NODES: 1
# WITNESS REGIONS: 535
# ACTIVE NODES: 536
# INACTIVE NODES: 1
# WITNESS REGIONS: 536
# ACTIVE NODES: 536
# INACTIVE NODES: 1
# WITNESS REGIONS: 536
# ACTIVE NODES: 537
# INACTIVE NODES: 1
# WITNESS REGIONS: 537
# ACTIVE NODES: 538
# INACTIVE NODES: 1
# WITNESS REGIONS: 538
# ACTIVE NODES: 539
# INACTIVE NODES: 1
# WITNESS REGIONS: 539
# ACTIVE NODES: 540
# INACTIVE NODES: 1
# WITNESS REGIONS: 540
# ACTIVE NODES: 541
# INACTIVE NODES: 1
# WITNESS REGIONS: 541
# ACTIVE NODES: 542
# INACTIVE NODES: 1
# WITNESS REGIONS: 542
# ACTIVE NODES: 543
# INACTIVE NODES: 1
# WITNESS REGIONS: 543
# ACTIVE NODES: 543
# INACTIVE NODES: 1
# WITNESS REGIONS: 543
# ACTIVE NODES: 544
# INACTIVE NODES: 1
# WITNESS REGIONS: 544
# ACTIVE NODES: 545
# INACTIVE NODES: 1
# WITNESS REGIONS: 545
# ACTIVE NODES: 546
# INACTIVE NODES: 1
# WITNESS REGIONS: 546
# ACTIVE NODES: 547
# ...
# INACTIVE NODES: 104
# WITNESS REGIONS: 6541
# ACTIVE NODES: 6542
# INACTIVE NODES: 104
# WITNESS REGIONS: 6542
# ACTIVE NODES: 6543
# INACTIVE NODES: 104
# WITNESS REGIONS: 6543
# ACTIVE NODES: 6544
# INACTIVE NODES: 104
# WITNESS REGIONS: 6544
# ACTIVE NODES: 6545
# INACTIVE NODES: 104
# WITNESS REGIONS: 6545
# ACTIVE NODES: 6546
# INACTIVE NODES: 104
# WITNESS REGIONS: 6546
# ACTIVE NODES: 6546
# INACTIVE NODES: 104
# WITNESS REGIONS: 6546
# ACTIVE NODES: 6546
# INACTIVE NODES: 104
# WITNESS REGIONS: 6546
# ACTIVE NODES: 6546
# INACTIVE NODES: 104
# WITNESS REGIONS: 6546
# ACTIVE NODES: 6547
# INACTIVE NODES: 104
# WITNESS REGIONS: 6547
# ACTIVE NODES: 6547
# INACTIVE NODES: 104
# WITNESS REGIONS: 6547
# ACTIVE NODES: 6547
# INACTIVE NODES: 104
# WITNESS REGIONS: 6547
# ACTIVE NODES: 6548
# INACTIVE NODES: 104
# WITNESS REGIONS: 6548
# <__main__.Vertice object at 0x000001F88F457580>
# <__main__.Vertice object at 0x000001F8C3665100>
# ACTIVE NODES: 6548
# INACTIVE NODES: 104
# WITNESS REGIONS: 6548
# ACTIVE NODES: 6549
# INACTIVE NODES: 104
# WITNESS REGIONS: 6549
# ACTIVE NODES: 6549
# INACTIVE NODES: 104
# WITNESS REGIONS: 6549
# ACTIVE NODES: 6550
# INACTIVE NODES: 104
# WITNESS REGIONS: 6550
# ACTIVE NODES: 6551
# INACTIVE NODES: 104
# WITNESS REGIONS: 6551
# ACTIVE NODES: 6552
# INACTIVE NODES: 104
# WITNESS REGIONS: 6552
# ACTIVE NODES: 6553
# INACTIVE NODES: 104
# WITNESS REGIONS: 6553
# ACTIVE NODES: 6554
# INACTIVE NODES: 104
# WITNESS REGIONS: 6554
# ACTIVE NODES: 6555
# INACTIVE NODES: 104
# WITNESS REGIONS: 6555
# ACTIVE NODES: 6556
# INACTIVE NODES: 104
# WITNESS REGIONS: 6556
# ACTIVE NODES: 6557
# INACTIVE NODES: 104
# WITNESS REGIONS: 6557
# ACTIVE NODES: 6557
# INACTIVE NODES: 104
# WITNESS REGIONS: 6557
# ACTIVE NODES: 6558
# INACTIVE NODES: 104
# WITNESS REGIONS: 6558
# ACTIVE NODES: 6559
# INACTIVE NODES: 104
# WITNESS REGIONS: 6559
# ACTIVE NODES: 6560
# INACTIVE NODES: 104
# WITNESS REGIONS: 6560
# ACTIVE NODES: 6560
# INACTIVE NODES: 104
# WITNESS REGIONS: 6560
# ACTIVE NODES: 6561
# INACTIVE NODES: 104
# WITNESS REGIONS: 6561
# ACTIVE NODES: 6562
# INACTIVE NODES: 104
# WITNESS REGIONS: 6562
# ACTIVE NODES: 6563
# INACTIVE NODES: 104
# WITNESS REGIONS: 6563
# ACTIVE NODES: 6563
# INACTIVE NODES: 104
# WITNESS REGIONS: 6563
# ACTIVE NODES: 6564
# INACTIVE NODES: 104
# WITNESS REGIONS: 6564
# ACTIVE NODES: 6564
# INACTIVE NODES: 104
# WITNESS REGIONS: 6564
# ACTIVE NODES: 6565
# INACTIVE NODES: 104
# WITNESS REGIONS: 6565
# ACTIVE NODES: 6566
# INACTIVE NODES: 104
# WITNESS REGIONS: 6566
# ACTIVE NODES: 6567
# INACTIVE NODES: 104
# WITNESS REGIONS: 6567
# ACTIVE NODES: 6568
# INACTIVE NODES: 104
# WITNESS REGIONS: 6568
# ACTIVE NODES: 6568
# INACTIVE NODES: 104
# WITNESS REGIONS: 6568
# ACTIVE NODES: 6569
# INACTIVE NODES: 104
# WITNESS REGIONS: 6569
# ACTIVE NODES: 6569
# INACTIVE NODES: 104
# WITNESS REGIONS: 6569
# ACTIVE NODES: 6570
# INACTIVE NODES: 104
# WITNESS REGIONS: 6570
# ACTIVE NODES: 6571
# INACTIVE NODES: 104
# WITNESS REGIONS: 6571
# ACTIVE NODES: 6571
# INACTIVE NODES: 104
# WITNESS REGIONS: 6571
# ACTIVE NODES: 6572
# INACTIVE NODES: 104
# WITNESS REGIONS: 6572
# ACTIVE NODES: 6573
# INACTIVE NODES: 104
# WITNESS REGIONS: 6573
# ACTIVE NODES: 6573
# INACTIVE NODES: 104
# WITNESS REGIONS: 6573
# ACTIVE NODES: 6573
# INACTIVE NODES: 104
# WITNESS REGIONS: 6573
# ACTIVE NODES: 6574
# INACTIVE NODES: 104
# WITNESS REGIONS: 6574
# ACTIVE NODES: 6574
# INACTIVE NODES: 104
# WITNESS REGIONS: 6574
# ACTIVE NODES: 6574
# INACTIVE NODES: 104
# WITNESS REGIONS: 6574
# ACTIVE NODES: 6575
# INACTIVE NODES: 104
# WITNESS REGIONS: 6575
# ACTIVE NODES: 6576
# INACTIVE NODES: 104
# WITNESS REGIONS: 6576
# ACTIVE NODES: 6577
# INACTIVE NODES: 104
# WITNESS REGIONS: 6577
# ACTIVE NODES: 6578
# INACTIVE NODES: 104
# WITNESS REGIONS: 6578
# ACTIVE NODES: 6579
# INACTIVE NODES: 104
# WITNESS REGIONS: 6579
# ACTIVE NODES: 6580
# INACTIVE NODES: 104
# WITNESS REGIONS: 6580
# ACTIVE NODES: 6581
# INACTIVE NODES: 104
# WITNESS REGIONS: 6581
# ACTIVE NODES: 6582
# INACTIVE NODES: 104
# WITNESS REGIONS: 6582
# ACTIVE NODES: 6583
# INACTIVE NODES: 104
# WITNESS REGIONS: 6583
# ACTIVE NODES: 6583
# INACTIVE NODES: 104
# WITNESS REGIONS: 6583
# ACTIVE NODES: 6584
# INACTIVE NODES: 104
# WITNESS REGIONS: 6584
# ACTIVE NODES: 6584
# INACTIVE NODES: 105
# WITNESS REGIONS: 6584
# ACTIVE NODES: 6584
# INACTIVE NODES: 105
# WITNESS REGIONS: 6584
# ACTIVE NODES: 6585
# INACTIVE NODES: 105
# WITNESS REGIONS: 6585
# ACTIVE NODES: 6586
# INACTIVE NODES: 105
# WITNESS REGIONS: 6586
# ACTIVE NODES: 6587
# INACTIVE NODES: 105
# WITNESS REGIONS: 6587
# ACTIVE NODES: 6588
# INACTIVE NODES: 105
# WITNESS REGIONS: 6588
# ACTIVE NODES: 6588
# INACTIVE NODES: 105
# WITNESS REGIONS: 6588
# ACTIVE NODES: 6589
# INACTIVE NODES: 105
# WITNESS REGIONS: 6589
# ACTIVE NODES: 6590
# INACTIVE NODES: 105
# WITNESS REGIONS: 6590
# ACTIVE NODES: 6591
# INACTIVE NODES: 105
# WITNESS REGIONS: 6591
# ACTIVE NODES: 6592
# INACTIVE NODES: 105
# WITNESS REGIONS: 6592
# ACTIVE NODES: 6593
# INACTIVE NODES: 105
# WITNESS REGIONS: 6593
# ACTIVE NODES: 6594
# INACTIVE NODES: 105
# WITNESS REGIONS: 6594
# ACTIVE NODES: 6594
# INACTIVE NODES: 105
# WITNESS REGIONS: 6594
# ACTIVE NODES: 6595
# INACTIVE NODES: 105
# WITNESS REGIONS: 6595
# ACTIVE NODES: 6596
# INACTIVE NODES: 105
# WITNESS REGIONS: 6596
# ACTIVE NODES: 6596
# INACTIVE NODES: 105
# WITNESS REGIONS: 6596
# ACTIVE NODES: 6597
# INACTIVE NODES: 105
# WITNESS REGIONS: 6597
# ACTIVE NODES: 6598
# INACTIVE NODES: 105
# WITNESS REGIONS: 6598
# ACTIVE NODES: 6599
# INACTIVE NODES: 105
# WITNESS REGIONS: 6599
# ACTIVE NODES: 6600
# INACTIVE NODES: 105
# WITNESS REGIONS: 6600
# ACTIVE NODES: 6601
# INACTIVE NODES: 105
# WITNESS REGIONS: 6601
# ACTIVE NODES: 6601
# INACTIVE NODES: 105
# WITNESS REGIONS: 6601
# ACTIVE NODES: 6602
# INACTIVE NODES: 105
# WITNESS REGIONS: 6602
# ACTIVE NODES: 6603
# INACTIVE NODES: 105
# WITNESS REGIONS: 6603
# ACTIVE NODES: 6603
# INACTIVE NODES: 106
# WITNESS REGIONS: 6603
# ACTIVE NODES: 6604
# INACTIVE NODES: 106
# WITNESS REGIONS: 6604
# ACTIVE NODES: 6605
# INACTIVE NODES: 106
# WITNESS REGIONS: 6605
# ACTIVE NODES: 6606
# INACTIVE NODES: 106
# WITNESS REGIONS: 6606
# ACTIVE NODES: 6607
# INACTIVE NODES: 106
# WITNESS REGIONS: 6607
# ACTIVE NODES: 6608
# INACTIVE NODES: 106
# WITNESS REGIONS: 6608
# ACTIVE NODES: 6609
# INACTIVE NODES: 106
# WITNESS REGIONS: 6609
# ACTIVE NODES: 6610
# INACTIVE NODES: 106
# WITNESS REGIONS: 6610
# ACTIVE NODES: 6610
# INACTIVE NODES: 106
# WITNESS REGIONS: 6610
# ACTIVE NODES: 6611
# INACTIVE NODES: 106
# WITNESS REGIONS: 6611
# ACTIVE NODES: 6612
# INACTIVE NODES: 106
# WITNESS REGIONS: 6612
# ACTIVE NODES: 6612
# INACTIVE NODES: 106
# WITNESS REGIONS: 6612
# ACTIVE NODES: 6612
# INACTIVE NODES: 106
# WITNESS REGIONS: 6612
# ACTIVE NODES: 6612
# INACTIVE NODES: 106
# WITNESS REGIONS: 6612
# ACTIVE NODES: 6613
# INACTIVE NODES: 106
# WITNESS REGIONS: 6613
# ACTIVE NODES: 6613
# INACTIVE NODES: 106
# WITNESS REGIONS: 6613
# ACTIVE NODES: 6614
# INACTIVE NODES: 106
# WITNESS REGIONS: 6614
# ACTIVE NODES: 6615
# INACTIVE NODES: 106
# WITNESS REGIONS: 6615
# ACTIVE NODES: 6616
# INACTIVE NODES: 106
# WITNESS REGIONS: 6616
# ACTIVE NODES: 6617
# INACTIVE NODES: 106
# WITNESS REGIONS: 6617
# ACTIVE NODES: 6617
# INACTIVE NODES: 106
# WITNESS REGIONS: 6617
# ACTIVE NODES: 6617
# INACTIVE NODES: 106
# WITNESS REGIONS: 6617
# ACTIVE NODES: 6618
# INACTIVE NODES: 106
# WITNESS REGIONS: 6618
# ACTIVE NODES: 6618
# INACTIVE NODES: 106
# WITNESS REGIONS: 6618
# ACTIVE NODES: 6619
# INACTIVE NODES: 106
# WITNESS REGIONS: 6619
# ACTIVE NODES: 6620
# INACTIVE NODES: 106
# WITNESS REGIONS: 6620
# ACTIVE NODES: 6621
# INACTIVE NODES: 106
# WITNESS REGIONS: 6621
# ACTIVE NODES: 6621
# INACTIVE NODES: 106
# WITNESS REGIONS: 6621
# ACTIVE NODES: 6622
# INACTIVE NODES: 106
# WITNESS REGIONS: 6622
# ACTIVE NODES: 6623
# INACTIVE NODES: 106
# WITNESS REGIONS: 6623
# ACTIVE NODES: 6624
# INACTIVE NODES: 106
# WITNESS REGIONS: 6624
# ACTIVE NODES: 6625
# INACTIVE NODES: 106
# WITNESS REGIONS: 6625
# ACTIVE NODES: 6626
# INACTIVE NODES: 106
# WITNESS REGIONS: 6626
# ACTIVE NODES: 6626
# INACTIVE NODES: 106
# WITNESS REGIONS: 6626
# ACTIVE NODES: 6626
# INACTIVE NODES: 106
# WITNESS REGIONS: 6626
# ACTIVE NODES: 6627
# INACTIVE NODES: 106
# WITNESS REGIONS: 6627
# ACTIVE NODES: 6628
# INACTIVE NODES: 106
# WITNESS REGIONS: 6628
# ACTIVE NODES: 6629
# INACTIVE NODES: 106
# WITNESS REGIONS: 6629
# ACTIVE NODES: 6630
# INACTIVE NODES: 106
# WITNESS REGIONS: 6630
# ACTIVE NODES: 6630
# INACTIVE NODES: 106
# WITNESS REGIONS: 6630
# ACTIVE NODES: 6630
# INACTIVE NODES: 106
# WITNESS REGIONS: 6630
# ACTIVE NODES: 6631
# INACTIVE NODES: 106
# WITNESS REGIONS: 6631
# ACTIVE NODES: 6632
# INACTIVE NODES: 106
# WITNESS REGIONS: 6632
# ACTIVE NODES: 6632
# INACTIVE NODES: 106
# WITNESS REGIONS: 6632
# ACTIVE NODES: 6633
# INACTIVE NODES: 106
# WITNESS REGIONS: 6633
# ACTIVE NODES: 6634
# INACTIVE NODES: 106
# WITNESS REGIONS: 6634
# ACTIVE NODES: 6635
# INACTIVE NODES: 106
# WITNESS REGIONS: 6635
# ACTIVE NODES: 6636
# INACTIVE NODES: 106
# WITNESS REGIONS: 6636
# ACTIVE NODES: 6637
# INACTIVE NODES: 106
# WITNESS REGIONS: 6637
# ACTIVE NODES: 6638
# INACTIVE NODES: 106
# WITNESS REGIONS: 6638
# ACTIVE NODES: 6639
# INACTIVE NODES: 106
# WITNESS REGIONS: 6639
# ACTIVE NODES: 6640
# INACTIVE NODES: 106
# WITNESS REGIONS: 6640
# ACTIVE NODES: 6641
# INACTIVE NODES: 106
# WITNESS REGIONS: 6641
# ACTIVE NODES: 6642
# INACTIVE NODES: 106
# WITNESS REGIONS: 6642
# ACTIVE NODES: 6642
# INACTIVE NODES: 106
# WITNESS REGIONS: 6642
# ACTIVE NODES: 6643
# INACTIVE NODES: 106
# WITNESS REGIONS: 6643
# ACTIVE NODES: 6644
# INACTIVE NODES: 106
# WITNESS REGIONS: 6644
# ACTIVE NODES: 6645
# INACTIVE NODES: 106
# WITNESS REGIONS: 6645
# ACTIVE NODES: 6645
# INACTIVE NODES: 106
# WITNESS REGIONS: 6645
# ACTIVE NODES: 6646
# INACTIVE NODES: 106
# WITNESS REGIONS: 6646
# ACTIVE NODES: 6647
# INACTIVE NODES: 106
# WITNESS REGIONS: 6647
# ACTIVE NODES: 6648
# INACTIVE NODES: 106
# WITNESS REGIONS: 6648
# ACTIVE NODES: 6649
# INACTIVE NODES: 106
# WITNESS REGIONS: 6649
# ACTIVE NODES: 6649
# INACTIVE NODES: 106
# WITNESS REGIONS: 6649
# ACTIVE NODES: 6650
# INACTIVE NODES: 106
# WITNESS REGIONS: 6650
# ACTIVE NODES: 6651
# INACTIVE NODES: 106
# WITNESS REGIONS: 6651
# ACTIVE NODES: 6652
# INACTIVE NODES: 106
# WITNESS REGIONS: 6652
# ACTIVE NODES: 6653
# INACTIVE NODES: 106
# WITNESS REGIONS: 6653
# ACTIVE NODES: 6654
# INACTIVE NODES: 106
# WITNESS REGIONS: 6654
# ACTIVE NODES: 6655
# INACTIVE NODES: 106
# WITNESS REGIONS: 6655
# ACTIVE NODES: 6655
# INACTIVE NODES: 106
# WITNESS REGIONS: 6655
# ACTIVE NODES: 6656
# INACTIVE NODES: 106
# WITNESS REGIONS: 6656
# ACTIVE NODES: 6657
# INACTIVE NODES: 106
# WITNESS REGIONS: 6657
# ACTIVE NODES: 6657
# INACTIVE NODES: 107
# WITNESS REGIONS: 6657
# ACTIVE NODES: 6657
# INACTIVE NODES: 107
# WITNESS REGIONS: 6657
# ACTIVE NODES: 6657
# INACTIVE NODES: 107
# WITNESS REGIONS: 6657
# ACTIVE NODES: 6658
# INACTIVE NODES: 107
# WITNESS REGIONS: 6658
# ACTIVE NODES: 6658
# INACTIVE NODES: 107
# WITNESS REGIONS: 6658
# ACTIVE NODES: 6659
# INACTIVE NODES: 107
# WITNESS REGIONS: 6659
# ACTIVE NODES: 6660
# INACTIVE NODES: 107
# WITNESS REGIONS: 6660
# ACTIVE NODES: 6660
# INACTIVE NODES: 107
# WITNESS REGIONS: 6660
# ACTIVE NODES: 6661
# INACTIVE NODES: 107
# WITNESS REGIONS: 6661
# ACTIVE NODES: 6661
# INACTIVE NODES: 107
# WITNESS REGIONS: 6661
# ACTIVE NODES: 6662
# INACTIVE NODES: 107
# WITNESS REGIONS: 6662
# ACTIVE NODES: 6663
# INACTIVE NODES: 107
# WITNESS REGIONS: 6663
# ACTIVE NODES: 6664
# INACTIVE NODES: 107
# WITNESS REGIONS: 6664
# ACTIVE NODES: 6664
# INACTIVE NODES: 107
# WITNESS REGIONS: 6664
# ACTIVE NODES: 6665
# INACTIVE NODES: 107
# WITNESS REGIONS: 6665
# ACTIVE NODES: 6665
# INACTIVE NODES: 107
# WITNESS REGIONS: 6665
# ACTIVE NODES: 6665
# INACTIVE NODES: 107
# WITNESS REGIONS: 6665
# ACTIVE NODES: 6666
# INACTIVE NODES: 107
# WITNESS REGIONS: 6666
# ACTIVE NODES: 6667
# INACTIVE NODES: 107
# WITNESS REGIONS: 6667
# ACTIVE NODES: 6668
# INACTIVE NODES: 107
# WITNESS REGIONS: 6668
# ACTIVE NODES: 6668
# INACTIVE NODES: 107
# WITNESS REGIONS: 6668
# ACTIVE NODES: 6669
# INACTIVE NODES: 107
# WITNESS REGIONS: 6669
# ACTIVE NODES: 6669
# INACTIVE NODES: 107
# WITNESS REGIONS: 6669
# ACTIVE NODES: 6669
# INACTIVE NODES: 107
# WITNESS REGIONS: 6669
# ACTIVE NODES: 6670
# INACTIVE NODES: 107
# WITNESS REGIONS: 6670
# ACTIVE NODES: 6671
# INACTIVE NODES: 107
# WITNESS REGIONS: 6671
# ACTIVE NODES: 6672
# INACTIVE NODES: 107
# WITNESS REGIONS: 6672
# ACTIVE NODES: 6673
# INACTIVE NODES: 107
# WITNESS REGIONS: 6673
# ACTIVE NODES: 6674
# INACTIVE NODES: 107
# WITNESS REGIONS: 6674
# ACTIVE NODES: 6675
# INACTIVE NODES: 107
# WITNESS REGIONS: 6675
# ACTIVE NODES: 6676
# INACTIVE NODES: 107
# WITNESS REGIONS: 6676
# ACTIVE NODES: 6676
# INACTIVE NODES: 107
# WITNESS REGIONS: 6676
# ACTIVE NODES: 6677
# INACTIVE NODES: 107
# WITNESS REGIONS: 6677
# ACTIVE NODES: 6678
# INACTIVE NODES: 107
# WITNESS REGIONS: 6678
# ACTIVE NODES: 6679
# INACTIVE NODES: 107
# WITNESS REGIONS: 6679
# ACTIVE NODES: 6680
# INACTIVE NODES: 107
# WITNESS REGIONS: 6680
# ACTIVE NODES: 6681
# INACTIVE NODES: 107
# WITNESS REGIONS: 6681
# ACTIVE NODES: 6681
# INACTIVE NODES: 107
# WITNESS REGIONS: 6681
# ACTIVE NODES: 6681
# INACTIVE NODES: 107
# WITNESS REGIONS: 6681
# ACTIVE NODES: 6681
# INACTIVE NODES: 107
# WITNESS REGIONS: 6681
# ACTIVE NODES: 6682
# INACTIVE NODES: 107
# WITNESS REGIONS: 6682
# ACTIVE NODES: 6683
# INACTIVE NODES: 107
# WITNESS REGIONS: 6683
# ACTIVE NODES: 6684
# INACTIVE NODES: 107
# WITNESS REGIONS: 6684
# ACTIVE NODES: 6684
# INACTIVE NODES: 107
# WITNESS REGIONS: 6684
# ACTIVE NODES: 6685
# INACTIVE NODES: 107
# WITNESS REGIONS: 6685
# ACTIVE NODES: 6685
# INACTIVE NODES: 107
# WITNESS REGIONS: 6685
# ACTIVE NODES: 6686
# INACTIVE NODES: 107
# WITNESS REGIONS: 6686
# ACTIVE NODES: 6687
# INACTIVE NODES: 107
# WITNESS REGIONS: 6687
# ACTIVE NODES: 6688
# INACTIVE NODES: 107
# WITNESS REGIONS: 6688
# ACTIVE NODES: 6688
# INACTIVE NODES: 107
# WITNESS REGIONS: 6688
# ACTIVE NODES: 6689
# INACTIVE NODES: 107
# WITNESS REGIONS: 6689
# ACTIVE NODES: 6690
# INACTIVE NODES: 107
# WITNESS REGIONS: 6690
# ACTIVE NODES: 6691
# INACTIVE NODES: 107
# WITNESS REGIONS: 6691
# ACTIVE NODES: 6692
# INACTIVE NODES: 107
# WITNESS REGIONS: 6692
# ACTIVE NODES: 6692
# INACTIVE NODES: 107
# WITNESS REGIONS: 6692
# ACTIVE NODES: 6693
# INACTIVE NODES: 107
# WITNESS REGIONS: 6693
# ACTIVE NODES: 6694
# INACTIVE NODES: 107
# WITNESS REGIONS: 6694
# ACTIVE NODES: 6694
# INACTIVE NODES: 107
# WITNESS REGIONS: 6694
# ACTIVE NODES: 6695
# INACTIVE NODES: 107
# WITNESS REGIONS: 6695
# ACTIVE NODES: 6695
# INACTIVE NODES: 107
# WITNESS REGIONS: 6695
# ACTIVE NODES: 6695
# INACTIVE NODES: 107
# WITNESS REGIONS: 6695
# ACTIVE NODES: 6696
# INACTIVE NODES: 107
# WITNESS REGIONS: 6696
# ACTIVE NODES: 6696
# INACTIVE NODES: 107
# WITNESS REGIONS: 6696
# ACTIVE NODES: 6697
# INACTIVE NODES: 107
# WITNESS REGIONS: 6697
# ACTIVE NODES: 6697
# INACTIVE NODES: 107
# WITNESS REGIONS: 6697
# ACTIVE NODES: 6698
# INACTIVE NODES: 107
# WITNESS REGIONS: 6698
# ACTIVE NODES: 6699
# INACTIVE NODES: 107
# WITNESS REGIONS: 6699
# ACTIVE NODES: 6699
# INACTIVE NODES: 107
# WITNESS REGIONS: 6699
# ACTIVE NODES: 6700
# INACTIVE NODES: 107
# WITNESS REGIONS: 6700
# ACTIVE NODES: 6701
# INACTIVE NODES: 107
# WITNESS REGIONS: 6701
# ACTIVE NODES: 6702
# INACTIVE NODES: 107
# WITNESS REGIONS: 6702
# ACTIVE NODES: 6703
# INACTIVE NODES: 107
# WITNESS REGIONS: 6703
# ACTIVE NODES: 6703
# INACTIVE NODES: 107
# WITNESS REGIONS: 6703
# ACTIVE NODES: 6704
# INACTIVE NODES: 107
# WITNESS REGIONS: 6704
# ACTIVE NODES: 6705
# INACTIVE NODES: 107
# WITNESS REGIONS: 6705
# ACTIVE NODES: 6705
# INACTIVE NODES: 107
# WITNESS REGIONS: 6705
# ACTIVE NODES: 6706
# INACTIVE NODES: 107
# WITNESS REGIONS: 6706
# ACTIVE NODES: 6707
# INACTIVE NODES: 107
# WITNESS REGIONS: 6707
# ACTIVE NODES: 6708
# INACTIVE NODES: 107
# WITNESS REGIONS: 6708
# ACTIVE NODES: 6709
# INACTIVE NODES: 107
# WITNESS REGIONS: 6709
# ACTIVE NODES: 6710
# INACTIVE NODES: 107
# WITNESS REGIONS: 6710
# ACTIVE NODES: 6711
# INACTIVE NODES: 107
# WITNESS REGIONS: 6711
# ACTIVE NODES: 6712
# INACTIVE NODES: 107
# WITNESS REGIONS: 6712
# ACTIVE NODES: 6713
# INACTIVE NODES: 107
# WITNESS REGIONS: 6713
# ACTIVE NODES: 6714
# INACTIVE NODES: 107
# WITNESS REGIONS: 6714
# ACTIVE NODES: 6715
# INACTIVE NODES: 107
# WITNESS REGIONS: 6715
# ACTIVE NODES: 6715
# INACTIVE NODES: 107
# WITNESS REGIONS: 6715
# ACTIVE NODES: 6716
# INACTIVE NODES: 107
# WITNESS REGIONS: 6716
# ACTIVE NODES: 6717
# INACTIVE NODES: 107
# WITNESS REGIONS: 6717
# ACTIVE NODES: 6718
# INACTIVE NODES: 107
# WITNESS REGIONS: 6718
# ACTIVE NODES: 6719
# INACTIVE NODES: 107
# WITNESS REGIONS: 6719
# ACTIVE NODES: 6719
# INACTIVE NODES: 107
# WITNESS REGIONS: 6719
# ACTIVE NODES: 6719
# INACTIVE NODES: 107
# WITNESS REGIONS: 6719
# ACTIVE NODES: 6719
# INACTIVE NODES: 107
# WITNESS REGIONS: 6719
# ACTIVE NODES: 6720
# INACTIVE NODES: 107
# WITNESS REGIONS: 6720
# ACTIVE NODES: 6721
# INACTIVE NODES: 107
# WITNESS REGIONS: 6721
# ACTIVE NODES: 6722
# INACTIVE NODES: 107
# WITNESS REGIONS: 6722
# ACTIVE NODES: 6722
# INACTIVE NODES: 107
# WITNESS REGIONS: 6722
# ACTIVE NODES: 6723
# INACTIVE NODES: 107
# WITNESS REGIONS: 6723
# ACTIVE NODES: 6723
# INACTIVE NODES: 107
# WITNESS REGIONS: 6723
